# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import random
import os

# %%
def my_seed_everywhere(seed: int = 42):
    random.seed(seed) # random
    np.random.seed(seed) # np
    os.environ["PYTHONHASHSEED"] = str(seed) # os
    tf.random.set_seed(seed) # tensorflow

my_seed = 42
my_seed_everywhere(my_seed)

# %%
df = pd.read_csv('/content/sample_data/onion_final.csv', index_col=0)
df = df.dropna(axis=0)
df = df.reset_index(drop=True)
df['Date'] = pd.to_datetime(df['Date'])
df['DayOfWeek'] = df['Date'].dt.dayofweek

# %%
df = df.drop(['Temp'],axis=1)
df = df.drop(['Oil'],axis=1)
df = df.drop(['Sup'],axis=1)
df = df.drop(['Avg_Price'], axis=1)

df['DayOfWeek'] = df['DayOfWeek'].astype('category')
df = pd.get_dummies(df, columns =['DayOfWeek'], prefix='W', drop_first=True)

df.tail()
# Out:
#            Date  Rain  Wind  sobimul  nongmul   Price  Produced  W_1  W_2  \
# 2390 2022-09-26   0.0   1.7      2.5      8.7  2601.0   1576752    0    0
# 2391 2022-09-27   0.0   1.6      2.5      8.7  2601.0   1576752    1    0
# 2392 2022-09-28   0.0   1.8      2.5      8.7  2601.0   1576752    0    1
# 2393 2022-09-29   0.0   1.4      2.5      8.7  2480.0   1576752    0    0
# 2394 2022-09-30   0.0   1.6      2.5      8.7  2480.0   1576752    0    0
#
#       W_3  W_4
# 2390    0    0
# 2391    0    0
# 2392    0    0
# 2393    1    0
# 2394    0    1

# %%
from sklearn.preprocessing import MinMaxScaler
input_indicator = df.loc[:,['Rain', 'Wind', 'sobimul', 'nongmul', 'Produced', 'W_1', 'W_2', 'W_3', 'W_4']]
target_indicator = df.loc[:,['Price']].values[:]

scaler_input = MinMaxScaler()
scaler_target = MinMaxScaler()
scaled_input_indicator = scaler_input.fit_transform(input_indicator)
scaled_target_indicator = scaler_target.fit_transform(target_indicator) # 가격 관련 지표에 스케일링

x = np.concatenate((scaled_target_indicator, scaled_input_indicator), axis=1)
y = x[:, [0]]

print(x)
print(y.shape)
# Out:
# [[0.37931034 0.         0.61403509 ... 1.         0.         0.        ]
#  [0.35632184 0.         0.36842105 ... 0.         1.         0.        ]
#  [0.35632184 0.         0.19298246 ... 0.         0.         1.        ]
#  ...
#  [0.52576937 0.         0.19298246 ... 1.         0.         0.        ]
#  [0.48090471 0.         0.12280702 ... 0.         1.         0.        ]
#  [0.48090471 0.         0.15789474 ... 0.         0.         1.        ]]
# (2395, 1)

# %%
# 7일치의 input으로 7일치의 output을 생산
seq_length = 7
predict_day = 7
dataX = [] 
dataY = [] 
for i in range(0, int(len(y) - seq_length - predict_day)):
    _x = x[i : i + seq_length]
    _y = y[i + predict_day : i + seq_length + predict_day] 
    dataX.append(_x) 
    dataY.append(_y) 
print(len(dataX))
print(len(dataY))
# Out:
# 2381
# 2381

# %%
# 7의 배수로 설정해야 batch에서 오류가 발생하지 않음
train_size = 1428
validation_size = 476
test_size = 476

trainX = np.array(dataX[0:train_size])
trainY = np.array(dataY[0:train_size])
validX = np.array(dataX[train_size:train_size+validation_size])
validY = np.array(dataY[train_size:train_size+validation_size])
testX = np.array(dataX[train_size+validation_size:train_size+validation_size+test_size])
testY = np.array(dataY[train_size+validation_size:train_size+validation_size+test_size])

print(trainX.shape)
print(trainY.shape)
print(validX.shape)
print(validY.shape)
print(testX.shape)
print(testY.shape)
# Out:
# (1428, 7, 10)
# (1428, 7, 1)
# (476, 7, 10)
# (476, 7, 1)
# (476, 7, 10)
# (476, 7, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, Activation
from tensorflow import keras

# %%
class CustomHistory(keras.callbacks.Callback):
    def init(self):
        self.train_loss = []
        self.val_loss = []
        
    def on_epoch_end(self, batch, logs={}):
        self.train_loss.append(logs.get('loss'))
        self.val_loss.append(logs.get('val_loss'))

# %%
input_columns = 10 # 데이터 셋의 '열' 개수 (dataX) / dataset's columns (dataX)

model = Sequential()
model.add(LSTM(16, batch_input_shape=(7, 7, input_columns), return_sequences=True, stateful=True, dropout=0.1))
model.add(LSTM(16, return_sequences=True, stateful=True, dropout=0.1))
model.add(Dense(1))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (7, 7, 16)                1728
#
#  lstm_5 (LSTM)               (7, 7, 16)                2112
#
#  dense_2 (Dense)             (7, 7, 1)                 17
#
# =================================================================
# Total params: 3,857
# Trainable params: 3,857
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping
checkpoint_cb = keras.callbacks.ModelCheckpoint('best-model-onion.h5', save_best_only=True)
early_stopping_cb = keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=5, restore_best_weights=True)

# %%
keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %%
custom_hist = CustomHistory()
custom_hist.init()

# %%
for epoch_idx in range(100):
  print('epochs:' + str(epoch_idx))
  hist = model.fit(trainX, trainY, validation_data=(validX, validY), epochs=1, batch_size=7, verbose=2, shuffle=False, callbacks=[checkpoint_cb, custom_hist, early_stopping_cb])
  model.reset_states()
# Out:
# epochs:0
# 204/204 - 4s - loss: 0.0370 - mae: 0.1322 - val_loss: 0.0489 - val_mae: 0.1980 - 4s/epoch - 19ms/step
# epochs:1
# 204/204 - 1s - loss: 0.0242 - mae: 0.1125 - val_loss: 0.0824 - val_mae: 0.2685 - 977ms/epoch - 5ms/step
# epochs:2
# 204/204 - 1s - loss: 0.0194 - mae: 0.1042 - val_loss: 0.0782 - val_mae: 0.2631 - 1s/epoch - 6ms/step
# epochs:3
# 204/204 - 1s - loss: 0.0172 - mae: 0.0983 - val_loss: 0.0769 - val_mae: 0.2622 - 1s/epoch - 6ms/step
# epochs:4
# 204/204 - 1s - loss: 0.0153 - mae: 0.0925 - val_loss: 0.0652 - val_mae: 0.2407 - 1s/epoch - 6ms/step
# epochs:5
# 204/204 - 1s - loss: 0.0140 - mae: 0.0883 - val_loss: 0.0554 - val_mae: 0.2208 - 964ms/epoch - 5ms/step
# epochs:6
# 204/204 - 1s - loss: 0.0120 - mae: 0.0801 - val_loss: 0.0469 - val_mae: 0.2023 - 1s/epoch - 5ms/step
# epochs:7
# 204/204 - 1s - loss: 0.0111 - mae: 0.0764 - val_loss: 0.0357 - val_mae: 0.1765 - 1s/epoch - 5ms/step
# epochs:8
# 204/204 - 1s - loss: 0.0099 - mae: 0.0720 - val_loss: 0.0281 - val_mae: 0.1558 - 1s/epoch - 6ms/step
# epochs:9
# 204/204 - 1s - loss: 0.0093 - mae: 0.0679 - val_loss: 0.0217 - val_mae: 0.1362 - 1s/epoch - 6ms/step
# epochs:10
# 204/204 - 1s - loss: 0.0090 - mae: 0.0661 - val_loss: 0.0161 - val_mae: 0.1171 - 983ms/epoch - 5ms/step
# epochs:11
# 204/204 - 1s - loss: 0.0090 - mae: 0.0669 - val_loss: 0.0147 - val_mae: 0.1117 - 1s/epoch - 5ms/step
# epochs:12
# 204/204 - 1s - loss: 0.0088 - mae: 0.0661 - val_loss: 0.0146 - val_mae: 0.1110 - 1s/epoch - 6ms/step
# epochs:13
# 204/204 - 1s - loss: 0.0083 - mae: 0.0633 - val_loss: 0.0121 - val_mae: 0.0997 - 1s/epoch - 5ms/step
# epochs:14
# 204/204 - 1s - loss: 0.0079 - mae: 0.0617 - val_loss: 0.0140 - val_mae: 0.1092 - 1s/epoch - 6ms/step
# epochs:15
# 204/204 - 1s - loss: 0.0080 - mae: 0.0625 - val_loss: 0.0141 - val_mae: 0.1093 - 1s/epoch - 5ms/step
# epochs:16
# 204/204 - 1s - loss: 0.0074 - mae: 0.0609 - val_loss: 0.0117 - val_mae: 0.0989 - 1s/epoch - 6ms/step
# epochs:17
# 204/204 - 1s - loss: 0.0075 - mae: 0.0599 - val_loss: 0.0127 - val_mae: 0.1032 - 1s/epoch - 6ms/step
# epochs:18
# 204/204 - 1s - loss: 0.0074 - mae: 0.0593 - val_loss: 0.0144 - val_mae: 0.1111 - 1s/epoch - 5ms/step
# epochs:19
# 204/204 - 1s - loss: 0.0073 - mae: 0.0596 - val_loss: 0.0106 - val_mae: 0.0940 - 1s/epoch - 5ms/step
# epochs:20
# 204/204 - 1s - loss: 0.0075 - mae: 0.0602 - val_loss: 0.0099 - val_mae: 0.0908 - 1s/epoch - 5ms/step
# epochs:21
# 204/204 - 1s - loss: 0.0073 - mae: 0.0596 - val_loss: 0.0102 - val_mae: 0.0925 - 1s/epoch - 6ms/step
# epochs:22
# 204/204 - 1s - loss: 0.0079 - mae: 0.0616 - val_loss: 0.0134 - val_mae: 0.1072 - 1s/epoch - 5ms/step
# epochs:23
# 204/204 - 1s - loss: 0.0072 - mae: 0.0587 - val_loss: 0.0104 - val_mae: 0.0935 - 1s/epoch - 5ms/step
# epochs:24
# 204/204 - 1s - loss: 0.0070 - mae: 0.0589 - val_loss: 0.0066 - val_mae: 0.0717 - 1s/epoch - 5ms/step
# epochs:25
# 204/204 - 1s - loss: 0.0071 - mae: 0.0586 - val_loss: 0.0139 - val_mae: 0.1095 - 1s/epoch - 6ms/step
# epochs:26
# 204/204 - 1s - loss: 0.0074 - mae: 0.0597 - val_loss: 0.0074 - val_mae: 0.0764 - 1s/epoch - 6ms/step
# epochs:27
# 204/204 - 1s - loss: 0.0069 - mae: 0.0569 - val_loss: 0.0112 - val_mae: 0.0975 - 1s/epoch - 7ms/step
# epochs:28
# 204/204 - 1s - loss: 0.0061 - mae: 0.0551 - val_loss: 0.0069 - val_mae: 0.0736 - 997ms/epoch - 5ms/step
# epochs:29
# 204/204 - 1s - loss: 0.0070 - mae: 0.0584 - val_loss: 0.0089 - val_mae: 0.0856 - 994ms/epoch - 5ms/step
# epochs:30
# 204/204 - 1s - loss: 0.0067 - mae: 0.0574 - val_loss: 0.0050 - val_mae: 0.0598 - 1s/epoch - 6ms/step
# epochs:31
# 204/204 - 1s - loss: 0.0063 - mae: 0.0553 - val_loss: 0.0133 - val_mae: 0.1067 - 1s/epoch - 5ms/step
# epochs:32
# 204/204 - 1s - loss: 0.0065 - mae: 0.0568 - val_loss: 0.0055 - val_mae: 0.0638 - 1s/epoch - 6ms/step
# epochs:33
# 204/204 - 1s - loss: 0.0059 - mae: 0.0537 - val_loss: 0.0084 - val_mae: 0.0824 - 997ms/epoch - 5ms/step
# epochs:34
# 204/204 - 2s - loss: 0.0063 - mae: 0.0549 - val_loss: 0.0083 - val_mae: 0.0821 - 2s/epoch - 8ms/step
# epochs:35
# 204/204 - 1s - loss: 0.0060 - mae: 0.0546 - val_loss: 0.0076 - val_mae: 0.0770 - 1s/epoch - 5ms/step
# epochs:36
# 204/204 - 1s - loss: 0.0061 - mae: 0.0543 - val_loss: 0.0102 - val_mae: 0.0919 - 991ms/epoch - 5ms/step
# epochs:37
# 204/204 - 1s - loss: 0.0063 - mae: 0.0557 - val_loss: 0.0085 - val_mae: 0.0826 - 987ms/epoch - 5ms/step
# epochs:38
# 204/204 - 1s - loss: 0.0060 - mae: 0.0545 - val_loss: 0.0101 - val_mae: 0.0918 - 1s/epoch - 6ms/step
# epochs:39
# 204/204 - 1s - loss: 0.0063 - mae: 0.0544 - val_loss: 0.0087 - val_mae: 0.0834 - 994ms/epoch - 5ms/step
# epochs:40
# 204/204 - 1s - loss: 0.0054 - mae: 0.0521 - val_loss: 0.0080 - val_mae: 0.0802 - 1s/epoch - 6ms/step
# epochs:41
# 204/204 - 1s - loss: 0.0058 - mae: 0.0533 - val_loss: 0.0090 - val_mae: 0.0853 - 994ms/epoch - 5ms/step
# epochs:42
# 204/204 - 1s - loss: 0.0058 - mae: 0.0535 - val_loss: 0.0065 - val_mae: 0.0703 - 984ms/epoch - 5ms/step
# epochs:43
# 204/204 - 1s - loss: 0.0056 - mae: 0.0520 - val_loss: 0.0062 - val_mae: 0.0685 - 1s/epoch - 6ms/step
# epochs:44
# 204/204 - 1s - loss: 0.0054 - mae: 0.0510 - val_loss: 0.0067 - val_mae: 0.0708 - 985ms/epoch - 5ms/step
# epochs:45
# 204/204 - 1s - loss: 0.0054 - mae: 0.0517 - val_loss: 0.0113 - val_mae: 0.0973 - 979ms/epoch - 5ms/step
# epochs:46
# 204/204 - 1s - loss: 0.0059 - mae: 0.0530 - val_loss: 0.0056 - val_mae: 0.0634 - 959ms/epoch - 5ms/step
# epochs:47
# 204/204 - 1s - loss: 0.0051 - mae: 0.0505 - val_loss: 0.0116 - val_mae: 0.0985 - 999ms/epoch - 5ms/step
# epochs:48
# 204/204 - 1s - loss: 0.0056 - mae: 0.0524 - val_loss: 0.0066 - val_mae: 0.0707 - 1s/epoch - 7ms/step
# epochs:49
# 204/204 - 1s - loss: 0.0051 - mae: 0.0506 - val_loss: 0.0094 - val_mae: 0.0870 - 984ms/epoch - 5ms/step
# epochs:50
# 204/204 - 1s - loss: 0.0052 - mae: 0.0505 - val_loss: 0.0085 - val_mae: 0.0828 - 1s/epoch - 5ms/step
# epochs:51
# 204/204 - 1s - loss: 0.0052 - mae: 0.0508 - val_loss: 0.0064 - val_mae: 0.0684 - 979ms/epoch - 5ms/step
# epochs:52
# 204/204 - 1s - loss: 0.0050 - mae: 0.0498 - val_loss: 0.0089 - val_mae: 0.0842 - 977ms/epoch - 5ms/step
# epochs:53
# 204/204 - 1s - loss: 0.0051 - mae: 0.0504 - val_loss: 0.0077 - val_mae: 0.0759 - 999ms/epoch - 5ms/step
# epochs:54
# 204/204 - 1s - loss: 0.0050 - mae: 0.0491 - val_loss: 0.0103 - val_mae: 0.0907 - 1s/epoch - 6ms/step
# epochs:55
# 204/204 - 1s - loss: 0.0047 - mae: 0.0484 - val_loss: 0.0068 - val_mae: 0.0716 - 1s/epoch - 5ms/step
# epochs:56
# 204/204 - 1s - loss: 0.0048 - mae: 0.0484 - val_loss: 0.0075 - val_mae: 0.0748 - 988ms/epoch - 5ms/step
# epochs:57
# 204/204 - 1s - loss: 0.0043 - mae: 0.0463 - val_loss: 0.0096 - val_mae: 0.0880 - 1s/epoch - 5ms/step
# epochs:58
# 204/204 - 1s - loss: 0.0049 - mae: 0.0489 - val_loss: 0.0063 - val_mae: 0.0663 - 1s/epoch - 5ms/step
# epochs:59
# 204/204 - 1s - loss: 0.0048 - mae: 0.0491 - val_loss: 0.0103 - val_mae: 0.0910 - 1s/epoch - 6ms/step
# epochs:60
# 204/204 - 1s - loss: 0.0047 - mae: 0.0490 - val_loss: 0.0091 - val_mae: 0.0858 - 990ms/epoch - 5ms/step
# epochs:61
# 204/204 - 1s - loss: 0.0047 - mae: 0.0482 - val_loss: 0.0067 - val_mae: 0.0704 - 1s/epoch - 5ms/step
# epochs:62
# 204/204 - 1s - loss: 0.0044 - mae: 0.0471 - val_loss: 0.0080 - val_mae: 0.0786 - 998ms/epoch - 5ms/step
# epochs:63
# 204/204 - 1s - loss: 0.0044 - mae: 0.0463 - val_loss: 0.0071 - val_mae: 0.0726 - 999ms/epoch - 5ms/step
# epochs:64
# 204/204 - 1s - loss: 0.0045 - mae: 0.0475 - val_loss: 0.0114 - val_mae: 0.0969 - 1s/epoch - 6ms/step
# epochs:65
# 204/204 - 1s - loss: 0.0045 - mae: 0.0471 - val_loss: 0.0062 - val_mae: 0.0660 - 993ms/epoch - 5ms/step
# epochs:66
# 204/204 - 1s - loss: 0.0042 - mae: 0.0465 - val_loss: 0.0089 - val_mae: 0.0838 - 988ms/epoch - 5ms/step
# epochs:67
# 204/204 - 1s - loss: 0.0045 - mae: 0.0471 - val_loss: 0.0082 - val_mae: 0.0786 - 1s/epoch - 5ms/step
# epochs:68
# 204/204 - 1s - loss: 0.0042 - mae: 0.0454 - val_loss: 0.0076 - val_mae: 0.0759 - 1s/epoch - 5ms/step
# epochs:69
# 204/204 - 1s - loss: 0.0045 - mae: 0.0465 - val_loss: 0.0083 - val_mae: 0.0793 - 1s/epoch - 6ms/step
# epochs:70
# 204/204 - 1s - loss: 0.0040 - mae: 0.0452 - val_loss: 0.0069 - val_mae: 0.0711 - 985ms/epoch - 5ms/step
# epochs:71
# 204/204 - 1s - loss: 0.0040 - mae: 0.0448 - val_loss: 0.0068 - val_mae: 0.0687 - 1s/epoch - 6ms/step
# epochs:72
# 204/204 - 1s - loss: 0.0040 - mae: 0.0444 - val_loss: 0.0076 - val_mae: 0.0748 - 1s/epoch - 5ms/step
# epochs:73
# 204/204 - 1s - loss: 0.0040 - mae: 0.0439 - val_loss: 0.0078 - val_mae: 0.0756 - 1s/epoch - 7ms/step
# epochs:74
# 204/204 - 1s - loss: 0.0037 - mae: 0.0443 - val_loss: 0.0062 - val_mae: 0.0656 - 1s/epoch - 6ms/step
# epochs:75
# 204/204 - 1s - loss: 0.0039 - mae: 0.0444 - val_loss: 0.0068 - val_mae: 0.0710 - 1s/epoch - 5ms/step
# epochs:76
# 204/204 - 1s - loss: 0.0042 - mae: 0.0448 - val_loss: 0.0065 - val_mae: 0.0682 - 1s/epoch - 6ms/step
# epochs:77
# 204/204 - 1s - loss: 0.0036 - mae: 0.0436 - val_loss: 0.0063 - val_mae: 0.0660 - 996ms/epoch - 5ms/step
# epochs:78
# 204/204 - 1s - loss: 0.0035 - mae: 0.0423 - val_loss: 0.0057 - val_mae: 0.0615 - 989ms/epoch - 5ms/step
# epochs:79
# 204/204 - 1s - loss: 0.0036 - mae: 0.0433 - val_loss: 0.0063 - val_mae: 0.0665 - 1s/epoch - 6ms/step
# epochs:80
# 204/204 - 1s - loss: 0.0037 - mae: 0.0438 - val_loss: 0.0060 - val_mae: 0.0640 - 1s/epoch - 5ms/step
# epochs:81
# 204/204 - 1s - loss: 0.0035 - mae: 0.0430 - val_loss: 0.0065 - val_mae: 0.0680 - 1s/epoch - 6ms/step
# epochs:82
# 204/204 - 1s - loss: 0.0036 - mae: 0.0426 - val_loss: 0.0056 - val_mae: 0.0610 - 1s/epoch - 6ms/step
# epochs:83
# 204/204 - 1s - loss: 0.0035 - mae: 0.0428 - val_loss: 0.0061 - val_mae: 0.0658 - 1s/epoch - 5ms/step
# epochs:84
# 204/204 - 1s - loss: 0.0036 - mae: 0.0421 - val_loss: 0.0053 - val_mae: 0.0602 - 998ms/epoch - 5ms/step
# epochs:85
# 204/204 - 1s - loss: 0.0040 - mae: 0.0439 - val_loss: 0.0053 - val_mae: 0.0591 - 975ms/epoch - 5ms/step
# epochs:86
# 204/204 - 1s - loss: 0.0039 - mae: 0.0453 - val_loss: 0.0102 - val_mae: 0.0922 - 980ms/epoch - 5ms/step
# epochs:87
# 204/204 - 1s - loss: 0.0038 - mae: 0.0435 - val_loss: 0.0046 - val_mae: 0.0544 - 1s/epoch - 5ms/step
# epochs:88
# 204/204 - 1s - loss: 0.0036 - mae: 0.0421 - val_loss: 0.0058 - val_mae: 0.0643 - 974ms/epoch - 5ms/step
# epochs:89
# 204/204 - 1s - loss: 0.0037 - mae: 0.0436 - val_loss: 0.0053 - val_mae: 0.0580 - 1s/epoch - 6ms/step
# epochs:90
# 204/204 - 1s - loss: 0.0039 - mae: 0.0447 - val_loss: 0.0050 - val_mae: 0.0551 - 1s/epoch - 6ms/step
# epochs:91
# 204/204 - 1s - loss: 0.0041 - mae: 0.0464 - val_loss: 0.0082 - val_mae: 0.0797 - 1s/epoch - 5ms/step
# epochs:92
# 204/204 - 1s - loss: 0.0040 - mae: 0.0442 - val_loss: 0.0057 - val_mae: 0.0629 - 997ms/epoch - 5ms/step
# epochs:93
# 204/204 - 1s - loss: 0.0033 - mae: 0.0410 - val_loss: 0.0045 - val_mae: 0.0533 - 1s/epoch - 5ms/step
# epochs:94
# 204/204 - 1s - loss: 0.0032 - mae: 0.0406 - val_loss: 0.0046 - val_mae: 0.0538 - 1s/epoch - 6ms/step
# epochs:95
# 204/204 - 1s - loss: 0.0036 - mae: 0.0425 - val_loss: 0.0051 - val_mae: 0.0565 - 999ms/epoch - 5ms/step
# epochs:96
# 204/204 - 1s - loss: 0.0032 - mae: 0.0409 - val_loss: 0.0062 - val_mae: 0.0655 - 998ms/epoch - 5ms/step
# epochs:97
# 204/204 - 1s - loss: 0.0036 - mae: 0.0429 - val_loss: 0.0051 - val_mae: 0.0562 - 1s/epoch - 6ms/step
# epochs:98
# 204/204 - 1s - loss: 0.0036 - mae: 0.0433 - val_loss: 0.0086 - val_mae: 0.0827 - 1s/epoch - 6ms/step
# epochs:99
# 204/204 - 1s - loss: 0.0036 - mae: 0.0428 - val_loss: 0.0057 - val_mae: 0.0639 - 1s/epoch - 6ms/step

# %%
a = 7

# %%
model.evaluate(trainX, trainY, batch_size = a)
# Out:
# 204/204 [==============================] - 1s 3ms/step - loss: 0.0046 - mae: 0.0500
# [0.004624024964869022, 0.05004009231925011]

# %%
print(custom_hist.train_loss)
# Out:
# [0.03696367144584656, 0.024217909201979637, 0.019384240731596947, 0.017237359657883644, 0.015256625600159168, 0.014033532701432705, 0.011965631507337093, 0.011106343939900398, 0.009921925142407417, 0.009317181073129177, 0.008968829177320004, 0.009035552851855755, 0.008848744444549084, 0.008268607780337334, 0.007883818820118904, 0.007992962375283241, 0.007410755846649408, 0.007517070043832064, 0.007402242626994848, 0.007268587592989206, 0.007524522487074137, 0.007291266694664955, 0.007934833876788616, 0.007172449491918087, 0.0069810133427381516, 0.0070791603066027164, 0.007381114177405834, 0.006851674988865852, 0.006115084048360586, 0.007014722563326359, 0.0067367334850132465, 0.006285431794822216, 0.006499664392322302, 0.005935318768024445, 0.006323155015707016, 0.005952096544206142, 0.006080084480345249, 0.006348108407109976, 0.006019026041030884, 0.006253078114241362, 0.00539515120908618, 0.005846607964485884, 0.005811454262584448, 0.005572169553488493, 0.005414696875959635, 0.005435904022306204, 0.0059189810417592525, 0.005110971629619598, 0.005620589945465326, 0.005105414427816868, 0.005209743045270443, 0.0052350424230098724, 0.005016878247261047, 0.00513063371181488, 0.004973740316927433, 0.00469075096771121, 0.004757648333907127, 0.004309840500354767, 0.00494165625423193, 0.004764206241816282, 0.0047089415602386, 0.004676527809351683, 0.0043831439688801765, 0.004368623252958059, 0.004472687840461731, 0.004497691988945007, 0.004234567750245333, 0.0045244875364005566, 0.00422326335683465, 0.004503621254116297, 0.003972465172410011, 0.003961266949772835, 0.003990933299064636, 0.00396478408947587, 0.0037094391882419586, 0.0038649013731628656, 0.0042335898615419865, 0.003587020095437765, 0.003460409352555871, 0.003623788710683584, 0.003698041196912527, 0.0035317097790539265, 0.003555400064215064, 0.003535526804625988, 0.003593736095353961, 0.004026731010526419, 0.003938778769224882, 0.0038408832624554634, 0.0035626620519906282, 0.00374965975061059, 0.0039010155014693737, 0.004091622307896614, 0.003982660360634327, 0.0033261829521507025, 0.0032370530534535646, 0.0036208275705575943, 0.0031666031572967768, 0.0035501865204423666, 0.0035598776303231716, 0.0035919437650591135]

# %%
plt.figure(figsize=(20,10))
plt.plot(custom_hist.train_loss, color = 'blue', label = 'train_loss')
plt.plot(custom_hist.val_loss, color = 'red', label = 'val_loss')
plt.title('Training Loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
from keras.models import load_model
model = load_model('/content/best-model-onion.h5')

# %% [markdown]
# Train Data *평가*

# %%
model.evaluate(trainX, trainY, batch_size=a)
# Out:
# 204/204 [==============================] - 1s 3ms/step - loss: 0.0047 - mae: 0.0499
# [0.004663817584514618, 0.049884263426065445]

# %%
predicted_price_train = model.predict(trainX, batch_size=a, verbose=1)
# Out:
# 204/204 [==============================] - 1s 2ms/step

# %%
trainY_test = np.delete(trainY, np.s_[1:a], axis=1)
predicted_price_train_test = np.delete(predicted_price_train, np.s_[1:a], axis=1)

trainY_test = np.reshape(trainY_test, (1428, 1))
predicted_price_train_test = np.reshape(predicted_price_train_test, (1428, 1))
print(trainY_test.shape)
print(predicted_price_train_test.shape)
# Out:
# (1428, 1)
# (1428, 1)

# %%
plt.figure(figsize=(20,10))
plt.plot(trainY_test, color = 'blue', label = 'Actual Stock Price')
plt.plot(predicted_price_train_test, color = 'red', label = 'Predicted Stock Price')
plt.title('Price Prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
predicted_price_train_test = np.reshape(predicted_price_train_test, (1428, ))
predicted_price_train_test = scaler_target.inverse_transform(predicted_price_train_test.reshape(-1,1))

print(predicted_price_train_test, predicted_price_train_test.shape)

trainY_test = scaler_target.inverse_transform(trainY_test.reshape(-1,1))

print(trainY_test, trainY_test.shape)
# Out:
# [[1797.2383]
#  [1767.9032]
#  [1774.588 ]
#  ...
#  [1585.4985]
#  [1587.8837]
#  [1592.32  ]] (1428, 1)
# [[2323.]
#  [2323.]
#  [2323.]
#  ...
#  [1653.]
#  [1520.]
#  [1520.]] (1428, 1)

# %%
from sklearn.metrics import mean_squared_error 
MSE = mean_squared_error(trainY_test, predicted_price_train_test) 
np.sqrt(MSE)
# Out:
# 187.9824045584249

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(trainY_test, predicted_price_train_test)
# Out:
# 136.71057316969757

# %% [markdown]
# Val Date 평가

# %%
model.evaluate(validX, validY, batch_size=a)
# Out:
# 68/68 [==============================] - 0s 3ms/step - loss: 0.0045 - mae: 0.0533
# [0.0045211464166641235, 0.05327194556593895]

# %%
predicted_price_valid = model.predict(validX, batch_size=a, verbose=1)
# Out:
# 68/68 [==============================] - 0s 2ms/step

# %%
validY_test = np.delete(validY, np.s_[1:a], axis=1)
predicted_price_valid_test = np.delete(predicted_price_valid, np.s_[1:a], axis=1)

validY_test = np.reshape(validY_test, (476, 1))
predicted_price_valid_test = np.reshape(predicted_price_valid_test, (476, 1))
print(validY_test.shape)
print(predicted_price_valid_test.shape)

plt.figure(figsize=(20,10))
plt.plot(validY_test, color = 'blue', label = 'Actual Stock Price')
plt.plot(predicted_price_valid_test, color = 'red', label = 'Predicted Stock Price')
plt.title('Price Prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# (476, 1)
# (476, 1)

# %%
predicted_price_valid_test = np.reshape(predicted_price_valid_test, (476, ))
predicted_price_valid_test = scaler_target.inverse_transform(predicted_price_valid_test.reshape(-1,1))

print(predicted_price_valid_test, predicted_price_valid_test.shape)

validY_test = scaler_target.inverse_transform(validY_test.reshape(-1,1))

print(validY_test, validY_test.shape)
# Out:
# [[2218.1912]
#  [2211.8145]
#  [2239.56  ]
#  [2280.2097]
#  [2317.1792]
#  [2227.612 ]
#  [2317.692 ]
#  [1581.3333]
#  [1581.3901]
#  [1595.111 ]
#  [1588.4222]
#  [1595.134 ]
#  [1600.7567]
#  [1613.3644]
#  [1557.3263]
#  [1550.8817]
#  [1547.5696]
#  [1554.7162]
#  [1559.9995]
#  [1574.2635]
#  [1573.0127]
#  [1544.8092]
#  [1549.3357]
#  [1547.2853]
#  [1552.8372]
#  [1545.0663]
#  [1542.8849]
#  [1546.7059]
#  [1553.6107]
#  [1561.2513]
#  [1565.8403]
#  [1580.4412]
#  [1586.7056]
#  [1601.3563]
#  [1597.3424]
#  [1586.9374]
#  [1591.1917]
#  [1605.4581]
#  [1602.4692]
#  [1596.6545]
#  [1600.5347]
#  [1652.2316]
#  [1665.9762]
#  [1670.5957]
#  [1681.2655]
#  [1690.5924]
#  [1709.6919]
#  [1705.1884]
#  [1703.1149]
#  [1710.4152]
#  [1717.3207]
#  [1733.9445]
#  [1718.7472]
#  [1707.3564]
#  [1698.9019]
#  [1693.3234]
#  [1703.6501]
#  [1680.3806]
#  [1659.8689]
#  [1649.8223]
#  [1643.0076]
#  [1652.1705]
#  [1641.3544]
#  [1637.8477]
#  [1646.3221]
#  [1653.3352]
#  [1661.1685]
#  [1666.1912]
#  [1681.4647]
#  [1665.1488]
#  [1651.8579]
#  [1650.4469]
#  [1650.7284]
#  [1667.1793]
#  [1649.5691]
#  [1626.7487]
#  [1613.3976]
#  [1606.1567]
#  [1615.0529]
#  [1613.1538]
#  [1621.8873]
#  [1633.1515]
#  [1656.8198]
#  [1644.6282]
#  [1627.4194]
#  [1617.1195]
#  [1610.3032]
#  [1618.601 ]
#  [1609.7986]
#  [1609.8547]
#  [1613.1198]
#  [1622.2869]
#  [1639.6798]
#  [1641.3489]
#  [1643.7511]
#  [1651.0543]
#  [1659.206 ]
#  [1678.1296]
#  [1662.5308]
#  [1647.4078]
#  [1640.9453]
#  [1636.5936]
#  [1647.4265]
#  [1671.4457]
#  [1669.2408]
#  [1667.6896]
#  [1656.1794]
#  [1665.3875]
#  [1655.9055]
#  [1644.9889]
#  [1641.5698]
#  [1641.0258]
#  [1655.3992]
#  [1850.7643]
#  [1894.6614]
#  [1962.7982]
#  [1998.6062]
#  [2015.317 ]
#  [1986.5602]
#  [1960.4117]
#  [1966.0052]
#  [1973.5135]
#  [1968.4207]
#  [1960.2365]
#  [1973.1007]
#  [1988.3247]
#  [1960.8068]
#  [1931.072 ]
#  [1917.8356]
#  [1914.1355]
#  [1927.1462]
#  [1908.094 ]
#  [1889.7848]
#  [1891.9325]
#  [1894.9878]
#  [1894.3529]
#  [1861.0369]
#  [1838.1533]
#  [1844.02  ]
#  [1835.8239]
#  [1836.3888]
#  [1800.3159]
#  [1772.6678]
#  [1759.6755]
#  [1752.0583]
#  [1760.3324]
#  [1721.3517]
#  [1711.1925]
#  [1708.9574]
#  [1718.4501]
#  [1699.329 ]
#  [1686.243 ]
#  [1684.6278]
#  [1674.8987]
#  [1685.2097]
#  [1665.5834]
#  [1649.4841]
#  [1643.91  ]
#  [1637.9882]
#  [1646.2228]
#  [1627.0035]
#  [1610.348 ]
#  [1610.1698]
#  [1614.2651]
#  [1629.936 ]
#  [1613.3186]
#  [1591.4753]
#  [1579.6088]
#  [1573.3583]
#  [1580.4028]
#  [1567.9492]
#  [1559.1838]
#  [1556.1948]
#  [1554.1847]
#  [1564.8827]
#  [1550.8687]
#  [1531.6731]
#  [1524.0455]
#  [1523.8145]
#  [1536.1266]
#  [1522.1694]
#  [1501.5825]
#  [1516.78  ]
#  [1523.9539]
#  [1521.1794]
#  [1515.7109]
#  [1510.2393]
#  [1509.3193]
#  [1509.634 ]
#  [1518.7711]
#  [1509.9495]
#  [1505.119 ]
#  [1499.1875]
#  [1518.2974]
#  [1538.1051]
#  [1533.3766]
#  [1530.2103]
#  [1529.7916]
#  [1540.4243]
#  [1529.3086]
#  [1513.5254]
#  [1510.0417]
#  [1503.5516]
#  [1518.2247]
#  [1503.8171]
#  [1511.1366]
#  [1525.6787]
#  [1534.2302]
#  [1544.6193]
#  [1530.6302]
#  [1529.9681]
#  [1534.0939]
#  [1520.1941]
#  [1536.5775]
#  [1539.8843]
#  [1538.2743]
#  [1546.9877]
#  [1533.0275]
#  [1516.9403]
#  [1511.9619]
#  [1508.5604]
#  [1518.6022]
#  [1507.7808]
#  [1501.3104]
#  [1506.2568]
#  [1511.697 ]
#  [1522.6356]
#  [1524.4023]
#  [1514.2025]
#  [1515.5294]
#  [1506.8207]
#  [1504.832 ]
#  [1508.3232]
#  [1511.7428]
#  [1526.2545]
#  [1519.9485]
#  [1518.4922]
#  [1525.0815]
#  [1528.5286]
#  [1543.1407]
#  [1532.294 ]
#  [1522.2118]
#  [1521.2524]
#  [1521.6573]
#  [1534.311 ]
#  [1524.345 ]
#  [1519.0708]
#  [1523.3939]
#  [1528.2687]
#  [1544.898 ]
#  [1537.8127]
#  [1533.884 ]
#  [1537.7517]
#  [1542.4812]
#  [1556.5089]
#  [1548.0238]
#  [1533.4551]
#  [1532.1493]
#  [1535.1165]
#  [1544.704 ]
#  [1530.5981]
#  [1519.2218]
#  [1521.9122]
#  [1527.0021]
#  [1542.8887]
#  [1535.0781]
#  [1525.5443]
#  [1525.5651]
#  [1526.3058]
#  [1537.977 ]
#  [1525.7528]
#  [1519.2709]
#  [1515.5918]
#  [1528.7483]
#  [1530.6865]
#  [1535.2369]
#  [1548.0137]
#  [1555.464 ]
#  [1575.811 ]
#  [1573.4554]
#  [1572.6744]
#  [1580.9675]
#  [1589.5454]
#  [1589.8977]
#  [1596.5444]
#  [1604.9266]
#  [1608.8577]
#  [1610.8843]
#  [1631.6134]
#  [1646.1035]
#  [1640.8982]
#  [1646.5757]
#  [1664.8835]
#  [1718.3453]
#  [1763.3406]
#  [1801.938 ]
#  [1834.8573]
#  [1865.5582]
#  [1894.2219]
#  [1916.9906]
#  [1937.8021]
#  [1960.6947]
#  [1954.5364]
#  [1954.3556]
#  [1962.0887]
#  [1963.9615]
#  [1973.5568]
#  [1979.6202]
#  [1978.3099]
#  [1983.7302]
#  [1975.0602]
#  [1982.3875]
#  [1986.656 ]
#  [1994.711 ]
#  [2004.8102]
#  [1989.6058]
#  [1989.603 ]
#  [1991.6033]
#  [1990.9833]
#  [1998.2333]
#  [1997.506 ]
#  [2006.6353]
#  [2020.0548]
#  [2020.8788]
#  [2047.0774]
#  [2112.8623]
#  [2148.5234]
#  [2380.8125]
#  [2457.6084]
#  [2480.1816]
#  [2527.5872]
#  [2529.8076]
#  [2525.9724]
#  [2487.2878]
#  [2470.3816]
#  [2420.8274]
#  [2404.8997]
#  [2386.2002]
#  [2381.3147]
#  [2383.2534]
#  [2405.0305]
#  [2401.9192]
#  [2394.4453]
#  [2391.427 ]
#  [2389.7104]
#  [2372.969 ]
#  [2369.6333]
#  [2367.8643]
#  [2368.2048]
#  [2377.0864]
#  [2382.5334]
#  [2389.8606]
#  [2379.1716]
#  [2373.3196]
#  [2375.6106]
#  [2351.2222]
#  [2339.2046]
#  [2359.2456]
#  [2369.5059]
#  [2370.4387]
#  [2355.4595]
#  [2350.473 ]
#  [2339.1523]
#  [2329.9998]
#  [2341.7415]
#  [2351.7488]
#  [2338.3792]
#  [2325.1838]
#  [2319.18  ]
#  [2319.3132]
#  [2293.4739]
#  [2284.67  ]
#  [2267.09  ]
#  [2261.736 ]
#  [2247.914 ]
#  [2238.4617]
#  [2246.53  ]
#  [2230.175 ]
#  [2211.1472]
#  [2208.6577]
#  [2212.3196]
#  [2201.4521]
#  [2190.9592]
#  [2182.6404]
#  [2181.1147]
#  [2184.6174]
#  [2183.969 ]
#  [2185.887 ]
#  [2208.339 ]
#  [2214.291 ]
#  [2220.2817]
#  [2214.8467]
#  [2214.284 ]
#  [2217.695 ]
#  [2220.9902]
#  [2218.301 ]
#  [2191.2747]
#  [2179.345 ]
#  [2175.7566]
#  [2172.4922]
#  [2174.2798]
#  [2156.6108]
#  [2155.0483]
#  [2154.7195]
#  [2157.8245]
#  [2138.7593]
#  [2111.246 ]
#  [2110.4077]
#  [2098.9597]
#  [2040.8184]
#  [2032.891 ]
#  [2045.6385]
#  [2057.2769]
#  [2068.1204]
#  [2076.4683]
#  [2083.1926]
#  [2085.4985]
#  [2083.229 ]
#  [2055.9526]
#  [2051.2185]
#  [2054.4731]
#  [2059.6138]
#  [2066.0803]
#  [2072.8064]
#  [2075.4849]
#  [2076.9397]
#  [1991.6848]
#  [1994.952 ]
#  [2007.9045]
#  [2015.9312]
#  [2002.1622]
#  [2016.6361]
#  [2032.9269]
#  [1995.1598]
#  [2012.7621]
#  [2008.4487]
#  [1975.1932]
#  [1990.2493]
#  [1992.1371]
#  [1961.6478]
#  [1957.3759]
#  [2004.9838]
#  [2026.6418]
#  [2032.2585]
#  [2042.2854]
#  [2071.5266]
#  [2093.9717]
#  [2114.4814]
#  [2127.6565]
#  [2136.2988]
#  [2107.7783]
#  [2091.1182]
#  [2095.42  ]
#  [2074.0144]
#  [2044.2256]
#  [2048.214 ]
#  [2070.2402]
#  [2063.7224]
#  [2059.9607]
#  [2055.8835]
#  [2107.4346]
#  [2137.7441]
#  [2145.9656]
#  [2161.6738]
#  [2168.8555]
#  [2180.0203]
#  [2194.4854]
#  [2208.1702]
#  [2220.1536]
#  [2224.9675]
#  [2238.8254]
#  [2245.6875]
#  [2262.846 ]
#  [2255.078 ]
#  [2256.531 ]
#  [2242.6067]] (476, 1)
# [[1520.]
#  [1613.]
#  [1613.]
#  [1579.]
#  [1579.]
#  [1567.]
#  [1584.]
#  [1584.]
#  [1584.]
#  [1584.]
#  [1584.]
#  [1560.]
#  [1601.]
#  [1540.]
#  [1533.]
#  [1586.]
#  [1529.]
#  [1529.]
#  [1554.]
#  [1554.]
#  [1554.]
#  [1554.]
#  [1638.]
#  [1638.]
#  [1638.]
#  [1638.]
#  [1638.]
#  [1616.]
#  [1616.]
#  [1616.]
#  [1630.]
#  [1639.]
#  [1639.]
#  [1639.]
#  [1639.]
#  [1616.]
#  [1616.]
#  [1616.]
#  [1611.]
#  [1611.]
#  [1633.]
#  [1633.]
#  [1633.]
#  [1616.]
#  [1616.]
#  [1600.]
#  [1600.]
#  [1533.]
#  [1534.]
#  [1534.]
#  [1465.]
#  [1465.]
#  [1465.]
#  [1465.]
#  [1465.]
#  [1534.]
#  [1534.]
#  [1595.]
#  [1585.]
#  [1585.]
#  [1585.]
#  [1560.]
#  [1511.]
#  [1511.]
#  [1511.]
#  [1511.]
#  [1511.]
#  [1371.]
#  [1371.]
#  [1371.]
#  [1371.]
#  [1371.]
#  [1535.]
#  [1535.]
#  [1535.]
#  [1535.]
#  [1439.]
#  [1404.]
#  [1404.]
#  [1404.]
#  [1404.]
#  [1503.]
#  [1519.]
#  [1458.]
#  [1526.]
#  [1526.]
#  [1559.]
#  [1559.]
#  [1559.]
#  [1589.]
#  [1589.]
#  [1503.]
#  [1503.]
#  [1493.]
#  [1493.]
#  [1493.]
#  [1714.]
#  [1568.]
#  [1568.]
#  [1568.]
#  [1568.]
#  [1568.]
#  [1510.]
#  [1510.]
#  [1510.]
#  [1510.]
#  [2120.]
#  [2107.]
#  [2191.]
#  [2183.]
#  [2158.]
#  [2074.]
#  [2056.]
#  [2056.]
#  [2043.]
#  [2008.]
#  [2021.]
#  [2045.]
#  [2036.]
#  [1944.]
#  [1919.]
#  [1909.]
#  [1909.]
#  [1938.]
#  [1894.]
#  [1894.]
#  [1918.]
#  [1918.]
#  [1835.]
#  [1820.]
#  [1820.]
#  [1886.]
#  [1779.]
#  [1766.]
#  [1683.]
#  [1683.]
#  [1683.]
#  [1670.]
#  [1670.]
#  [1600.]
#  [1600.]
#  [1600.]
#  [1600.]
#  [1581.]
#  [1581.]
#  [1581.]
#  [1553.]
#  [1553.]
#  [1491.]
#  [1491.]
#  [1491.]
#  [1420.]
#  [1466.]
#  [1410.]
#  [1394.]
#  [1469.]
#  [1469.]
#  [1469.]
#  [1335.]
#  [1335.]
#  [1335.]
#  [1335.]
#  [1335.]
#  [1369.]
#  [1340.]
#  [1320.]
#  [1271.]
#  [1271.]
#  [1211.]
#  [1205.]
#  [1251.]
#  [1251.]
#  [1251.]
#  [1249.]
#  [1231.]
#  [1231.]
#  [1238.]
#  [1231.]
#  [1218.]
#  [1218.]
#  [1218.]
#  [1218.]
#  [1213.]
#  [1278.]
#  [1278.]
#  [1278.]
#  [1278.]
#  [1278.]
#  [1278.]
#  [1296.]
#  [1276.]
#  [1296.]
#  [1230.]
#  [1230.]
#  [1230.]
#  [1230.]
#  [1230.]
#  [1329.]
#  [1343.]
#  [1366.]
#  [1343.]
#  [1338.]
#  [1339.]
#  [1339.]
#  [1311.]
#  [1339.]
#  [1339.]
#  [1339.]
#  [1339.]
#  [1339.]
#  [1284.]
#  [1284.]
#  [1249.]
#  [1249.]
#  [1249.]
#  [1290.]
#  [1290.]
#  [1290.]
#  [1290.]
#  [1290.]
#  [1274.]
#  [1223.]
#  [1223.]
#  [1314.]
#  [1250.]
#  [1250.]
#  [1250.]
#  [1250.]
#  [1326.]
#  [1326.]
#  [1284.]
#  [1268.]
#  [1268.]
#  [1275.]
#  [1275.]
#  [1275.]
#  [1284.]
#  [1284.]
#  [1323.]
#  [1323.]
#  [1323.]
#  [1323.]
#  [1323.]
#  [1343.]
#  [1343.]
#  [1343.]
#  [1343.]
#  [1343.]
#  [1301.]
#  [1301.]
#  [1301.]
#  [1301.]
#  [1301.]
#  [1310.]
#  [1310.]
#  [1349.]
#  [1349.]
#  [1349.]
#  [1310.]
#  [1310.]
#  [1310.]
#  [1285.]
#  [1285.]
#  [1301.]
#  [1244.]
#  [1278.]
#  [1319.]
#  [1395.]
#  [1395.]
#  [1398.]
#  [1419.]
#  [1419.]
#  [1441.]
#  [1441.]
#  [1463.]
#  [1463.]
#  [1470.]
#  [1460.]
#  [1443.]
#  [1443.]
#  [1464.]
#  [1464.]
#  [1464.]
#  [1464.]
#  [1470.]
#  [1530.]
#  [1638.]
#  [1661.]
#  [1695.]
#  [1695.]
#  [1748.]
#  [1743.]
#  [1756.]
#  [1768.]
#  [1768.]
#  [1740.]
#  [1703.]
#  [1703.]
#  [1793.]
#  [1760.]
#  [1779.]
#  [1779.]
#  [1779.]
#  [1808.]
#  [1808.]
#  [1808.]
#  [1808.]
#  [1808.]
#  [1773.]
#  [1773.]
#  [1785.]
#  [1785.]
#  [1785.]
#  [1835.]
#  [1835.]
#  [1863.]
#  [1903.]
#  [2005.]
#  [2103.]
#  [2120.]
#  [2575.]
#  [2575.]
#  [2613.]
#  [2663.]
#  [2625.]
#  [2598.]
#  [2559.]
#  [2546.]
#  [2394.]
#  [2424.]
#  [2380.]
#  [2421.]
#  [2434.]
#  [2443.]
#  [2443.]
#  [2428.]
#  [2428.]
#  [2428.]
#  [2380.]
#  [2380.]
#  [2380.]
#  [2374.]
#  [2410.]
#  [2410.]
#  [2410.]
#  [2361.]
#  [2383.]
#  [2403.]
#  [2318.]
#  [2318.]
#  [2390.]
#  [2405.]
#  [2359.]
#  [2339.]
#  [2339.]
#  [2339.]
#  [2339.]
#  [2379.]
#  [2379.]
#  [2338.]
#  [2338.]
#  [2338.]
#  [2323.]
#  [2235.]
#  [2275.]
#  [2220.]
#  [2244.]
#  [2203.]
#  [2203.]
#  [2248.]
#  [2174.]
#  [2248.]
#  [2268.]
#  [2268.]
#  [2153.]
#  [2133.]
#  [2108.]
#  [2120.]
#  [2120.]
#  [2126.]
#  [2101.]
#  [2170.]
#  [2170.]
#  [2170.]
#  [2149.]
#  [2149.]
#  [2149.]
#  [2149.]
#  [2149.]
#  [2061.]
#  [2061.]
#  [2061.]
#  [2061.]
#  [2061.]
#  [2030.]
#  [2030.]
#  [2030.]
#  [2030.]
#  [2030.]
#  [1985.]
#  [1985.]
#  [1985.]
#  [1985.]
#  [1985.]
#  [1968.]
#  [1968.]
#  [1984.]
#  [1984.]
#  [1984.]
#  [1996.]
#  [1939.]
#  [1996.]
#  [1996.]
#  [1996.]
#  [1979.]
#  [1964.]
#  [1979.]
#  [1979.]
#  [1979.]
#  [1926.]
#  [1926.]
#  [1926.]
#  [1926.]
#  [1926.]
#  [1931.]
#  [1944.]
#  [1958.]
#  [1966.]
#  [1979.]
#  [1964.]
#  [1964.]
#  [1964.]
#  [1979.]
#  [1979.]
#  [2011.]
#  [2011.]
#  [2011.]
#  [2011.]
#  [2059.]
#  [2059.]
#  [2059.]
#  [2059.]
#  [2059.]
#  [1996.]
#  [1996.]
#  [1996.]
#  [1860.]
#  [1880.]
#  [2036.]
#  [2041.]
#  [2096.]
#  [2053.]
#  [2083.]
#  [2175.]
#  [2175.]
#  [2134.]
#  [2156.]
#  [2130.]
#  [2153.]
#  [2161.]
#  [2174.]
#  [2174.]
#  [2174.]
#  [2218.]
#  [2218.]
#  [2259.]
#  [2176.]
#  [2164.]
#  [2164.]
#  [2164.]
#  [2226.]
#  [2226.]
#  [2276.]
#  [2276.]
#  [2298.]
#  [2298.]] (476, 1)

# %%
plt.figure(figsize=(20,10))
plt.plot(validY_test, color = 'blue', label = 'Actual Stock Price')
plt.plot(predicted_price_valid_test, color = 'red', label = 'Predicted Stock Price')
plt.title('Price Prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error 
MSE = mean_squared_error(validY_test, predicted_price_valid_test) 
np.sqrt(MSE)
# Out:
# 199.2274946077702

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(validY_test, predicted_price_valid_test)
# Out:
# 153.1386457170759

# %% [markdown]
# Test Data 평가

# %%
model.evaluate(testX, testY, batch_size=a)
# Out:
# 68/68 [==============================] - 0s 3ms/step - loss: 0.0139 - mae: 0.0806
# [0.013897126540541649, 0.08058271557092667]

# %%
predicted_price_test = model.predict(testX, batch_size=a, verbose=1)
# Out:
# 68/68 [==============================] - 0s 2ms/step

# %%
testY_test = np.delete(testY, np.s_[1:a], axis=1)
predicted_price_test_test = np.delete(predicted_price_test, np.s_[1:a], axis=1)

testY_test = np.reshape(testY_test, (476, 1))
predicted_price_test_test = np.reshape(predicted_price_test_test, (476, 1))
print(testY_test.shape)
print(predicted_price_test_test.shape)

plt.figure(figsize=(20,10))
plt.plot(testY_test, color = 'blue', label = 'Actual Stock Price')
plt.plot(predicted_price_test_test, color = 'red', label = 'Predicted Stock Price')
plt.title('Price Prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# (476, 1)
# (476, 1)

# %%
predicted_price_test_test = np.reshape(predicted_price_test_test, (476, ))
predicted_price_test_test = scaler_target.inverse_transform(predicted_price_test_test.reshape(-1,1))

print(predicted_price_test_test, predicted_price_test_test.shape)

testY_test = scaler_target.inverse_transform(testY_test.reshape(-1,1))

print(testY_test, testY_test.shape)
# Out:
# [[1874.0436]
#  [1928.656 ]
#  [1918.8463]
#  [1908.37  ]
#  [1906.4805]
#  [1966.3472]
#  [1965.5875]
#  [2129.4988]
#  [2167.8633]
#  [2156.524 ]
#  [2150.0195]
#  [2135.431 ]
#  [2167.5212]
#  [2166.7314]
#  [2267.6436]
#  [2283.6262]
#  [2287.939 ]
#  [2288.1455]
#  [2283.508 ]
#  [2277.837 ]
#  [2231.8838]
#  [2249.5073]
#  [2249.2095]
#  [2250.8855]
#  [2247.835 ]
#  [2283.7717]
#  [2308.909 ]
#  [2323.3406]
#  [2339.2708]
#  [2328.3   ]
#  [2224.8337]
#  [2243.6318]
#  [2273.5093]
#  [2284.2725]
#  [2284.0483]
#  [2296.1272]
#  [2305.942 ]
#  [2312.3843]
#  [2318.3015]
#  [2319.2258]
#  [2321.7078]
#  [2327.3894]
#  [2325.774 ]
#  [2326.8193]
#  [2344.9136]
#  [2359.2012]
#  [2373.6277]
#  [2369.4072]
#  [2362.5012]
#  [2343.6992]
#  [2341.6433]
#  [2338.0564]
#  [2340.066 ]
#  [2339.789 ]
#  [2308.6213]
#  [2291.6238]
#  [2283.6775]
#  [2283.3838]
#  [2294.9707]
#  [2281.358 ]
#  [2243.273 ]
#  [2214.213 ]
#  [2224.3447]
#  [2217.7075]
#  [2236.4236]
#  [2240.8486]
#  [2261.558 ]
#  [2396.8687]
#  [2421.3032]
#  [2438.4907]
#  [2491.5237]
#  [2514.8032]
#  [2661.5935]
#  [2697.8857]
#  [2760.013 ]
#  [2742.3215]
#  [2726.3682]
#  [2751.407 ]
#  [2756.7004]
#  [2775.0806]
#  [2755.6992]
#  [2720.373 ]
#  [2726.0688]
#  [2712.6667]
#  [2742.584 ]
#  [2712.187 ]
#  [2698.6414]
#  [2729.9202]
#  [2703.56  ]
#  [2714.429 ]
#  [2757.901 ]
#  [2768.761 ]
#  [2819.0464]
#  [2809.8787]
#  [2794.8154]
#  [2835.4092]
#  [2834.4482]
#  [2805.163 ]
#  [2803.7966]
#  [2864.7598]
#  [2863.8003]
#  [2885.6519]
#  [2851.738 ]
#  [2834.194 ]
#  [2884.214 ]
#  [2885.117 ]
#  [2906.2603]
#  [2873.469 ]
#  [2854.9187]
#  [2899.7786]
#  [2899.3352]
#  [2932.832 ]
#  [2893.287 ]
#  [2879.4268]
#  [2887.6436]
#  [2869.2852]
#  [2867.8816]
#  [2817.437 ]
#  [2788.4949]
#  [2785.9329]
#  [2773.9868]
#  [2802.0483]
#  [2776.3608]
#  [2731.6597]
#  [2660.4355]
#  [2617.7017]
#  [2564.805 ]
#  [2513.0066]
#  [2484.2483]
#  [2417.2566]
#  [2361.2546]
#  [2357.492 ]
#  [2323.053 ]
#  [2309.125 ]
#  [2277.312 ]
#  [2248.5369]
#  [2259.9583]
#  [2254.2808]
#  [2244.09  ]
#  [2179.5146]
#  [2070.9036]
#  [2058.0688]
#  [2009.8763]
#  [2020.2186]
#  [2010.229 ]
#  [2010.8843]
#  [2011.9081]
#  [2013.7609]
#  [1997.9734]
#  [1990.2847]
#  [1993.8524]
#  [2001.6633]
#  [1987.1575]
#  [1965.8947]
#  [1977.1466]
#  [1968.7117]
#  [1972.7439]
#  [1930.1925]
#  [1886.1705]
#  [1890.0393]
#  [1900.9875]
#  [1919.6615]
#  [1881.102 ]
#  [1868.1422]
#  [1875.4106]
#  [1886.9268]
#  [1904.6306]
#  [1887.1577]
#  [1868.3555]
#  [1872.3435]
#  [1877.9622]
#  [1893.8408]
#  [1897.9011]
#  [1884.6881]
#  [1890.6973]
#  [1897.6515]
#  [1901.3267]
#  [1905.193 ]
#  [1899.9083]
#  [1906.7568]
#  [1895.6971]
#  [1898.275 ]
#  [1903.0017]
#  [1897.6016]
#  [1907.027 ]
#  [1918.938 ]
#  [1917.8159]
#  [1923.6232]
#  [1920.7661]
#  [1934.5497]
#  [1948.4668]
#  [1965.6125]
#  [1969.9794]
#  [1955.1486]
#  [1848.442 ]
#  [1851.1449]
#  [1852.5562]
#  [1843.2567]
#  [1833.3955]
#  [1846.4604]
#  [1862.7266]
#  [1882.7842]
#  [1879.7969]
#  [1869.2051]
#  [1868.3562]
#  [1876.4088]
#  [1892.2919]
#  [1897.1814]
#  [1890.583 ]
#  [1878.7864]
#  [1869.7004]
#  [1874.7428]
#  [1862.8983]
#  [1859.9795]
#  [1853.3035]
#  [1861.4648]
#  [1895.5575]
#  [1906.5657]
#  [1911.9955]
#  [1906.6088]
#  [1920.1406]
#  [1948.9637]
#  [1950.0353]
#  [1967.1482]
#  [1856.313 ]
#  [1877.9982]
#  [1913.959 ]
#  [1918.2831]
#  [1919.1129]
#  [1876.6178]
#  [1880.7157]
#  [1902.5667]
#  [1906.3257]
#  [1928.8219]
#  [1947.6687]
#  [1968.5599]
#  [1999.2926]
#  [2005.7726]
#  [2032.1115]
#  [2035.3224]
#  [2053.9878]
#  [2064.229 ]
#  [2051.731 ]
#  [2051.4624]
#  [2014.0441]
#  [2020.4915]
#  [2020.9849]
#  [2014.5365]
#  [1982.5447]
#  [1992.7687]
#  [2009.9622]
#  [2034.0365]
#  [2019.0404]
#  [2024.5818]
#  [2031.3617]
#  [2047.07  ]
#  [2056.4097]
#  [2043.8677]
#  [2056.294 ]
#  [2066.4724]
#  [2079.7202]
#  [2063.2473]
#  [2035.2119]
#  [2028.9122]
#  [2015.6926]
#  [2011.3953]
#  [1995.8495]
#  [1974.711 ]
#  [1932.1976]
#  [1940.0621]
#  [1953.0557]
#  [1965.63  ]
#  [1962.7994]
#  [1971.2952]
#  [1980.923 ]
#  [1995.1782]
#  [2005.2264]
#  [1996.827 ]
#  [2012.3632]
#  [2023.8611]
#  [2035.6923]
#  [2035.3204]
#  [2020.1128]
#  [2025.0076]
#  [1971.4484]
#  [1978.1405]
#  [1999.4777]
#  [2013.3064]
#  [2021.8851]
#  [2036.6372]
#  [2031.6031]
#  [2011.064 ]
#  [2017.5292]
#  [2021.7843]
#  [2029.4989]
#  [2055.607 ]
#  [2048.0027]
#  [2059.5508]
#  [2068.693 ]
#  [2080.1045]
#  [2075.282 ]
#  [2056.0303]
#  [2058.6167]
#  [2062.8933]
#  [2073.212 ]
#  [2069.7146]
#  [2055.1775]
#  [2093.757 ]
#  [2109.7783]
#  [2124.0945]
#  [2086.3452]
#  [2037.7062]
#  [2014.6735]
#  [2006.2473]
#  [2005.8907]
#  [1968.1616]
#  [1923.7477]
#  [1915.0619]
#  [1915.2538]
#  [1923.356 ]
#  [1903.0332]
#  [1874.689 ]
#  [1874.7056]
#  [1867.8911]
#  [1873.3757]
#  [1846.3646]
#  [1813.8927]
#  [1789.054 ]
#  [1771.9751]
#  [1776.7523]
#  [1783.4855]
#  [1798.909 ]
#  [1807.9111]
#  [1796.8965]
#  [1793.8762]
#  [1807.7406]
#  [1823.7471]
#  [1808.424 ]
#  [1785.2834]
#  [1789.4152]
#  [1776.8788]
#  [1780.955 ]
#  [1772.6058]
#  [1752.2616]
#  [1752.2134]
#  [1763.7513]
#  [1755.9928]
#  [1743.8693]
#  [1747.94  ]
#  [1752.841 ]
#  [1742.0873]
#  [1730.1327]
#  [1735.1963]
#  [1742.3977]
#  [1762.2051]
#  [1744.2954]
#  [1721.0676]
#  [1709.5887]
#  [1702.7948]
#  [1711.4764]
#  [1705.8674]
#  [1694.3958]
#  [1707.8323]
#  [1716.7596]
#  [1732.8424]
#  [1733.8699]
#  [1724.4617]
#  [1721.9873]
#  [1721.754 ]
#  [1734.765 ]
#  [1723.7397]
#  [1704.9376]
#  [1728.8031]
#  [1742.5985]
#  [1760.2096]
#  [1735.2894]
#  [1703.605 ]
#  [1707.6881]
#  [1719.1765]
#  [1731.2957]
#  [1728.5746]
#  [1719.8972]
#  [1727.9537]
#  [1736.6029]
#  [1753.7141]
#  [1754.1572]
#  [1739.0242]
#  [1749.4213]
#  [1753.2616]
#  [1767.0757]
#  [1750.3842]
#  [1753.1088]
#  [1754.0648]
#  [1767.2222]
#  [1748.5675]
#  [1726.9308]
#  [1735.146 ]
#  [1740.5743]
#  [1755.52  ]
#  [1742.895 ]
#  [1723.7725]
#  [1717.8071]
#  [1715.0894]
#  [1726.515 ]
#  [1715.528 ]
#  [1700.8053]
#  [1700.3346]
#  [1700.639 ]
#  [1706.1917]
#  [1704.047 ]
#  [1722.1139]
#  [1750.2214]
#  [1808.3336]
#  [1811.8865]
#  [1831.2113]
#  [1844.875 ]
#  [1833.6979]
#  [1869.2046]
#  [1850.0162]
#  [1861.2463]
#  [1871.6471]
#  [1891.9813]
#  [1853.4078]
#  [1923.8818]
#  [1960.9421]
#  [1958.8436]
#  [1936.8643]
#  [1879.9227]
#  [1881.0924]
#  [1915.6987]
#  [1932.7166]
#  [1923.4421]
#  [1977.3419]
#  [1946.2125]
#  [1968.3331]
#  [1942.1409]
#  [1884.2545]
#  [1936.7236]
#  [1901.0559]
#  [1913.6553]
#  [1913.4055]
#  [1934.0107]
#  [1922.2141]
#  [1893.68  ]
#  [1879.4357]
#  [1940.2677]
#  [1949.0024]
#  [1955.0863]
#  [1932.0203]
#  [1955.3677]
#  [1946.3938]
#  [1935.2185]
#  [1951.7351]
#  [1913.9785]
#  [1879.1967]
#  [1869.4072]
#  [1883.873 ]
#  [1873.3843]
#  [1851.6547]
#  [1858.8737]
#  [1852.8824]
#  [1876.34  ]
#  [1835.1478]
#  [1897.1102]
#  [1899.2921]
#  [1899.1362]
#  [1903.786 ]
#  [1892.07  ]
#  [1919.9272]
#  [1895.5623]
#  [1909.0326]
#  [1940.4551]
#  [1920.0834]
#  [1890.5315]
#  [1921.8481]
#  [1912.9872]] (476, 1)
# [[2298.]
#  [2298.]
#  [2298.]
#  [2298.]
#  [2290.]
#  [2311.]
#  [2311.]
#  [2311.]
#  [2316.]
#  [2316.]
#  [2316.]
#  [2316.]
#  [2304.]
#  [2178.]
#  [2193.]
#  [2193.]
#  [2193.]
#  [2193.]
#  [2311.]
#  [2311.]
#  [2311.]
#  [2311.]
#  [2311.]
#  [2311.]
#  [2311.]
#  [2311.]
#  [2311.]
#  [2311.]
#  [2311.]
#  [2311.]
#  [2311.]
#  [2311.]
#  [2311.]
#  [2311.]
#  [2311.]
#  [2311.]
#  [2311.]
#  [2364.]
#  [2364.]
#  [2364.]
#  [2364.]
#  [2364.]
#  [2321.]
#  [2321.]
#  [2321.]
#  [2321.]
#  [2321.]
#  [2221.]
#  [2221.]
#  [2221.]
#  [2221.]
#  [2290.]
#  [2331.]
#  [2300.]
#  [2300.]
#  [2360.]
#  [2360.]
#  [2397.]
#  [2420.]
#  [2469.]
#  [2671.]
#  [2671.]
#  [2607.]
#  [2797.]
#  [2797.]
#  [3091.]
#  [3091.]
#  [3124.]
#  [3124.]
#  [3124.]
#  [3131.]
#  [3176.]
#  [3176.]
#  [3176.]
#  [3176.]
#  [3171.]
#  [3171.]
#  [3171.]
#  [3171.]
#  [3171.]
#  [3200.]
#  [3200.]
#  [3200.]
#  [3221.]
#  [3243.]
#  [3290.]
#  [3317.]
#  [3317.]
#  [3389.]
#  [3386.]
#  [3386.]
#  [3386.]
#  [3443.]
#  [3443.]
#  [3443.]
#  [3443.]
#  [3443.]
#  [3506.]
#  [3506.]
#  [3506.]
#  [3506.]
#  [3506.]
#  [3549.]
#  [3549.]
#  [3549.]
#  [3549.]
#  [3549.]
#  [3523.]
#  [3523.]
#  [3444.]
#  [3451.]
#  [3403.]
#  [3346.]
#  [3346.]
#  [3368.]
#  [3368.]
#  [3228.]
#  [3078.]
#  [3078.]
#  [3117.]
#  [3013.]
#  [2909.]
#  [2673.]
#  [2640.]
#  [2640.]
#  [2559.]
#  [2559.]
#  [2441.]
#  [2441.]
#  [2441.]
#  [2441.]
#  [2417.]
#  [2187.]
#  [2163.]
#  [2163.]
#  [2163.]
#  [2126.]
#  [2126.]
#  [2076.]
#  [2076.]
#  [2013.]
#  [2013.]
#  [2076.]
#  [2044.]
#  [2030.]
#  [1914.]
#  [2000.]
#  [2000.]
#  [2000.]
#  [1950.]
#  [1851.]
#  [1853.]
#  [1933.]
#  [1933.]
#  [1933.]
#  [1877.]
#  [1877.]
#  [1877.]
#  [1877.]
#  [1877.]
#  [1843.]
#  [1843.]
#  [1843.]
#  [1843.]
#  [1843.]
#  [1850.]
#  [1850.]
#  [1850.]
#  [1829.]
#  [1829.]
#  [1877.]
#  [1877.]
#  [1867.]
#  [1829.]
#  [1867.]
#  [1889.]
#  [1889.]
#  [1889.]
#  [1889.]
#  [1889.]
#  [1946.]
#  [1946.]
#  [1946.]
#  [1946.]
#  [1946.]
#  [1960.]
#  [1921.]
#  [1874.]
#  [1864.]
#  [1864.]
#  [1807.]
#  [1807.]
#  [1854.]
#  [1854.]
#  [1854.]
#  [1821.]
#  [1821.]
#  [1821.]
#  [1821.]
#  [1821.]
#  [1860.]
#  [1850.]
#  [1731.]
#  [1741.]
#  [1741.]
#  [1766.]
#  [1846.]
#  [1846.]
#  [1846.]
#  [1934.]
#  [1934.]
#  [1934.]
#  [1934.]
#  [1934.]
#  [2006.]
#  [1996.]
#  [1996.]
#  [1996.]
#  [2029.]
#  [2029.]
#  [2029.]
#  [2029.]
#  [2003.]
#  [2003.]
#  [2003.]
#  [2003.]
#  [2003.]
#  [2003.]
#  [2003.]
#  [2061.]
#  [2061.]
#  [2061.]
#  [2061.]
#  [2074.]
#  [2074.]
#  [2074.]
#  [2083.]
#  [2083.]
#  [2083.]
#  [2083.]
#  [2069.]
#  [1964.]
#  [2079.]
#  [2079.]
#  [2104.]
#  [2026.]
#  [2104.]
#  [2104.]
#  [2104.]
#  [2104.]
#  [2104.]
#  [2104.]
#  [2104.]
#  [2104.]
#  [2043.]
#  [2043.]
#  [2021.]
#  [1939.]
#  [1939.]
#  [1977.]
#  [1977.]
#  [1977.]
#  [1977.]
#  [1977.]
#  [1979.]
#  [1979.]
#  [1979.]
#  [1979.]
#  [1979.]
#  [2023.]
#  [2023.]
#  [2023.]
#  [2023.]
#  [2023.]
#  [2031.]
#  [2031.]
#  [2031.]
#  [2031.]
#  [2031.]
#  [2041.]
#  [2041.]
#  [2041.]
#  [2041.]
#  [2030.]
#  [2030.]
#  [2030.]
#  [2030.]
#  [2030.]
#  [2124.]
#  [2046.]
#  [2093.]
#  [2093.]
#  [2093.]
#  [2093.]
#  [2093.]
#  [2079.]
#  [2079.]
#  [2079.]
#  [2053.]
#  [2053.]
#  [2053.]
#  [2053.]
#  [2053.]
#  [2079.]
#  [2079.]
#  [2063.]
#  [2047.]
#  [2047.]
#  [2007.]
#  [2007.]
#  [2050.]
#  [2050.]
#  [2050.]
#  [2050.]
#  [2050.]
#  [2030.]
#  [2007.]
#  [2007.]
#  [1967.]
#  [1920.]
#  [1839.]
#  [1901.]
#  [1933.]
#  [1933.]
#  [1933.]
#  [2033.]
#  [2033.]
#  [1944.]
#  [2033.]
#  [2033.]
#  [1993.]
#  [1993.]
#  [1993.]
#  [1851.]
#  [1914.]
#  [1966.]
#  [1926.]
#  [1926.]
#  [1870.]
#  [1950.]
#  [1950.]
#  [1950.]
#  [1950.]
#  [1871.]
#  [1871.]
#  [1871.]
#  [1871.]
#  [1911.]
#  [1807.]
#  [1744.]
#  [1751.]
#  [1751.]
#  [1714.]
#  [1849.]
#  [1849.]
#  [1863.]
#  [1863.]
#  [1849.]
#  [1917.]
#  [1917.]
#  [1840.]
#  [1847.]
#  [1847.]
#  [1846.]
#  [1823.]
#  [1963.]
#  [1963.]
#  [1926.]
#  [1743.]
#  [1743.]
#  [1870.]
#  [1911.]
#  [1808.]
#  [1903.]
#  [1903.]
#  [1923.]
#  [1917.]
#  [1917.]
#  [1957.]
#  [1957.]
#  [1943.]
#  [1934.]
#  [1934.]
#  [1963.]
#  [1943.]
#  [1943.]
#  [1957.]
#  [1884.]
#  [1884.]
#  [1921.]
#  [1921.]
#  [1921.]
#  [1881.]
#  [1881.]
#  [1827.]
#  [1827.]
#  [1827.]
#  [1817.]
#  [1827.]
#  [1817.]
#  [1817.]
#  [1871.]
#  [1871.]
#  [1900.]
#  [1941.]
#  [2174.]
#  [2164.]
#  [2173.]
#  [2140.]
#  [2044.]
#  [2243.]
#  [2216.]
#  [2214.]
#  [2214.]
#  [2273.]
#  [2373.]
#  [2487.]
#  [2487.]
#  [2487.]
#  [2517.]
#  [2529.]
#  [2371.]
#  [2436.]
#  [2543.]
#  [2543.]
#  [2611.]
#  [2586.]
#  [2611.]
#  [2456.]
#  [2456.]
#  [2423.]
#  [2423.]
#  [2423.]
#  [2423.]
#  [2537.]
#  [2434.]
#  [2434.]
#  [2296.]
#  [2534.]
#  [2534.]
#  [2467.]
#  [2486.]
#  [2557.]
#  [2557.]
#  [2557.]
#  [2467.]
#  [2467.]
#  [2467.]
#  [2467.]
#  [2467.]
#  [2423.]
#  [2423.]
#  [2426.]
#  [2426.]
#  [2466.]
#  [2466.]
#  [2466.]
#  [2496.]
#  [2496.]
#  [2466.]
#  [2513.]
#  [2513.]
#  [2513.]
#  [2513.]
#  [2541.]
#  [2541.]
#  [2541.]
#  [2541.]
#  [2541.]
#  [2541.]
#  [2496.]
#  [2496.]
#  [2570.]
#  [2570.]
#  [2570.]
#  [2570.]] (476, 1)

# %%
from sklearn.metrics import mean_squared_error 
MSE = mean_squared_error(testY_test, predicted_price_test_test) 
np.sqrt(MSE)
# Out:
# 316.5716398048425

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(testY_test, predicted_price_test_test)
# Out:
# 219.46718591000854

# %% [markdown]
# 예측방법

# %%
minX1 = np.array(dataX[0:7])
minX2 = np.array(dataX[0:8])
minX3 = np.array(dataX[0:2380])
minX4 = np.array(dataX[0:train_size])

# %%
predicted_price_min1 = model.predict(minX1, batch_size=a, verbose=1)
predicted_price_min2 = model.predict(minX2, batch_size=a, verbose=1) 
predicted_price_min3 = model.predict(minX3, batch_size=a, verbose=1)
predicted_price_min4 = model.predict(minX4, batch_size=a, verbose=1)
# Out:
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 1s 7ms/step
# 340/340 [==============================] - 1s 3ms/step
# 204/204 [==============================] - 1s 2ms/step

# %%
predicted_price_min1[0]
# Out:
# array([[0.24257636],
#        [0.2127758 ],
#        [0.19604716],
#        [0.19285223],
#        [0.17866859],
#        [0.17391121],
#        [0.19723114]], dtype=float32)

# %%
predicted_price_min2[0]
# Out:
# array([[0.19398737],
#        [0.19696312],
#        [0.19743334],
#        [0.20653376],
#        [0.19991168],
#        [0.20356661],
#        [0.23556557]], dtype=float32)

# %%
predicted_price_min3[0]
# Out:
# array([[0.27939177],
#        [0.27981317],
#        [0.27133626],
#        [0.27306294],
#        [0.26727262],
#        [0.27159923],
#        [0.2972232 ]], dtype=float32)

# %%
scaler_target.inverse_transform(predicted_price_min4[0].reshape(-1,1))
# Out:
# array([[1837.2285],
#        [1756.8563],
#        [1711.7391],
#        [1703.1224],
#        [1664.8691],
#        [1652.0386],
#        [1714.9324]], dtype=float32)
