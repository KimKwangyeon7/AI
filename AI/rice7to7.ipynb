# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import random
import os

# %%
def my_seed_everywhere(seed: int = 42):
    random.seed(seed) # random
    np.random.seed(seed) # np
    os.environ["PYTHONHASHSEED"] = str(seed) # os
    tf.random.set_seed(seed) # tensorflow

my_seed = 42
my_seed_everywhere(my_seed)

# %%
df = pd.read_csv('/content/sample_data/rice_final.csv', index_col=0)
df = df.dropna(axis=0)
df = df.reset_index(drop=True)
df['Date'] = pd.to_datetime(df['Date'])
df['DayOfWeek'] = df['Date'].dt.dayofweek

# %%
df = df.drop(['Temp'],axis=1)
df = df.drop(['Oil'],axis=1)
df = df.drop(['Sup'],axis=1)
df = df.drop(['Avg_Price'], axis=1)
df = df.drop(['Real_Price'], axis = 1)

df['DayOfWeek'] = df['DayOfWeek'].astype('category')
df = pd.get_dummies(df, columns =['DayOfWeek'], prefix='W', drop_first=True)

df.tail()
# Out:
#            Date  Rain  Wind  sobimul  nongmul    Price  Produced  W_1  W_2  \
# 2390 2022-09-26   0.0   1.7      2.5      8.7  45957.0   5211037    0    0
# 2391 2022-09-27   0.0   1.6      2.5      8.7  45957.0   5211037    1    0
# 2392 2022-09-28   0.0   1.8      2.5      8.7  45586.0   5211037    0    1
# 2393 2022-09-29   0.0   1.4      2.5      8.7  45375.0   5211037    0    0
# 2394 2022-09-30   0.0   1.6      2.5      8.7  45375.0   5211037    0    0
#
#       W_3  W_4
# 2390    0    0
# 2391    0    0
# 2392    0    0
# 2393    1    0
# 2394    0    1

# %%
from sklearn.preprocessing import MinMaxScaler
input_indicator = df.loc[:,['Rain', 'Wind', 'sobimul', 'nongmul', 'Produced', 'W_1', 'W_2', 'W_3', 'W_4']]
target_indicator = df.loc[:,['Price']].values[:]
scaler_input = MinMaxScaler()
scaler_target = MinMaxScaler()
scaled_input_indicator = scaler_input.fit_transform(input_indicator)
scaled_target_indicator = scaler_target.fit_transform(target_indicator) # 가격 관련 지표에 스케일링

x = np.concatenate((scaled_target_indicator, scaled_input_indicator), axis=1)
y = x[:, [0]]

print(x)
print(y.shape)
# Out:
# [[0.47995674 0.         0.61403509 ... 1.         0.         0.        ]
#  [0.47995674 0.         0.36842105 ... 0.         1.         0.        ]
#  [0.47995674 0.         0.19298246 ... 0.         0.         1.        ]
#  ...
#  [0.4558237  0.         0.19298246 ... 1.         0.         0.        ]
#  [0.44869195 0.         0.12280702 ... 0.         1.         0.        ]
#  [0.44869195 0.         0.15789474 ... 0.         0.         1.        ]]
# (2395, 1)

# %%
# 21일치의 input으로 8일치의 output을 생산(API 문제상 당일날 input은 활용 불가능할 것으로 예상됨)
# 추후 train, validation, train set를 6년, 2년, 2년으로 나눠볼까 생각중, 지금은 many_to_many 코드 구현을 목표로 구현하지 않음
seq_length = 7
predict_day = 7
dataX = [] 
dataY = [] 
for i in range(0, int(len(y) - seq_length - predict_day)):
    _x = x[i : i + seq_length]
    _y = y[i + predict_day : i + seq_length + predict_day] 
    dataX.append(_x) 
    dataY.append(_y) 
print(len(dataX))
print(len(dataY))
# Out:
# 2381
# 2381

# %%
# Train Set 생성, 추후 Validation, Test도 여기에다가 추가 예상됨, 또한 21의 배수로 설정해야 batch에서 오류가 발생하지 않음
train_size = 1428
validation_size = 476
test_size = 476

trainX = np.array(dataX[0:train_size])
trainY = np.array(dataY[0:train_size])
validX = np.array(dataX[train_size:train_size+validation_size])
validY = np.array(dataY[train_size:train_size+validation_size])
testX = np.array(dataX[train_size+validation_size:train_size+validation_size+test_size])
testY = np.array(dataY[train_size+validation_size:train_size+validation_size+test_size])

print(trainX.shape)
print(trainY.shape)
print(validX.shape)
print(validY.shape)
print(testX.shape)
print(testY.shape)
# Out:
# (1428, 7, 10)
# (1428, 7, 1)
# (476, 7, 10)
# (476, 7, 1)
# (476, 7, 10)
# (476, 7, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, Activation
from tensorflow import keras

# %%
class CustomHistory(keras.callbacks.Callback):
    def init(self):
        self.train_loss = []
        self.val_loss = []
        
    def on_epoch_end(self, batch, logs={}):
        self.train_loss.append(logs.get('loss'))
        self.val_loss.append(logs.get('val_loss'))

# %%
input_columns = 10 # 데이터 셋의 '열' 개수 (dataX) / dataset's columns (dataX)

model = Sequential()
model.add(LSTM(16, batch_input_shape=(7, 7, input_columns), return_sequences=True, stateful=True, dropout=0.01))
model.add(LSTM(16, return_sequences=True, stateful=True, dropout=0.01))
model.add(Dense(1))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (7, 7, 16)                1728
#
#  lstm_3 (LSTM)               (7, 7, 16)                2112
#
#  dense_1 (Dense)             (7, 7, 1)                 17
#
# =================================================================
# Total params: 3,857
# Trainable params: 3,857
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping
checkpoint_cb = keras.callbacks.ModelCheckpoint('best-model-rice.h5', save_best_only=True)
early_stopping_cb = keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=5, restore_best_weights=True)

# %%
keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %%
custom_hist = CustomHistory()
custom_hist.init()

# %%
for epoch_idx in range(100):
  print('epochs:' + str(epoch_idx))
  hist = model.fit(trainX, trainY, validation_data=(validX, validY), epochs=1, batch_size=7, verbose=2, shuffle=False, callbacks=[checkpoint_cb, custom_hist, early_stopping_cb])
  model.reset_states()
# Out:
# epochs:0
# 204/204 - 4s - loss: 0.0061 - mae: 0.0532 - val_loss: 0.0273 - val_mae: 0.1215 - 4s/epoch - 20ms/step
# epochs:1
# 204/204 - 1s - loss: 0.0079 - mae: 0.0611 - val_loss: 0.0252 - val_mae: 0.1361 - 937ms/epoch - 5ms/step
# epochs:2
# 204/204 - 1s - loss: 0.0072 - mae: 0.0613 - val_loss: 0.0216 - val_mae: 0.1137 - 951ms/epoch - 5ms/step
# epochs:3
# 204/204 - 1s - loss: 0.0073 - mae: 0.0625 - val_loss: 0.0192 - val_mae: 0.1142 - 946ms/epoch - 5ms/step
# epochs:4
# 204/204 - 1s - loss: 0.0091 - mae: 0.0724 - val_loss: 0.0196 - val_mae: 0.1124 - 913ms/epoch - 4ms/step
# epochs:5
# 204/204 - 1s - loss: 0.0084 - mae: 0.0699 - val_loss: 0.0264 - val_mae: 0.1371 - 1s/epoch - 5ms/step
# epochs:6
# 204/204 - 1s - loss: 0.0079 - mae: 0.0689 - val_loss: 0.0319 - val_mae: 0.1460 - 926ms/epoch - 5ms/step
# epochs:7
# 204/204 - 1s - loss: 0.0070 - mae: 0.0645 - val_loss: 0.0383 - val_mae: 0.1577 - 935ms/epoch - 5ms/step
# epochs:8
# 204/204 - 1s - loss: 0.0062 - mae: 0.0601 - val_loss: 0.0475 - val_mae: 0.1771 - 929ms/epoch - 5ms/step
# epochs:9
# 204/204 - 1s - loss: 0.0059 - mae: 0.0577 - val_loss: 0.0524 - val_mae: 0.1873 - 967ms/epoch - 5ms/step
# epochs:10
# 204/204 - 1s - loss: 0.0057 - mae: 0.0562 - val_loss: 0.0547 - val_mae: 0.1929 - 937ms/epoch - 5ms/step
# epochs:11
# 204/204 - 1s - loss: 0.0056 - mae: 0.0563 - val_loss: 0.0519 - val_mae: 0.1884 - 1s/epoch - 5ms/step
# epochs:12
# 204/204 - 1s - loss: 0.0053 - mae: 0.0554 - val_loss: 0.0492 - val_mae: 0.1859 - 959ms/epoch - 5ms/step
# epochs:13
# 204/204 - 1s - loss: 0.0051 - mae: 0.0548 - val_loss: 0.0453 - val_mae: 0.1831 - 1s/epoch - 5ms/step
# epochs:14
# 204/204 - 1s - loss: 0.0048 - mae: 0.0529 - val_loss: 0.0420 - val_mae: 0.1795 - 935ms/epoch - 5ms/step
# epochs:15
# 204/204 - 1s - loss: 0.0045 - mae: 0.0515 - val_loss: 0.0389 - val_mae: 0.1758 - 938ms/epoch - 5ms/step
# epochs:16
# 204/204 - 1s - loss: 0.0042 - mae: 0.0490 - val_loss: 0.0354 - val_mae: 0.1684 - 934ms/epoch - 5ms/step
# epochs:17
# 204/204 - 1s - loss: 0.0039 - mae: 0.0471 - val_loss: 0.0333 - val_mae: 0.1648 - 1s/epoch - 5ms/step
# epochs:18
# 204/204 - 1s - loss: 0.0038 - mae: 0.0457 - val_loss: 0.0311 - val_mae: 0.1595 - 934ms/epoch - 5ms/step
# epochs:19
# 204/204 - 1s - loss: 0.0035 - mae: 0.0441 - val_loss: 0.0289 - val_mae: 0.1511 - 931ms/epoch - 5ms/step
# epochs:20
# 204/204 - 1s - loss: 0.0034 - mae: 0.0431 - val_loss: 0.0264 - val_mae: 0.1418 - 927ms/epoch - 5ms/step
# epochs:21
# 204/204 - 1s - loss: 0.0031 - mae: 0.0412 - val_loss: 0.0254 - val_mae: 0.1369 - 925ms/epoch - 5ms/step
# epochs:22
# 204/204 - 1s - loss: 0.0030 - mae: 0.0402 - val_loss: 0.0231 - val_mae: 0.1280 - 1s/epoch - 5ms/step
# epochs:23
# 204/204 - 1s - loss: 0.0028 - mae: 0.0386 - val_loss: 0.0224 - val_mae: 0.1243 - 913ms/epoch - 4ms/step
# epochs:24
# 204/204 - 1s - loss: 0.0025 - mae: 0.0366 - val_loss: 0.0235 - val_mae: 0.1308 - 1s/epoch - 5ms/step
# epochs:25
# 204/204 - 1s - loss: 0.0023 - mae: 0.0343 - val_loss: 0.0224 - val_mae: 0.1201 - 1s/epoch - 5ms/step
# epochs:26
# 204/204 - 1s - loss: 0.0021 - mae: 0.0336 - val_loss: 0.0464 - val_mae: 0.2001 - 922ms/epoch - 5ms/step
# epochs:27
# 204/204 - 1s - loss: 0.0020 - mae: 0.0326 - val_loss: 0.0189 - val_mae: 0.1249 - 1s/epoch - 5ms/step
# epochs:28
# 204/204 - 1s - loss: 0.0019 - mae: 0.0308 - val_loss: 0.0511 - val_mae: 0.2179 - 1s/epoch - 6ms/step
# epochs:29
# 204/204 - 1s - loss: 0.0019 - mae: 0.0319 - val_loss: 0.0162 - val_mae: 0.1166 - 1s/epoch - 7ms/step
# epochs:30
# 204/204 - 1s - loss: 0.0018 - mae: 0.0302 - val_loss: 0.0529 - val_mae: 0.2214 - 933ms/epoch - 5ms/step
# epochs:31
# 204/204 - 1s - loss: 0.0017 - mae: 0.0308 - val_loss: 0.0154 - val_mae: 0.1114 - 945ms/epoch - 5ms/step
# epochs:32
# 204/204 - 1s - loss: 0.0018 - mae: 0.0296 - val_loss: 0.0522 - val_mae: 0.2206 - 1s/epoch - 5ms/step
# epochs:33
# 204/204 - 1s - loss: 0.0017 - mae: 0.0306 - val_loss: 0.0141 - val_mae: 0.1024 - 1s/epoch - 5ms/step
# epochs:34
# 204/204 - 1s - loss: 0.0017 - mae: 0.0293 - val_loss: 0.0481 - val_mae: 0.2095 - 945ms/epoch - 5ms/step
# epochs:35
# 204/204 - 1s - loss: 0.0016 - mae: 0.0292 - val_loss: 0.0170 - val_mae: 0.0982 - 938ms/epoch - 5ms/step
# epochs:36
# 204/204 - 1s - loss: 0.0015 - mae: 0.0283 - val_loss: 0.0446 - val_mae: 0.2026 - 925ms/epoch - 5ms/step
# epochs:37
# 204/204 - 1s - loss: 0.0015 - mae: 0.0289 - val_loss: 0.0137 - val_mae: 0.1040 - 1s/epoch - 5ms/step
# epochs:38
# 204/204 - 1s - loss: 0.0016 - mae: 0.0286 - val_loss: 0.0459 - val_mae: 0.2047 - 940ms/epoch - 5ms/step
# epochs:39
# 204/204 - 1s - loss: 0.0015 - mae: 0.0289 - val_loss: 0.0170 - val_mae: 0.1024 - 936ms/epoch - 5ms/step
# epochs:40
# 204/204 - 1s - loss: 0.0015 - mae: 0.0279 - val_loss: 0.0363 - val_mae: 0.1777 - 925ms/epoch - 5ms/step
# epochs:41
# 204/204 - 1s - loss: 0.0014 - mae: 0.0278 - val_loss: 0.0196 - val_mae: 0.1042 - 1s/epoch - 6ms/step
# epochs:42
# 204/204 - 1s - loss: 0.0015 - mae: 0.0278 - val_loss: 0.0325 - val_mae: 0.1611 - 1s/epoch - 7ms/step
# epochs:43
# 204/204 - 1s - loss: 0.0014 - mae: 0.0275 - val_loss: 0.0198 - val_mae: 0.1052 - 1s/epoch - 5ms/step
# epochs:44
# 204/204 - 1s - loss: 0.0016 - mae: 0.0290 - val_loss: 0.0405 - val_mae: 0.1894 - 945ms/epoch - 5ms/step
# epochs:45
# 204/204 - 1s - loss: 0.0014 - mae: 0.0283 - val_loss: 0.0314 - val_mae: 0.1590 - 943ms/epoch - 5ms/step
# epochs:46
# 204/204 - 1s - loss: 0.0013 - mae: 0.0268 - val_loss: 0.0133 - val_mae: 0.1026 - 956ms/epoch - 5ms/step
# epochs:47
# 204/204 - 1s - loss: 0.0014 - mae: 0.0268 - val_loss: 0.0298 - val_mae: 0.1541 - 931ms/epoch - 5ms/step
# epochs:48
# 204/204 - 1s - loss: 0.0014 - mae: 0.0276 - val_loss: 0.0184 - val_mae: 0.1064 - 935ms/epoch - 5ms/step
# epochs:49
# 204/204 - 1s - loss: 0.0013 - mae: 0.0262 - val_loss: 0.0173 - val_mae: 0.0967 - 927ms/epoch - 5ms/step
# epochs:50
# 204/204 - 1s - loss: 0.0017 - mae: 0.0288 - val_loss: 0.0407 - val_mae: 0.1913 - 958ms/epoch - 5ms/step
# epochs:51
# 204/204 - 1s - loss: 0.0014 - mae: 0.0275 - val_loss: 0.0234 - val_mae: 0.1199 - 942ms/epoch - 5ms/step
# epochs:52
# 204/204 - 1s - loss: 0.0013 - mae: 0.0262 - val_loss: 0.0129 - val_mae: 0.0986 - 965ms/epoch - 5ms/step
# epochs:53
# 204/204 - 1s - loss: 0.0014 - mae: 0.0263 - val_loss: 0.0260 - val_mae: 0.1360 - 925ms/epoch - 5ms/step
# epochs:54
# 204/204 - 1s - loss: 0.0013 - mae: 0.0265 - val_loss: 0.0199 - val_mae: 0.1041 - 936ms/epoch - 5ms/step
# epochs:55
# 204/204 - 1s - loss: 0.0013 - mae: 0.0268 - val_loss: 0.0108 - val_mae: 0.0927 - 962ms/epoch - 5ms/step
# epochs:56
# 204/204 - 1s - loss: 0.0014 - mae: 0.0277 - val_loss: 0.0260 - val_mae: 0.1323 - 935ms/epoch - 5ms/step
# epochs:57
# 204/204 - 1s - loss: 0.0013 - mae: 0.0264 - val_loss: 0.0154 - val_mae: 0.1055 - 1s/epoch - 5ms/step
# epochs:58
# 204/204 - 1s - loss: 0.0013 - mae: 0.0259 - val_loss: 0.0185 - val_mae: 0.0956 - 1s/epoch - 5ms/step
# epochs:59
# 204/204 - 1s - loss: 0.0012 - mae: 0.0255 - val_loss: 0.0132 - val_mae: 0.0906 - 1s/epoch - 5ms/step
# epochs:60
# 204/204 - 1s - loss: 0.0011 - mae: 0.0245 - val_loss: 0.0131 - val_mae: 0.0792 - 935ms/epoch - 5ms/step
# epochs:61
# 204/204 - 1s - loss: 0.0012 - mae: 0.0252 - val_loss: 0.0229 - val_mae: 0.1219 - 967ms/epoch - 5ms/step
# epochs:62
# 204/204 - 1s - loss: 0.0013 - mae: 0.0268 - val_loss: 0.0099 - val_mae: 0.0918 - 949ms/epoch - 5ms/step
# epochs:63
# 204/204 - 1s - loss: 0.0014 - mae: 0.0272 - val_loss: 0.0162 - val_mae: 0.0907 - 925ms/epoch - 5ms/step
# epochs:64
# 204/204 - 1s - loss: 0.0013 - mae: 0.0268 - val_loss: 0.0341 - val_mae: 0.1733 - 955ms/epoch - 5ms/step
# epochs:65
# 204/204 - 1s - loss: 0.0014 - mae: 0.0276 - val_loss: 0.0089 - val_mae: 0.0876 - 1s/epoch - 5ms/step
# epochs:66
# 204/204 - 1s - loss: 0.0014 - mae: 0.0279 - val_loss: 0.0114 - val_mae: 0.0770 - 1s/epoch - 5ms/step
# epochs:67
# 204/204 - 1s - loss: 0.0013 - mae: 0.0259 - val_loss: 0.0256 - val_mae: 0.1325 - 971ms/epoch - 5ms/step
# epochs:68
# 204/204 - 1s - loss: 0.0012 - mae: 0.0265 - val_loss: 0.0116 - val_mae: 0.0909 - 1s/epoch - 5ms/step
# epochs:69
# 204/204 - 1s - loss: 0.0011 - mae: 0.0232 - val_loss: 0.0133 - val_mae: 0.0785 - 1s/epoch - 5ms/step
# epochs:70
# 204/204 - 1s - loss: 0.0013 - mae: 0.0254 - val_loss: 0.0384 - val_mae: 0.1881 - 930ms/epoch - 5ms/step
# epochs:71
# 204/204 - 1s - loss: 0.0013 - mae: 0.0277 - val_loss: 0.0094 - val_mae: 0.0912 - 1s/epoch - 5ms/step
# epochs:72
# 204/204 - 1s - loss: 0.0012 - mae: 0.0248 - val_loss: 0.0191 - val_mae: 0.1073 - 1s/epoch - 5ms/step
# epochs:73
# 204/204 - 1s - loss: 0.0011 - mae: 0.0248 - val_loss: 0.0194 - val_mae: 0.1106 - 928ms/epoch - 5ms/step
# epochs:74
# 204/204 - 1s - loss: 0.0011 - mae: 0.0250 - val_loss: 0.0088 - val_mae: 0.0875 - 1s/epoch - 5ms/step
# epochs:75
# 204/204 - 1s - loss: 0.0013 - mae: 0.0259 - val_loss: 0.0155 - val_mae: 0.0898 - 1s/epoch - 5ms/step
# epochs:76
# 204/204 - 1s - loss: 0.0025 - mae: 0.0312 - val_loss: 0.0316 - val_mae: 0.1713 - 1s/epoch - 5ms/step
# epochs:77
# 204/204 - 1s - loss: 0.0013 - mae: 0.0265 - val_loss: 0.0146 - val_mae: 0.0960 - 927ms/epoch - 5ms/step
# epochs:78
# 204/204 - 1s - loss: 0.0016 - mae: 0.0274 - val_loss: 0.0170 - val_mae: 0.1083 - 948ms/epoch - 5ms/step
# epochs:79
# 204/204 - 1s - loss: 0.0014 - mae: 0.0259 - val_loss: 0.0090 - val_mae: 0.0666 - 936ms/epoch - 5ms/step
# epochs:80
# 204/204 - 1s - loss: 0.0017 - mae: 0.0300 - val_loss: 0.0101 - val_mae: 0.0691 - 1s/epoch - 5ms/step
# epochs:81
# 204/204 - 1s - loss: 0.0024 - mae: 0.0329 - val_loss: 0.0215 - val_mae: 0.1349 - 933ms/epoch - 5ms/step
# epochs:82
# 204/204 - 1s - loss: 0.0014 - mae: 0.0265 - val_loss: 0.0148 - val_mae: 0.1029 - 926ms/epoch - 5ms/step
# epochs:83
# 204/204 - 1s - loss: 0.0014 - mae: 0.0259 - val_loss: 0.0131 - val_mae: 0.0882 - 938ms/epoch - 5ms/step
# epochs:84
# 204/204 - 1s - loss: 0.0012 - mae: 0.0249 - val_loss: 0.0101 - val_mae: 0.0744 - 953ms/epoch - 5ms/step
# epochs:85
# 204/204 - 1s - loss: 0.0012 - mae: 0.0247 - val_loss: 0.0073 - val_mae: 0.0630 - 995ms/epoch - 5ms/step
# epochs:86
# 204/204 - 1s - loss: 0.0012 - mae: 0.0252 - val_loss: 0.0068 - val_mae: 0.0598 - 991ms/epoch - 5ms/step
# epochs:87
# 204/204 - 1s - loss: 0.0014 - mae: 0.0265 - val_loss: 0.0061 - val_mae: 0.0576 - 967ms/epoch - 5ms/step
# epochs:88
# 204/204 - 1s - loss: 0.0015 - mae: 0.0269 - val_loss: 0.0060 - val_mae: 0.0573 - 960ms/epoch - 5ms/step
# epochs:89
# 204/204 - 1s - loss: 0.0013 - mae: 0.0252 - val_loss: 0.0057 - val_mae: 0.0558 - 1s/epoch - 5ms/step
# epochs:90
# 204/204 - 1s - loss: 0.0013 - mae: 0.0260 - val_loss: 0.0059 - val_mae: 0.0577 - 951ms/epoch - 5ms/step
# epochs:91
# 204/204 - 1s - loss: 0.0016 - mae: 0.0278 - val_loss: 0.0088 - val_mae: 0.0781 - 1s/epoch - 6ms/step
# epochs:92
# 204/204 - 1s - loss: 0.0012 - mae: 0.0248 - val_loss: 0.0046 - val_mae: 0.0515 - 975ms/epoch - 5ms/step
# epochs:93
# 204/204 - 1s - loss: 0.0011 - mae: 0.0240 - val_loss: 0.0048 - val_mae: 0.0517 - 1s/epoch - 7ms/step
# epochs:94
# 204/204 - 2s - loss: 0.0015 - mae: 0.0277 - val_loss: 0.0085 - val_mae: 0.0763 - 2s/epoch - 8ms/step
# epochs:95
# 204/204 - 1s - loss: 0.0014 - mae: 0.0265 - val_loss: 0.0094 - val_mae: 0.0818 - 1s/epoch - 5ms/step
# epochs:96
# 204/204 - 1s - loss: 9.6723e-04 - mae: 0.0228 - val_loss: 0.0062 - val_mae: 0.0637 - 950ms/epoch - 5ms/step
# epochs:97
# 204/204 - 1s - loss: 9.2740e-04 - mae: 0.0221 - val_loss: 0.0033 - val_mae: 0.0439 - 950ms/epoch - 5ms/step
# epochs:98
# 204/204 - 1s - loss: 8.3521e-04 - mae: 0.0208 - val_loss: 0.0033 - val_mae: 0.0427 - 955ms/epoch - 5ms/step
# epochs:99
# 204/204 - 1s - loss: 0.0010 - mae: 0.0230 - val_loss: 0.0038 - val_mae: 0.0462 - 948ms/epoch - 5ms/step

# %%
a = 7

# %%
model.evaluate(trainX, trainY, batch_size = a)
# Out:
# 204/204 [==============================] - 1s 3ms/step - loss: 0.0036 - mae: 0.0517
# [0.003587626852095127, 0.051719535142183304]

# %%
print(custom_hist.train_loss)
# Out:
# [0.006081627681851387, 0.007855520583689213, 0.007230132818222046, 0.007308467291295528, 0.009099148213863373, 0.00836909655481577, 0.007922456599771976, 0.006993922404944897, 0.00620455713942647, 0.005906556732952595, 0.00565732829272747, 0.005553280469030142, 0.005279371980577707, 0.005120118148624897, 0.004799847025424242, 0.004527769982814789, 0.004167069680988789, 0.00389190879650414, 0.003755147336050868, 0.00351265468634665, 0.0034033996053040028, 0.003115946426987648, 0.003026262391358614, 0.002801780588924885, 0.002531156875193119, 0.002273417077958584, 0.0021240601781755686, 0.001960709225386381, 0.001923720701597631, 0.0018725879490375519, 0.0018234287854284048, 0.001745376968756318, 0.00175935635343194, 0.001693932106718421, 0.0017273899866268039, 0.001553934533149004, 0.0015069834189489484, 0.0015149882528930902, 0.0016249942127615213, 0.0015117238508537412, 0.0014950080076232553, 0.00141735072247684, 0.0014552169013768435, 0.0014126173919066787, 0.0016278947005048394, 0.0014465440763160586, 0.0013041625497862697, 0.0014143340522423387, 0.001399617874994874, 0.0013273836812004447, 0.0016503315418958664, 0.0013843177584931254, 0.0012712973402813077, 0.0013568405993282795, 0.0012968466617166996, 0.0013151912717148662, 0.0014210939407348633, 0.001294718706049025, 0.0012594956206157804, 0.0011814406607300043, 0.0011415828485041857, 0.001184513559564948, 0.0012731861788779497, 0.0013596753124147654, 0.0013228912139311433, 0.0013796098064631224, 0.0014292586129158735, 0.0012907389318570495, 0.0012360223336145282, 0.0010539714712649584, 0.0012608407996594906, 0.0013239027466624975, 0.001194474403746426, 0.0011440837988629937, 0.0011321573983877897, 0.00131807045545429, 0.002527073724195361, 0.0013452433049678802, 0.0015839050756767392, 0.0013625526335090399, 0.001739788567647338, 0.0024402388371527195, 0.0013587316498160362, 0.001354442909359932, 0.0012243307428434491, 0.0011757775209844112, 0.0012056425912305713, 0.0014185529435053468, 0.0014553340151906013, 0.0012510906672105193, 0.0012993084965273738, 0.0015816433588042855, 0.0012152544222772121, 0.0011012440081685781, 0.0015424491139128804, 0.001401459681801498, 0.0009672308806329966, 0.0009273953619413078, 0.000835210841614753, 0.0010153428884223104]

# %%
plt.figure(figsize=(20,10))
plt.plot(custom_hist.train_loss, color = 'blue', label = 'train_loss')
plt.plot(custom_hist.val_loss, color = 'red', label = 'val_loss')
plt.title('Training Loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
from keras.models import load_model
model = load_model('/content/best-model-rice.h5')

# %% [markdown]
# Train Data *평가*

# %%
model.evaluate(trainX, trainY, batch_size=a)
# Out:
# 204/204 [==============================] - 1s 3ms/step - loss: 0.0020 - mae: 0.0366
# [0.0020267509389668703, 0.036642685532569885]

# %%
predicted_price_train = model.predict(trainX, batch_size=a, verbose=1)
# Out:
# 204/204 [==============================] - 1s 2ms/step

# %%
trainY_test = np.delete(trainY, np.s_[1:a], axis=1)
predicted_price_train_test = np.delete(predicted_price_train, np.s_[1:a], axis=1)

trainY_test = np.reshape(trainY_test, (1428, 1))
predicted_price_train_test = np.reshape(predicted_price_train_test, (1428, 1))
print(trainY_test.shape)
print(predicted_price_train_test.shape)
# Out:
# (1428, 1)
# (1428, 1)

# %%
plt.figure(figsize=(20,10))
plt.plot(trainY_test, color = 'blue', label = 'Actual Stock Price')
plt.plot(predicted_price_train_test, color = 'red', label = 'Predicted Stock Price')
plt.title('Price Prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
predicted_price_train_test = np.reshape(predicted_price_train_test, (1428, ))
predicted_price_train_test = scaler_target.inverse_transform(predicted_price_train_test.reshape(-1,1))

print(predicted_price_train_test, predicted_price_train_test.shape)

trainY_test = scaler_target.inverse_transform(trainY_test.reshape(-1,1))

print(trainY_test, trainY_test.shape)
# Out:
# [[49616.582]
#  [50856.023]
#  [51500.36 ]
#  ...
#  [52645.78 ]
#  [52262.97 ]
#  [52439.465]] (1428, 1)
# [[46257.]
#  [46257.]
#  [46257.]
#  ...
#  [52649.]
#  [52836.]
#  [52924.]] (1428, 1)

# %%
import matplotlib.ticker as ticker
plt.figure(figsize=(20,10))
plt.plot(trainY_test, color = 'blue', label = 'Actual Stock Price')
plt.plot(predicted_price_train_test, color = 'red', label = 'Predicted Stock Price')

ax=plt.axes()
ax.xaxis.set_major_locator(ticker.MultipleLocator(100))
ax.yaxis.set_major_locator(ticker.MultipleLocator(1000))

plt.title('Price Prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
from sklearn.metrics import mean_squared_error 
MSE = mean_squared_error(trainY_test, predicted_price_train_test) 
np.sqrt(MSE)
# Out:
# 1377.1633734606867

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(trainY_test, predicted_price_train_test)
# Out:
# 1106.9273787640057

# %% [markdown]
# Val Date 평가

# %%
model.evaluate(validX, validY, batch_size=a)
# Out:
# 68/68 [==============================] - 0s 3ms/step - loss: 0.0033 - mae: 0.0426
# [0.0032511954195797443, 0.042634036391973495]

# %%
predicted_price_valid = model.predict(validX, batch_size=a, verbose=1)
# Out:
# 68/68 [==============================] - 0s 2ms/step

# %%
validY_test = np.delete(validY, np.s_[1:a], axis=1)
predicted_price_valid_test = np.delete(predicted_price_valid, np.s_[1:a], axis=1)

validY_test = np.reshape(validY_test, (476, 1))
predicted_price_valid_test = np.reshape(predicted_price_valid_test, (476, 1))
print(validY_test.shape)
print(predicted_price_valid_test.shape)

plt.figure(figsize=(20,10))
plt.plot(validY_test, color = 'blue', label = 'Actual Stock Price')
plt.plot(predicted_price_valid_test, color = 'red', label = 'Predicted Stock Price')
plt.title('Price Prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# (476, 1)
# (476, 1)

# %%
predicted_price_valid_test = np.reshape(predicted_price_valid_test, (476, ))
predicted_price_valid_test = scaler_target.inverse_transform(predicted_price_valid_test.reshape(-1,1))

print(predicted_price_valid_test, predicted_price_valid_test.shape)

validY_test = scaler_target.inverse_transform(validY_test.reshape(-1,1))

print(validY_test, validY_test.shape)
# Out:
# [[52570.426]
#  [51978.598]
#  [52210.17 ]
#  [52655.266]
#  [52727.254]
#  [52935.44 ]
#  [53661.9  ]
#  [52764.49 ]
#  [52665.59 ]
#  [53163.598]
#  [53542.066]
#  [53485.805]
#  [53677.535]
#  [53059.88 ]
#  [53054.246]
#  [52810.45 ]
#  [52929.35 ]
#  [53309.25 ]
#  [52876.023]
#  [52986.695]
#  [53151.586]
#  [53178.07 ]
#  [53280.098]
#  [52493.496]
#  [52792.71 ]
#  [52711.863]
#  [52572.027]
#  [52488.297]
#  [52379.69 ]
#  [52574.08 ]
#  [52733.176]
#  [53053.074]
#  [52844.63 ]
#  [53158.62 ]
#  [53451.426]
#  [53500.285]
#  [53453.445]
#  [53345.88 ]
#  [52794.027]
#  [52716.598]
#  [53256.848]
#  [53843.723]
#  [54072.902]
#  [54229.19 ]
#  [53980.207]
#  [53035.234]
#  [53070.582]
#  [53098.324]
#  [53121.766]
#  [53278.625]
#  [52488.656]
#  [52230.22 ]
#  [52434.258]
#  [52623.727]
#  [52834.562]
#  [52426.934]
#  [52147.883]
#  [52416.46 ]
#  [52086.94 ]
#  [51950.71 ]
#  [51910.3  ]
#  [51996.08 ]
#  [51849.973]
#  [52112.945]
#  [52669.535]
#  [52823.004]
#  [52897.547]
#  [52520.97 ]
#  [51985.395]
#  [52453.918]
#  [52378.977]
#  [52714.027]
#  [52384.88 ]
#  [51933.13 ]
#  [52231.53 ]
#  [52335.51 ]
#  [52300.203]
#  [52078.61 ]
#  [51974.625]
#  [52143.16 ]
#  [51611.082]
#  [51362.152]
#  [51100.207]
#  [51423.03 ]
#  [51654.703]
#  [52069.746]
#  [51549.027]
#  [50850.527]
#  [51533.44 ]
#  [52001.855]
#  [52540.97 ]
#  [52420.832]
#  [52349.355]
#  [52037.945]
#  [51711.26 ]
#  [52016.53 ]
#  [51719.504]
#  [51027.94 ]
#  [51212.434]
#  [51396.504]
#  [51531.58 ]
#  [51290.1  ]
#  [50994.812]
#  [51282.89 ]
#  [51202.367]
#  [51445.92 ]
#  [51100.58 ]
#  [50978.223]
#  [51474.69 ]
#  [51556.008]
#  [51920.965]
#  [51783.195]
#  [51505.258]
#  [51975.953]
#  [52315.46 ]
#  [52649.414]
#  [52456.234]
#  [52214.805]
#  [52163.492]
#  [52238.93 ]
#  [52668.523]
#  [52260.133]
#  [52523.812]
#  [52467.16 ]
#  [51979.895]
#  [51604.668]
#  [51670.855]
#  [51729.035]
#  [52123.445]
#  [51903.03 ]
#  [51749.3  ]
#  [52158.26 ]
#  [52455.95 ]
#  [52118.48 ]
#  [51609.215]
#  [51153.098]
#  [51693.637]
#  [51928.55 ]
#  [51881.844]
#  [51356.645]
#  [51137.12 ]
#  [51280.402]
#  [51051.617]
#  [51468.15 ]
#  [51136.61 ]
#  [50991.004]
#  [50833.227]
#  [51208.25 ]
#  [51130.152]
#  [50899.832]
#  [51382.44 ]
#  [51549.02 ]
#  [51618.2  ]
#  [51469.934]
#  [51206.98 ]
#  [51546.363]
#  [51745.81 ]
#  [51908.156]
#  [51715.426]
#  [51722.598]
#  [52018.195]
#  [51856.098]
#  [51637.812]
#  [51061.977]
#  [50840.54 ]
#  [51027.297]
#  [51168.98 ]
#  [51222.992]
#  [50916.53 ]
#  [50542.586]
#  [51346.008]
#  [51421.434]
#  [51970.156]
#  [51789.324]
#  [51801.453]
#  [52246.848]
#  [52316.18 ]
#  [52216.715]
#  [51884.188]
#  [51729.86 ]
#  [52129.133]
#  [51884.293]
#  [51691.145]
#  [50841.348]
#  [50494.04 ]
#  [50988.355]
#  [51414.46 ]
#  [51967.203]
#  [51768.29 ]
#  [51829.555]
#  [52142.402]
#  [52345.887]
#  [52097.508]
#  [51652.5  ]
#  [51426.08 ]
#  [51035.305]
#  [51582.434]
#  [51387.44 ]
#  [51453.39 ]
#  [51743.156]
#  [51637.113]
#  [52098.52 ]
#  [51894.37 ]
#  [51593.547]
#  [51312.523]
#  [51111.844]
#  [51400.254]
#  [50955.824]
#  [50458.617]
#  [50665.297]
#  [50723.18 ]
#  [51056.87 ]
#  [50393.21 ]
#  [49809.758]
#  [49423.11 ]
#  [49406.754]
#  [48967.03 ]
#  [49611.312]
#  [49843.066]
#  [50162.82 ]
#  [50190.27 ]
#  [50190.44 ]
#  [50762.953]
#  [50947.516]
#  [51319.11 ]
#  [51069.047]
#  [50193.57 ]
#  [50127.75 ]
#  [50337.332]
#  [49900.043]
#  [50824.656]
#  [50923.785]
#  [50808.406]
#  [50713.72 ]
#  [50603.145]
#  [50988.617]
#  [50847.74 ]
#  [51460.953]
#  [51214.91 ]
#  [50637.54 ]
#  [50629.42 ]
#  [50541.88 ]
#  [50620.34 ]
#  [50288.74 ]
#  [50284.094]
#  [50571.137]
#  [50806.336]
#  [50976.863]
#  [50878.742]
#  [50648.016]
#  [50684.492]
#  [50827.38 ]
#  [50867.047]
#  [50866.96 ]
#  [50152.39 ]
#  [50200.523]
#  [50312.9  ]
#  [49773.32 ]
#  [49507.477]
#  [49523.766]
#  [50197.625]
#  [50410.016]
#  [50432.312]
#  [50303.027]
#  [49779.2  ]
#  [50330.73 ]
#  [50541.64 ]
#  [50338.574]
#  [50430.99 ]
#  [50267.51 ]
#  [50242.086]
#  [49888.55 ]
#  [50157.914]
#  [49385.09 ]
#  [50100.766]
#  [50369.168]
#  [50761.008]
#  [50494.734]
#  [50090.86 ]
#  [50472.83 ]
#  [50584.69 ]
#  [50911.62 ]
#  [50972.18 ]
#  [51470.355]
#  [51570.39 ]
#  [51330.113]
#  [50666.344]
#  [51665.832]
#  [51760.63 ]
#  [51013.633]
#  [49701.15 ]
#  [48835.54 ]
#  [49064.746]
#  [49311.49 ]
#  [49320.645]
#  [49355.797]
#  [48887.21 ]
#  [49580.72 ]
#  [49903.51 ]
#  [49827.74 ]
#  [49941.47 ]
#  [49494.41 ]
#  [50084.09 ]
#  [49458.902]
#  [49039.082]
#  [49701.137]
#  [49765.6  ]
#  [49560.832]
#  [49312.035]
#  [48584.266]
#  [49331.16 ]
#  [49575.938]
#  [49959.89 ]
#  [50058.26 ]
#  [49481.344]
#  [50336.94 ]
#  [50973.28 ]
#  [50435.965]
#  [50267.824]
#  [50033.926]
#  [50855.543]
#  [50967.16 ]
#  [51329.773]
#  [50100.344]
#  [49723.453]
#  [50402.645]
#  [50952.625]
#  [50789.008]
#  [50428.29 ]
#  [49288.043]
#  [49779.867]
#  [50231.086]
#  [50569.797]
#  [50092.836]
#  [49200.67 ]
#  [49642.016]
#  [49366.77 ]
#  [49375.035]
#  [49370.32 ]
#  [49104.4  ]
#  [48781.2  ]
#  [48652.188]
#  [49040.113]
#  [49152.523]
#  [48874.098]
#  [49699.832]
#  [49483.832]
#  [49907.08 ]
#  [49920.258]
#  [48929.46 ]
#  [49564.465]
#  [49577.746]
#  [49738.59 ]
#  [49596.812]
#  [48727.117]
#  [49155.574]
#  [49264.71 ]
#  [49138.26 ]
#  [49069.668]
#  [49685.656]
#  [49769.992]
#  [49474.805]
#  [48801.17 ]
#  [48092.668]
#  [48244.305]
#  [47961.652]
#  [48060.88 ]
#  [47999.73 ]
#  [47724.246]
#  [47771.902]
#  [47748.24 ]
#  [48286.473]
#  [48346.688]
#  [48373.945]
#  [48301.27 ]
#  [47941.234]
#  [48655.68 ]
#  [48551.633]
#  [48608.637]
#  [48349.652]
#  [48308.18 ]
#  [49077.152]
#  [49504.715]
#  [49813.625]
#  [49791.12 ]
#  [49260.12 ]
#  [50147.75 ]
#  [50561.63 ]
#  [50167.594]
#  [50075.945]
#  [49576.01 ]
#  [50015.555]
#  [50486.727]
#  [50709.016]
#  [50479.33 ]
#  [50050.23 ]
#  [50685.79 ]
#  [51158.926]
#  [50936.844]
#  [50699.547]
#  [50226.332]
#  [51078.484]
#  [51271.535]
#  [51418.035]
#  [51181.34 ]
#  [50018.742]
#  [50524.387]
#  [50145.715]
#  [50204.414]
#  [49030.55 ]
#  [49043.125]
#  [49704.383]
#  [49789.29 ]
#  [50060.38 ]
#  [49857.793]
#  [49535.734]
#  [50367.26 ]
#  [50253.434]
#  [49336.53 ]
#  [49129.63 ]
#  [48879.32 ]
#  [49698.992]
#  [50062.94 ]
#  [49539.38 ]
#  [49702.22 ]
#  [49480.703]
#  [48818.395]
#  [48550.035]
#  [48883.258]
#  [49048.836]
#  [48642.05 ]
#  [49662.45 ]
#  [50067.777]
#  [49310.242]
#  [49129.16 ]
#  [48990.477]
#  [48917.023]
#  [49850.17 ]
#  [49928.227]
#  [49234.293]
#  [49668.24 ]
#  [50214.555]
#  [50217.81 ]
#  [50417.223]
#  [50313.09 ]
#  [51575.934]
#  [52451.508]
#  [52606.836]
#  [52336.555]
#  [51057.715]
#  [50917.28 ]
#  [51557.402]
#  [51454.07 ]
#  [51265.965]
#  [50413.555]
#  [49567.6  ]
#  [49699.973]
#  [48848.83 ]
#  [48529.977]
#  [48430.086]
#  [49252.496]
#  [49311.04 ]
#  [49828.645]
#  [50035.727]
#  [49767.24 ]
#  [50573.113]
#  [50615.445]
#  [51159.062]
#  [50741.586]
#  [49786.652]
#  [49865.562]
#  [50081.383]
#  [50526.496]
#  [50578.812]
#  [51207.04 ]
#  [51448.957]] (476, 1)
# [[52924.]
#  [52924.]
#  [52924.]
#  [52924.]
#  [52924.]
#  [52924.]
#  [52924.]
#  [52924.]
#  [52924.]
#  [52924.]
#  [52924.]
#  [52924.]
#  [52924.]
#  [52924.]
#  [52924.]
#  [52924.]
#  [52924.]
#  [52924.]
#  [52924.]
#  [52999.]
#  [52999.]
#  [52999.]
#  [52999.]
#  [52999.]
#  [52999.]
#  [52999.]
#  [52999.]
#  [52749.]
#  [52749.]
#  [52749.]
#  [52749.]
#  [52749.]
#  [52749.]
#  [52749.]
#  [52749.]
#  [52849.]
#  [52849.]
#  [52149.]
#  [52149.]
#  [52149.]
#  [52149.]
#  [52149.]
#  [52074.]
#  [52324.]
#  [52324.]
#  [52199.]
#  [52199.]
#  [52199.]
#  [51949.]
#  [52161.]
#  [52161.]
#  [51949.]
#  [52199.]
#  [52199.]
#  [52199.]
#  [52199.]
#  [52199.]
#  [52199.]
#  [52411.]
#  [52411.]
#  [52411.]
#  [52411.]
#  [52449.]
#  [52236.]
#  [52236.]
#  [52236.]
#  [52236.]
#  [52236.]
#  [52236.]
#  [52236.]
#  [52236.]
#  [52236.]
#  [52236.]
#  [51861.]
#  [52011.]
#  [52011.]
#  [52136.]
#  [52261.]
#  [52261.]
#  [52249.]
#  [52249.]
#  [52536.]
#  [52536.]
#  [52536.]
#  [52536.]
#  [52536.]
#  [52286.]
#  [52286.]
#  [52286.]
#  [52286.]
#  [52324.]
#  [52324.]
#  [52324.]
#  [52324.]
#  [52324.]
#  [52449.]
#  [52449.]
#  [52699.]
#  [52699.]
#  [52586.]
#  [52336.]
#  [52211.]
#  [52211.]
#  [52211.]
#  [52211.]
#  [52211.]
#  [52711.]
#  [52711.]
#  [52211.]
#  [52211.]
#  [52211.]
#  [51899.]
#  [51899.]
#  [51899.]
#  [51899.]
#  [51899.]
#  [51899.]
#  [51899.]
#  [51899.]
#  [51899.]
#  [51899.]
#  [52086.]
#  [52086.]
#  [52086.]
#  [52086.]
#  [52086.]
#  [52961.]
#  [52961.]
#  [52086.]
#  [52086.]
#  [52086.]
#  [51974.]
#  [51974.]
#  [51974.]
#  [51849.]
#  [51849.]
#  [51849.]
#  [51849.]
#  [51849.]
#  [51849.]
#  [51849.]
#  [51849.]
#  [51849.]
#  [51849.]
#  [51849.]
#  [51849.]
#  [51849.]
#  [51849.]
#  [51849.]
#  [51849.]
#  [51849.]
#  [51849.]
#  [51849.]
#  [51324.]
#  [50799.]
#  [50799.]
#  [50799.]
#  [50799.]
#  [50799.]
#  [50799.]
#  [50799.]
#  [50799.]
#  [50799.]
#  [51849.]
#  [51849.]
#  [51724.]
#  [51724.]
#  [51724.]
#  [51724.]
#  [51724.]
#  [51724.]
#  [51724.]
#  [51724.]
#  [51724.]
#  [51724.]
#  [51724.]
#  [51724.]
#  [51724.]
#  [51724.]
#  [51724.]
#  [51724.]
#  [51724.]
#  [51724.]
#  [51724.]
#  [51724.]
#  [50961.]
#  [50961.]
#  [50961.]
#  [51575.]
#  [51488.]
#  [51488.]
#  [51488.]
#  [51488.]
#  [51488.]
#  [51488.]
#  [51488.]
#  [51488.]
#  [51113.]
#  [51113.]
#  [51113.]
#  [51113.]
#  [51113.]
#  [51113.]
#  [51113.]
#  [51113.]
#  [51113.]
#  [51113.]
#  [51113.]
#  [51375.]
#  [51375.]
#  [51375.]
#  [51375.]
#  [51463.]
#  [51463.]
#  [51113.]
#  [51238.]
#  [51238.]
#  [51238.]
#  [51238.]
#  [51238.]
#  [51238.]
#  [51113.]
#  [51000.]
#  [51000.]
#  [51000.]
#  [50967.]
#  [51156.]
#  [51440.]
#  [51156.]
#  [51233.]
#  [51233.]
#  [51233.]
#  [51263.]
#  [51300.]
#  [51300.]
#  [51300.]
#  [51050.]
#  [51300.]
#  [51300.]
#  [51300.]
#  [51300.]
#  [51300.]
#  [51350.]
#  [51350.]
#  [51275.]
#  [51275.]
#  [51313.]
#  [51313.]
#  [51313.]
#  [51313.]
#  [51313.]
#  [51313.]
#  [51438.]
#  [51688.]
#  [51688.]
#  [51688.]
#  [51438.]
#  [51525.]
#  [51525.]
#  [51525.]
#  [51525.]
#  [51663.]
#  [51663.]
#  [51663.]
#  [51663.]
#  [51663.]
#  [51663.]
#  [51700.]
#  [51700.]
#  [51700.]
#  [51700.]
#  [51700.]
#  [51700.]
#  [51700.]
#  [51700.]
#  [51700.]
#  [51788.]
#  [51788.]
#  [51788.]
#  [51788.]
#  [51788.]
#  [51788.]
#  [51788.]
#  [51788.]
#  [51788.]
#  [51563.]
#  [51563.]
#  [51563.]
#  [51563.]
#  [51563.]
#  [51563.]
#  [51563.]
#  [51563.]
#  [51563.]
#  [51563.]
#  [51563.]
#  [51563.]
#  [51475.]
#  [51475.]
#  [51475.]
#  [51475.]
#  [51475.]
#  [51475.]
#  [51700.]
#  [51700.]
#  [51700.]
#  [51700.]
#  [51700.]
#  [51700.]
#  [51700.]
#  [51700.]
#  [51700.]
#  [51700.]
#  [51700.]
#  [51700.]
#  [51575.]
#  [51575.]
#  [51575.]
#  [51825.]
#  [51825.]
#  [51825.]
#  [51825.]
#  [51825.]
#  [51825.]
#  [51825.]
#  [51825.]
#  [51825.]
#  [51825.]
#  [51613.]
#  [51613.]
#  [51613.]
#  [51613.]
#  [51613.]
#  [51613.]
#  [51613.]
#  [51613.]
#  [51613.]
#  [51613.]
#  [51863.]
#  [51925.]
#  [51800.]
#  [51800.]
#  [51800.]
#  [51675.]
#  [51675.]
#  [51675.]
#  [51675.]
#  [51463.]
#  [51463.]
#  [51463.]
#  [51338.]
#  [51338.]
#  [51338.]
#  [51338.]
#  [51338.]
#  [51338.]
#  [51338.]
#  [51338.]
#  [51300.]
#  [51300.]
#  [51300.]
#  [51300.]
#  [51300.]
#  [51300.]
#  [51300.]
#  [51300.]
#  [51300.]
#  [51300.]
#  [51300.]
#  [51300.]
#  [51300.]
#  [51300.]
#  [51300.]
#  [51300.]
#  [51300.]
#  [51300.]
#  [51300.]
#  [51338.]
#  [51338.]
#  [51338.]
#  [51338.]
#  [51338.]
#  [51338.]
#  [51338.]
#  [51338.]
#  [51338.]
#  [51338.]
#  [51463.]
#  [51463.]
#  [51463.]
#  [51463.]
#  [51463.]
#  [51463.]
#  [51463.]
#  [51463.]
#  [51463.]
#  [51463.]
#  [51463.]
#  [51463.]
#  [51463.]
#  [51463.]
#  [51463.]
#  [51463.]
#  [51463.]
#  [51463.]
#  [51463.]
#  [51463.]
#  [51588.]
#  [51588.]
#  [51300.]
#  [51300.]
#  [51300.]
#  [51300.]
#  [51175.]
#  [51225.]
#  [51225.]
#  [51225.]
#  [51225.]
#  [51350.]
#  [51350.]
#  [51350.]
#  [51638.]
#  [51638.]
#  [51638.]
#  [51900.]
#  [51900.]
#  [51900.]
#  [51900.]
#  [51900.]
#  [51900.]
#  [51900.]
#  [51900.]
#  [51900.]
#  [51988.]
#  [51988.]
#  [51988.]
#  [51988.]
#  [51738.]
#  [52238.]
#  [52238.]
#  [52075.]
#  [52075.]
#  [52075.]
#  [52163.]
#  [52163.]
#  [52163.]
#  [51788.]
#  [51788.]
#  [51788.]
#  [51788.]
#  [51788.]
#  [51825.]
#  [51825.]
#  [51825.]
#  [51825.]
#  [51988.]
#  [51988.]
#  [51988.]
#  [51988.]
#  [52075.]
#  [52075.]
#  [52075.]
#  [52075.]
#  [52163.]
#  [52363.]
#  [52363.]
#  [52363.]
#  [55475.]
#  [55475.]
#  [55475.]
#  [56920.]
#  [56360.]
#  [56260.]
#  [56767.]
#  [56656.]
#  [56589.]] (476, 1)

# %%
plt.figure(figsize=(40,10))
plt.plot(validY_test, color = 'blue', label = 'Actual Stock Price')
plt.plot(predicted_price_valid_test, color = 'red', label = 'Predicted Stock Price')
plt.title('Price Prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(40,10))
plt.plot(validY_test, color = 'blue', label = 'Actual Stock Price')
plt.plot(predicted_price_valid_test, color = 'red', label = 'Predicted Stock Price')

ax=plt.axes()
ax.xaxis.set_major_locator(ticker.MultipleLocator(100))
ax.yaxis.set_major_locator(ticker.MultipleLocator(1000))

plt.title('Price Prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   """

# %%
from sklearn.metrics import mean_squared_error 
MSE = mean_squared_error(validY_test, predicted_price_valid_test) 
np.sqrt(MSE)
# Out:
# 1645.1194983626724

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(validY_test, predicted_price_valid_test)
# Out:
# 1236.5984604779412

# %% [markdown]
# Test Data 평가

# %%
model.evaluate(testX, testY, batch_size=a)
# Out:
# 68/68 [==============================] - 0s 3ms/step - loss: 0.0046 - mae: 0.0558
# [0.004631416406482458, 0.055820707231760025]

# %%
predicted_price_test = model.predict(testX, batch_size=a, verbose=1)
# Out:
# 68/68 [==============================] - 0s 2ms/step

# %%
testY_test = np.delete(testY, np.s_[1:a], axis=1)
predicted_price_test_test = np.delete(predicted_price_test, np.s_[1:a], axis=1)

testY_test = np.reshape(testY_test, (476, 1))
predicted_price_test_test = np.reshape(predicted_price_test_test, (476, 1))
print(testY_test.shape)
print(predicted_price_test_test.shape)

plt.figure(figsize=(20,10))
plt.plot(testY_test, color = 'blue', label = 'Actual Stock Price')
plt.plot(predicted_price_test_test, color = 'red', label = 'Predicted Stock Price')
plt.title('Price Prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# (476, 1)
# (476, 1)

# %%
predicted_price_test_test = np.reshape(predicted_price_test_test, (476, ))
predicted_price_test_test = scaler_target.inverse_transform(predicted_price_test_test.reshape(-1,1))

print(predicted_price_test_test, predicted_price_test_test.shape)

testY_test = scaler_target.inverse_transform(testY_test.reshape(-1,1))

print(testY_test, testY_test.shape)
# Out:
# [[48373.246]
#  [49596.082]
#  [48489.754]
#  [47773.344]
#  [48070.156]
#  [49325.29 ]
#  [48823.406]
#  [53933.223]
#  [54822.562]
#  [53454.902]
#  [53381.547]
#  [53809.508]
#  [54761.53 ]
#  [53739.645]
#  [56377.227]
#  [57107.742]
#  [57572.62 ]
#  [57355.914]
#  [56716.043]
#  [56049.477]
#  [56629.69 ]
#  [56938.535]
#  [56871.934]
#  [56488.508]
#  [56260.043]
#  [56588.016]
#  [56923.58 ]
#  [57308.117]
#  [56627.195]
#  [55918.883]
#  [54909.39 ]
#  [55240.195]
#  [55634.82 ]
#  [55943.566]
#  [56067.094]
#  [57256.465]
#  [57526.285]
#  [58119.035]
#  [58026.758]
#  [57917.547]
#  [57928.348]
#  [57432.367]
#  [57379.438]
#  [57177.105]
#  [57607.953]
#  [57875.6  ]
#  [57598.938]
#  [57373.39 ]
#  [56856.836]
#  [57705.395]
#  [57664.613]
#  [58273.46 ]
#  [58072.633]
#  [57723.016]
#  [57836.223]
#  [57779.516]
#  [57438.76 ]
#  [56354.36 ]
#  [57022.16 ]
#  [57427.37 ]
#  [57518.633]
#  [57385.38 ]
#  [57271.1  ]
#  [57472.65 ]
#  [58101.035]
#  [58081.7  ]
#  [57748.195]
#  [57828.023]
#  [57628.652]
#  [57624.24 ]
#  [57588.54 ]
#  [57286.97 ]
#  [57333.87 ]
#  [57524.44 ]
#  [57706.324]
#  [57534.11 ]
#  [57186.39 ]
#  [56888.4  ]
#  [56971.496]
#  [57466.17 ]
#  [57248.24 ]
#  [57260.312]
#  [57477.746]
#  [57607.004]
#  [57611.465]
#  [57605.51 ]
#  [57374.094]
#  [56375.773]
#  [56389.316]
#  [55423.176]
#  [56089.562]
#  [56495.83 ]
#  [57155.98 ]
#  [57243.17 ]
#  [57373.04 ]
#  [57902.23 ]
#  [57895.01 ]
#  [57836.227]
#  [57616.273]
#  [57632.02 ]
#  [57577.98 ]
#  [57712.098]
#  [57423.547]
#  [57164.094]
#  [57296.83 ]
#  [57253.34 ]
#  [57376.15 ]
#  [57050.2  ]
#  [56940.957]
#  [57170.93 ]
#  [57184.734]
#  [57176.61 ]
#  [57085.344]
#  [56818.51 ]
#  [57219.28 ]
#  [57581.5  ]
#  [57611.86 ]
#  [57578.566]
#  [57477.805]
#  [57191.547]
#  [57206.004]
#  [57569.016]
#  [57479.43 ]
#  [57169.902]
#  [57355.33 ]
#  [57447.266]
#  [57710.156]
#  [57341.33 ]
#  [56950.85 ]
#  [56911.76 ]
#  [56740.19 ]
#  [56838.06 ]
#  [56759.906]
#  [56500.086]
#  [56431.516]
#  [56147.258]
#  [56402.906]
#  [56392.266]
#  [56077.777]
#  [56305.742]
#  [56246.13 ]
#  [56660.61 ]
#  [56508.207]
#  [57437.08 ]
#  [57067.625]
#  [57769.133]
#  [57526.938]
#  [57379.535]
#  [57741.387]
#  [57970.76 ]
#  [58316.215]
#  [58142.773]
#  [58614.535]
#  [58500.69 ]
#  [58459.01 ]
#  [57922.1  ]
#  [57486.547]
#  [57567.734]
#  [57806.023]
#  [58291.4  ]
#  [58176.145]
#  [57907.63 ]
#  [58065.66 ]
#  [57984.7  ]
#  [58284.55 ]
#  [58166.05 ]
#  [58046.797]
#  [58006.734]
#  [57929.91 ]
#  [58162.25 ]
#  [57955.117]
#  [57249.895]
#  [57619.67 ]
#  [57745.14 ]
#  [58311.23 ]
#  [58238.016]
#  [58035.07 ]
#  [58387.906]
#  [58549.348]
#  [58653.883]
#  [58469.93 ]
#  [58413.496]
#  [58430.06 ]
#  [58376.484]
#  [58615.6  ]
#  [58437.035]
#  [58314.67 ]
#  [58340.188]
#  [58436.863]
#  [58643.67 ]
#  [58436.61 ]
#  [58142.344]
#  [58246.53 ]
#  [58364.535]
#  [58368.766]
#  [58456.11 ]
#  [58164.344]
#  [58246.49 ]
#  [58368.008]
#  [58441.133]
#  [58264.438]
#  [58103.098]
#  [58257.21 ]
#  [58368.598]
#  [58650.207]
#  [58447.438]
#  [58210.98 ]
#  [58274.848]
#  [58367.676]
#  [58486.32 ]
#  [58255.156]
#  [58065.79 ]
#  [57927.977]
#  [57862.07 ]
#  [57616.547]
#  [57071.562]
#  [57123.133]
#  [57206.49 ]
#  [57529.445]
#  [57268.605]
#  [57150.375]
#  [57476.867]
#  [57936.68 ]
#  [58403.38 ]
#  [57857.508]
#  [57680.613]
#  [57245.797]
#  [57157.35 ]
#  [56948.96 ]
#  [56647.516]
#  [56467.934]
#  [56793.305]
#  [56606.87 ]
#  [56608.562]
#  [56076.758]
#  [55124.527]
#  [54836.625]
#  [54360.473]
#  [55384.258]
#  [55069.33 ]
#  [55262.84 ]
#  [55103.63 ]
#  [54817.47 ]
#  [54974.24 ]
#  [54452.426]
#  [54347.4  ]
#  [53870.523]
#  [54229.19 ]
#  [54236.336]
#  [54159.457]
#  [53921.848]
#  [54374.875]
#  [54339.742]
#  [54333.664]
#  [54344.035]
#  [54194.723]
#  [54315.324]
#  [54248.53 ]
#  [54463.223]
#  [54834.695]
#  [54644.04 ]
#  [55133.395]
#  [55086.438]
#  [55079.73 ]
#  [55153.723]
#  [54950.11 ]
#  [55141.336]
#  [55014.22 ]
#  [54775.047]
#  [54692.86 ]
#  [54319.02 ]
#  [54373.156]
#  [54270.797]
#  [54863.297]
#  [54954.227]
#  [54887.12 ]
#  [54906.445]
#  [54836.625]
#  [54602.203]
#  [54451.414]
#  [54438.17 ]
#  [54740.176]
#  [54683.316]
#  [55128.473]
#  [54589.926]
#  [53832.273]
#  [54333.95 ]
#  [54220.805]
#  [54641.703]
#  [54599.906]
#  [54720.77 ]
#  [54633.94 ]
#  [54895.703]
#  [54900.9  ]
#  [54785.89 ]
#  [54956.6  ]
#  [54114.004]
#  [54576.773]
#  [54699.266]
#  [54635.62 ]
#  [54981.438]
#  [54661.05 ]
#  [54983.105]
#  [54868.836]
#  [54427.055]
#  [54273.926]
#  [53911.25 ]
#  [53564.863]
#  [53556.516]
#  [53717.09 ]
#  [53695.363]
#  [53710.285]
#  [53705.42 ]
#  [52654.77 ]
#  [52989.504]
#  [52464.668]
#  [52665.277]
#  [52835.54 ]
#  [52388.586]
#  [52818.69 ]
#  [52909.246]
#  [52890.082]
#  [52565.934]
#  [52202.66 ]
#  [52633.688]
#  [52725.56 ]
#  [52492.76 ]
#  [53811.684]
#  [53309.01 ]
#  [53552.21 ]
#  [52918.83 ]
#  [53172.957]
#  [52779.33 ]
#  [52565.395]
#  [52360.523]
#  [51521.793]
#  [51565.023]
#  [51929.82 ]
#  [52272.11 ]
#  [52371.617]
#  [51815.89 ]
#  [52284.656]
#  [52514.633]
#  [52589.574]
#  [52941.133]
#  [53333.37 ]
#  [53217.38 ]
#  [52605.152]
#  [52873.465]
#  [52383.547]
#  [53007.656]
#  [52751.06 ]
#  [52396.18 ]
#  [51999.242]
#  [52301.984]
#  [52136.062]
#  [51367.8  ]
#  [51910.445]
#  [51719.85 ]
#  [52184.79 ]
#  [52522.49 ]
#  [52361.953]
#  [52585.203]
#  [52152.87 ]
#  [52619.13 ]
#  [52449.02 ]
#  [52449.8  ]
#  [52506.78 ]
#  [51892.312]
#  [52049.875]
#  [51727.816]
#  [51831.477]
#  [52019.55 ]
#  [51492.324]
#  [51049.62 ]
#  [50939.49 ]
#  [51016.914]
#  [51484.88 ]
#  [51226.457]
#  [51580.348]
#  [51541.547]
#  [51159.543]
#  [51801.234]
#  [51096.14 ]
#  [51217.125]
#  [51277.38 ]
#  [50904.055]
#  [51225.438]
#  [50890.535]
#  [50982.184]
#  [50328.37 ]
#  [50598.35 ]
#  [50241.133]
#  [50277.89 ]
#  [50594.184]
#  [50547.57 ]
#  [50487.902]
#  [50150.402]
#  [50031.17 ]
#  [50267.21 ]
#  [50433.812]
#  [50782.555]
#  [50451.49 ]
#  [50287.375]
#  [49912.996]
#  [49584.875]
#  [49876.266]
#  [49638.21 ]
#  [50101.38 ]
#  [50258.35 ]
#  [49792.29 ]
#  [49854.09 ]
#  [50245.125]
#  [50301.094]
#  [50194.957]
#  [49269.656]
#  [49490.93 ]
#  [49723.492]
#  [49904.03 ]
#  [50435.89 ]
#  [50120.848]
#  [50197.33 ]
#  [49787.99 ]
#  [49355.355]
#  [49447.78 ]
#  [48468.19 ]
#  [48402.215]
#  [48427.637]
#  [48732.207]
#  [49075.16 ]
#  [49165.684]
#  [49274.203]
#  [49435.234]
#  [49268.05 ]
#  [49776.543]
#  [49558.11 ]
#  [49581.613]
#  [49823.29 ]
#  [49664.176]
#  [49949.766]
#  [49678.137]
#  [49820.195]
#  [49810.555]
#  [49992.855]
#  [50286.164]
#  [50088.195]
#  [50213.332]
#  [50302.633]
#  [50255.516]
#  [50280.31 ]
#  [49670.504]
#  [49524.047]
#  [49539.76 ]
#  [49353.49 ]
#  [49047.535]
#  [48383.438]
#  [48698.453]
#  [48890.04 ]
#  [48953.47 ]
#  [48641.645]
#  [48817.39 ]
#  [48947.613]
#  [48692.6  ]
#  [48573.66 ]
#  [48318.758]
#  [48206.324]
#  [48106.645]
#  [47734.633]
#  [47658.656]
#  [47250.848]
#  [47211.016]
#  [47802.543]
#  [47430.9  ]
#  [47270.64 ]
#  [46852.617]
#  [47024.336]] (476, 1)
# [[56763.]
#  [57388.]
#  [57388.]
#  [57888.]
#  [57725.]
#  [57725.]
#  [57725.]
#  [58000.]
#  [58000.]
#  [58000.]
#  [57250.]
#  [58000.]
#  [58000.]
#  [56988.]
#  [56988.]
#  [56738.]
#  [56738.]
#  [56988.]
#  [56988.]
#  [57663.]
#  [57663.]
#  [57675.]
#  [57675.]
#  [57550.]
#  [57550.]
#  [58263.]
#  [58263.]
#  [58313.]
#  [59538.]
#  [59538.]
#  [59663.]
#  [59663.]
#  [59663.]
#  [59163.]
#  [59163.]
#  [59175.]
#  [59175.]
#  [59050.]
#  [59050.]
#  [59050.]
#  [59050.]
#  [58850.]
#  [59475.]
#  [59475.]
#  [59600.]
#  [59600.]
#  [59600.]
#  [59600.]
#  [59600.]
#  [59600.]
#  [59600.]
#  [59100.]
#  [59529.]
#  [59529.]
#  [59529.]
#  [59614.]
#  [59614.]
#  [59614.]
#  [59614.]
#  [59657.]
#  [59657.]
#  [59657.]
#  [59657.]
#  [59657.]
#  [59657.]
#  [59657.]
#  [59657.]
#  [59657.]
#  [59657.]
#  [59657.]
#  [60514.]
#  [60514.]
#  [60514.]
#  [60514.]
#  [60514.]
#  [59800.]
#  [59800.]
#  [59800.]
#  [59800.]
#  [59800.]
#  [59800.]
#  [59800.]
#  [59800.]
#  [59800.]
#  [59800.]
#  [59800.]
#  [59800.]
#  [59800.]
#  [59800.]
#  [59800.]
#  [59371.]
#  [59457.]
#  [59457.]
#  [59457.]
#  [59457.]
#  [59457.]
#  [59457.]
#  [59600.]
#  [59600.]
#  [59600.]
#  [59600.]
#  [59600.]
#  [59314.]
#  [59314.]
#  [59314.]
#  [59314.]
#  [59486.]
#  [60086.]
#  [60086.]
#  [60086.]
#  [60086.]
#  [60086.]
#  [59943.]
#  [59943.]
#  [59943.]
#  [59943.]
#  [59943.]
#  [60229.]
#  [60229.]
#  [60229.]
#  [60229.]
#  [60229.]
#  [57943.]
#  [57943.]
#  [57943.]
#  [57943.]
#  [57943.]
#  [57943.]
#  [57943.]
#  [57943.]
#  [57943.]
#  [57943.]
#  [58086.]
#  [58086.]
#  [58086.]
#  [58086.]
#  [60371.]
#  [60371.]
#  [60371.]
#  [60371.]
#  [60371.]
#  [60657.]
#  [60657.]
#  [60871.]
#  [60871.]
#  [61586.]
#  [61300.]
#  [61300.]
#  [61300.]
#  [61300.]
#  [61300.]
#  [61586.]
#  [61586.]
#  [61586.]
#  [60871.]
#  [60871.]
#  [60871.]
#  [60871.]
#  [60871.]
#  [60871.]
#  [60871.]
#  [60871.]
#  [60871.]
#  [60871.]
#  [60871.]
#  [60871.]
#  [60871.]
#  [61586.]
#  [61586.]
#  [61586.]
#  [61586.]
#  [61586.]
#  [60871.]
#  [61300.]
#  [61300.]
#  [61300.]
#  [61300.]
#  [61300.]
#  [61586.]
#  [61586.]
#  [61586.]
#  [61586.]
#  [61586.]
#  [61586.]
#  [61586.]
#  [61586.]
#  [61686.]
#  [61686.]
#  [61686.]
#  [61686.]
#  [61400.]
#  [61400.]
#  [61400.]
#  [61400.]
#  [61400.]
#  [61400.]
#  [61400.]
#  [61400.]
#  [61400.]
#  [61400.]
#  [61400.]
#  [61400.]
#  [61400.]
#  [61400.]
#  [61400.]
#  [59686.]
#  [59686.]
#  [59686.]
#  [59686.]
#  [59686.]
#  [59686.]
#  [59686.]
#  [59686.]
#  [59686.]
#  [60971.]
#  [60971.]
#  [60971.]
#  [60971.]
#  [61171.]
#  [58687.]
#  [58652.]
#  [58687.]
#  [57830.]
#  [57830.]
#  [58686.]
#  [57830.]
#  [57257.]
#  [55686.]
#  [55400.]
#  [54257.]
#  [54257.]
#  [54257.]
#  [54257.]
#  [54257.]
#  [54257.]
#  [54257.]
#  [54257.]
#  [53971.]
#  [53971.]
#  [53971.]
#  [53971.]
#  [53971.]
#  [53588.]
#  [53588.]
#  [54113.]
#  [54113.]
#  [52738.]
#  [53738.]
#  [53738.]
#  [53238.]
#  [53738.]
#  [53738.]
#  [55457.]
#  [55457.]
#  [55457.]
#  [55457.]
#  [54267.]
#  [54929.]
#  [54929.]
#  [54857.]
#  [54857.]
#  [54857.]
#  [54857.]
#  [54857.]
#  [54857.]
#  [54857.]
#  [54800.]
#  [54800.]
#  [54800.]
#  [54800.]
#  [54800.]
#  [54800.]
#  [54800.]
#  [54800.]
#  [54800.]
#  [54800.]
#  [54800.]
#  [54800.]
#  [54800.]
#  [54800.]
#  [54800.]
#  [54800.]
#  [54800.]
#  [54729.]
#  [54729.]
#  [54729.]
#  [54729.]
#  [54729.]
#  [54657.]
#  [54657.]
#  [54586.]
#  [54586.]
#  [54586.]
#  [54586.]
#  [54586.]
#  [54586.]
#  [54586.]
#  [54586.]
#  [54586.]
#  [54586.]
#  [54543.]
#  [54543.]
#  [54543.]
#  [54543.]
#  [54543.]
#  [53400.]
#  [52886.]
#  [52886.]
#  [51886.]
#  [51886.]
#  [51886.]
#  [51886.]
#  [51886.]
#  [51886.]
#  [51886.]
#  [51886.]
#  [51886.]
#  [51886.]
#  [51886.]
#  [51886.]
#  [51886.]
#  [51886.]
#  [51886.]
#  [51886.]
#  [51600.]
#  [51600.]
#  [51600.]
#  [51600.]
#  [51600.]
#  [51600.]
#  [51600.]
#  [51600.]
#  [51600.]
#  [51600.]
#  [51600.]
#  [51600.]
#  [51600.]
#  [51600.]
#  [51600.]
#  [51600.]
#  [51600.]
#  [51600.]
#  [51600.]
#  [51600.]
#  [51600.]
#  [51600.]
#  [51600.]
#  [51600.]
#  [51600.]
#  [51600.]
#  [51600.]
#  [51600.]
#  [51600.]
#  [51600.]
#  [51600.]
#  [51600.]
#  [51600.]
#  [51600.]
#  [51600.]
#  [52314.]
#  [51600.]
#  [50986.]
#  [50986.]
#  [50986.]
#  [50986.]
#  [50986.]
#  [50986.]
#  [50986.]
#  [50986.]
#  [50771.]
#  [50771.]
#  [50771.]
#  [50771.]
#  [50629.]
#  [50629.]
#  [50629.]
#  [50629.]
#  [50629.]
#  [50629.]
#  [50629.]
#  [50629.]
#  [50629.]
#  [50629.]
#  [49429.]
#  [49286.]
#  [49286.]
#  [49286.]
#  [49286.]
#  [49286.]
#  [49286.]
#  [49286.]
#  [49286.]
#  [50200.]
#  [50200.]
#  [50200.]
#  [49571.]
#  [49229.]
#  [49229.]
#  [49229.]
#  [49229.]
#  [49229.]
#  [49086.]
#  [49086.]
#  [49086.]
#  [49086.]
#  [49086.]
#  [49086.]
#  [49086.]
#  [49086.]
#  [49086.]
#  [49086.]
#  [49086.]
#  [49086.]
#  [49086.]
#  [49086.]
#  [49086.]
#  [49086.]
#  [49086.]
#  [49086.]
#  [48943.]
#  [48943.]
#  [48943.]
#  [48943.]
#  [48943.]
#  [48943.]
#  [48943.]
#  [48943.]
#  [48943.]
#  [48943.]
#  [48943.]
#  [48943.]
#  [48943.]
#  [48943.]
#  [48943.]
#  [48943.]
#  [48943.]
#  [48943.]
#  [48943.]
#  [48943.]
#  [48943.]
#  [48943.]
#  [48943.]
#  [48943.]
#  [48943.]
#  [48943.]
#  [48371.]
#  [48371.]
#  [48371.]
#  [47757.]
#  [47757.]
#  [47471.]
#  [47471.]
#  [47471.]
#  [47329.]
#  [46386.]
#  [46386.]
#  [46386.]
#  [46386.]
#  [46386.]
#  [44671.]
#  [44671.]
#  [44671.]
#  [44671.]
#  [44671.]
#  [46386.]
#  [46386.]
#  [46386.]
#  [46386.]
#  [46386.]
#  [46386.]
#  [46386.]
#  [46386.]
#  [46386.]
#  [46386.]
#  [46386.]
#  [45957.]] (476, 1)

# %%
plt.figure(figsize=(50,10))
plt.plot(testY_test, color = 'blue', label = 'Actual Stock Price')
plt.plot(predicted_price_test_test, color = 'red', label = 'Predicted Stock Price')

ax=plt.axes()
ax.xaxis.set_major_locator(ticker.MultipleLocator(100))
ax.yaxis.set_major_locator(ticker.MultipleLocator(1000))

plt.title('Price Prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   """

# %%
plt.figure(figsize=(50,10))
plt.plot(testY_test, color = 'blue', label = 'Actual Stock Price')
plt.plot(predicted_price_test_test, color = 'red', label = 'Predicted Stock Price')
plt.title('Price Prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error 
MSE = mean_squared_error(testY_test, predicted_price_test_test) 
np.sqrt(MSE)
# Out:
# 2299.868128425883

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(testY_test, predicted_price_test_test)
# Out:
# 1786.3184004070376

# %% [markdown]
# 예측방법

# %%
minX1 = np.array(dataX[0:7])
minX2 = np.array(dataX[0:8])
minX3 = np.array(dataX[0:2380])
minX4 = np.array(dataX[0:train_size])

# %%
predicted_price_min1 = model.predict(minX1, batch_size=a, verbose=1)
predicted_price_min2 = model.predict(minX2, batch_size=a, verbose=1) 
predicted_price_min3 = model.predict(minX3, batch_size=a, verbose=1)
predicted_price_min4 = model.predict(minX4, batch_size=a, verbose=1)
# Out:
# 1/1 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 1s 8ms/step
# 340/340 [==============================] - 1s 2ms/step
# 204/204 [==============================] - 1s 2ms/step

# %%
predicted_price_min1[0]
# Out:
# array([[0.48515505],
#        [0.4817613 ],
#        [0.47928956],
#        [0.48169646],
#        [0.4798974 ],
#        [0.47687632],
#        [0.4739542 ]], dtype=float32)

# %%
predicted_price_min2[0]
# Out:
# array([[0.47402796],
#        [0.4678072 ],
#        [0.46776146],
#        [0.46782738],
#        [0.46895152],
#        [0.46831125],
#        [0.46322602]], dtype=float32)

# %%
predicted_price_min3[0]
# Out:
# array([[0.46225756],
#        [0.45585722],
#        [0.4581593 ],
#        [0.4574445 ],
#        [0.46009022],
#        [0.4608909 ],
#        [0.4546368 ]], dtype=float32)

# %%
scaler_target.inverse_transform(predicted_price_min4[0].reshape(-1,1))
# Out:
# array([[46453.8  ],
#        [46353.39 ],
#        [46280.26 ],
#        [46351.473],
#        [46298.242],
#        [46208.863],
#        [46122.41 ]], dtype=float32)
