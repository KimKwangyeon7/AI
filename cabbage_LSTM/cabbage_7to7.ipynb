# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import random
import os

# %%
def my_seed_everywhere(seed: int = 42):
    random.seed(seed) # random
    np.random.seed(seed) # np
    os.environ["PYTHONHASHSEED"] = str(seed) # os
    tf.random.set_seed(seed) # tensorflow

my_seed = 42
my_seed_everywhere(my_seed)

# %%
df = pd.read_csv('/content/sample_data/cabbage_final.csv', index_col=0)
df = df.dropna(axis=0)
df = df.reset_index(drop=True)
df['Date'] = pd.to_datetime(df['Date'])
df['DayOfWeek'] = df['Date'].dt.dayofweek

# %%
df = df.drop(['Temp'],axis=1)
df = df.drop(['Oil'],axis=1)
df = df.drop(['Sup'],axis=1)
df = df.drop(['Avg_Price'], axis=1)

df['DayOfWeek'] = df['DayOfWeek'].astype('category')
df = pd.get_dummies(df, columns =['DayOfWeek'], prefix='W', drop_first=True)

df.tail()
# Out:
#            Date  Rain  Wind  sobimul  nongmul   Price  Produced  W_1  W_2  \
# 2390 2022-09-26   0.0   1.7      2.5      8.7  8547.0   2017507    0    0
# 2391 2022-09-27   0.0   1.6      2.5      8.7  8196.0   2017507    1    0
# 2392 2022-09-28   0.0   1.8      2.5      8.7  7912.0   2017507    0    1
# 2393 2022-09-29   0.0   1.4      2.5      8.7  8052.0   2017507    0    0
# 2394 2022-09-30   0.0   1.6      2.5      8.7  8112.0   2017507    0    0
#
#       W_3  W_4
# 2390    0    0
# 2391    0    0
# 2392    0    0
# 2393    1    0
# 2394    0    1

# %%
from sklearn.preprocessing import MinMaxScaler
input_indicator = df.loc[:,['Rain', 'Wind', 'sobimul', 'nongmul', 'Produced', 'W_1', 'W_2', 'W_3', 'W_4']]
target_indicator = df.loc[:,['Price']].values[:]

scaler_input = MinMaxScaler()
scaler_target = MinMaxScaler()
scaled_input_indicator = scaler_input.fit_transform(input_indicator)
scaled_target_indicator = scaler_target.fit_transform(target_indicator) # 가격 관련 지표에 스케일링

x = np.concatenate((scaled_target_indicator, scaled_input_indicator), axis=1)
y = x[:, [0]]

print(x)
print(y.shape)
# Out:
# [[0.22860209 0.         0.61403509 ... 1.         0.         0.        ]
#  [0.2345944  0.         0.36842105 ... 0.         1.         0.        ]
#  [0.23119578 0.         0.19298246 ... 0.         0.         1.        ]
#  ...
#  [0.56882211 0.         0.19298246 ... 1.         0.         0.        ]
#  [0.58134335 0.         0.12280702 ... 0.         1.         0.        ]
#  [0.5867096  0.         0.15789474 ... 0.         0.         1.        ]]
# (2395, 1)

# %%
# 7일치의 input으로 7일치의 output을 생산
seq_length = 7
predict_day = 7
dataX = [] 
dataY = [] 
for i in range(0, int(len(y) - seq_length - predict_day)):
    _x = x[i : i + seq_length]
    _y = y[i + predict_day : i + seq_length + predict_day] 
    dataX.append(_x) 
    dataY.append(_y) 
print(len(dataX))
print(len(dataY))
# Out:
# 2381
# 2381

# %%
# 7의 배수로 설정해야 batch에서 오류가 발생하지 않음
train_size = 1428
validation_size = 476
test_size = 476

trainX = np.array(dataX[0:train_size])
trainY = np.array(dataY[0:train_size])
validX = np.array(dataX[train_size:train_size+validation_size])
validY = np.array(dataY[train_size:train_size+validation_size])
testX = np.array(dataX[train_size+validation_size:train_size+validation_size+test_size])
testY = np.array(dataY[train_size+validation_size:train_size+validation_size+test_size])

print(trainX.shape)
print(trainY.shape)
print(validX.shape)
print(validY.shape)
print(testX.shape)
print(testY.shape)
# Out:
# (1428, 7, 10)
# (1428, 7, 1)
# (476, 7, 10)
# (476, 7, 1)
# (476, 7, 10)
# (476, 7, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, Activation
from tensorflow import keras

# %%
class CustomHistory(keras.callbacks.Callback):
    def init(self):
        self.train_loss = []
        self.val_loss = []
        
    def on_epoch_end(self, batch, logs={}):
        self.train_loss.append(logs.get('loss'))
        self.val_loss.append(logs.get('val_loss'))

# %%
input_columns = 10 # 데이터 셋의 '열' 개수 (dataX) / dataset's columns (dataX)

model = Sequential()
model.add(LSTM(16, batch_input_shape=(7, 7, input_columns), return_sequences=True, stateful=True, dropout=0.1))
model.add(LSTM(16, return_sequences=True, stateful=True, dropout=0.1))
model.add(Dense(1))
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_8 (LSTM)               (7, 7, 16)                1728
#
#  lstm_9 (LSTM)               (7, 7, 16)                2112
#
#  dense_4 (Dense)             (7, 7, 1)                 17
#
# =================================================================
# Total params: 3,857
# Trainable params: 3,857
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping
checkpoint_cb = keras.callbacks.ModelCheckpoint('best-model-cabbage.h5', save_best_only=True)
early_stopping_cb = keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=5, restore_best_weights=True)

# %%
keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %%
custom_hist = CustomHistory()
custom_hist.init()

# %%
for epoch_idx in range(100):
  print('epochs:' + str(epoch_idx))
  hist = model.fit(trainX, trainY, validation_data=(validX, validY), epochs=1, batch_size=7, verbose=2, shuffle=False, callbacks=[checkpoint_cb, custom_hist, early_stopping_cb])
  model.reset_states()
# Out:
# epochs:0
# 204/204 - 4s - loss: 0.0024 - mae: 0.0342 - val_loss: 0.0117 - val_mae: 0.0617 - 4s/epoch - 20ms/step
# epochs:1
# 204/204 - 1s - loss: 0.0025 - mae: 0.0359 - val_loss: 0.0082 - val_mae: 0.0551 - 1s/epoch - 6ms/step
# epochs:2
# 204/204 - 1s - loss: 0.0025 - mae: 0.0354 - val_loss: 0.0126 - val_mae: 0.0662 - 1s/epoch - 5ms/step
# epochs:3
# 204/204 - 1s - loss: 0.0032 - mae: 0.0400 - val_loss: 0.0078 - val_mae: 0.0553 - 1s/epoch - 6ms/step
# epochs:4
# 204/204 - 2s - loss: 0.0024 - mae: 0.0344 - val_loss: 0.0121 - val_mae: 0.0646 - 2s/epoch - 11ms/step
# epochs:5
# 204/204 - 1s - loss: 0.0025 - mae: 0.0349 - val_loss: 0.0079 - val_mae: 0.0498 - 1s/epoch - 7ms/step
# epochs:6
# 204/204 - 1s - loss: 0.0024 - mae: 0.0343 - val_loss: 0.0061 - val_mae: 0.0472 - 1s/epoch - 6ms/step
# epochs:7
# 204/204 - 1s - loss: 0.0024 - mae: 0.0345 - val_loss: 0.0078 - val_mae: 0.0542 - 1s/epoch - 5ms/step
# epochs:8
# 204/204 - 1s - loss: 0.0024 - mae: 0.0350 - val_loss: 0.0097 - val_mae: 0.0592 - 1s/epoch - 6ms/step
# epochs:9
# 204/204 - 1s - loss: 0.0021 - mae: 0.0328 - val_loss: 0.0089 - val_mae: 0.0561 - 979ms/epoch - 5ms/step
# epochs:10
# 204/204 - 1s - loss: 0.0074 - mae: 0.0575 - val_loss: 0.0110 - val_mae: 0.0689 - 1s/epoch - 5ms/step
# epochs:11
# 204/204 - 1s - loss: 0.0031 - mae: 0.0390 - val_loss: 0.0082 - val_mae: 0.0580 - 1s/epoch - 5ms/step
# epochs:12
# 204/204 - 1s - loss: 0.0026 - mae: 0.0351 - val_loss: 0.0084 - val_mae: 0.0534 - 1s/epoch - 6ms/step
# epochs:13
# 204/204 - 1s - loss: 0.0025 - mae: 0.0343 - val_loss: 0.0076 - val_mae: 0.0496 - 999ms/epoch - 5ms/step
# epochs:14
# 204/204 - 1s - loss: 0.0023 - mae: 0.0330 - val_loss: 0.0070 - val_mae: 0.0501 - 969ms/epoch - 5ms/step
# epochs:15
# 204/204 - 1s - loss: 0.0024 - mae: 0.0333 - val_loss: 0.0067 - val_mae: 0.0460 - 1s/epoch - 5ms/step
# epochs:16
# 204/204 - 1s - loss: 0.0023 - mae: 0.0327 - val_loss: 0.0068 - val_mae: 0.0539 - 991ms/epoch - 5ms/step
# epochs:17
# 204/204 - 1s - loss: 0.0023 - mae: 0.0340 - val_loss: 0.0058 - val_mae: 0.0512 - 1s/epoch - 5ms/step
# epochs:18
# 204/204 - 1s - loss: 0.0021 - mae: 0.0325 - val_loss: 0.0053 - val_mae: 0.0473 - 998ms/epoch - 5ms/step
# epochs:19
# 204/204 - 1s - loss: 0.0021 - mae: 0.0326 - val_loss: 0.0056 - val_mae: 0.0499 - 972ms/epoch - 5ms/step
# epochs:20
# 204/204 - 1s - loss: 0.0022 - mae: 0.0339 - val_loss: 0.0073 - val_mae: 0.0516 - 986ms/epoch - 5ms/step
# epochs:21
# 204/204 - 1s - loss: 0.0020 - mae: 0.0322 - val_loss: 0.0073 - val_mae: 0.0584 - 1000ms/epoch - 5ms/step
# epochs:22
# 204/204 - 1s - loss: 0.0020 - mae: 0.0331 - val_loss: 0.0065 - val_mae: 0.0503 - 972ms/epoch - 5ms/step
# epochs:23
# 204/204 - 1s - loss: 0.0022 - mae: 0.0333 - val_loss: 0.0051 - val_mae: 0.0428 - 1s/epoch - 5ms/step
# epochs:24
# 204/204 - 1s - loss: 0.0020 - mae: 0.0325 - val_loss: 0.0111 - val_mae: 0.0640 - 976ms/epoch - 5ms/step
# epochs:25
# 204/204 - 1s - loss: 0.0020 - mae: 0.0329 - val_loss: 0.0095 - val_mae: 0.0712 - 1s/epoch - 5ms/step
# epochs:26
# 204/204 - 1s - loss: 0.0020 - mae: 0.0326 - val_loss: 0.0065 - val_mae: 0.0571 - 1s/epoch - 6ms/step
# epochs:27
# 204/204 - 1s - loss: 0.0022 - mae: 0.0334 - val_loss: 0.0185 - val_mae: 0.0771 - 980ms/epoch - 5ms/step
# epochs:28
# 204/204 - 1s - loss: 0.0027 - mae: 0.0367 - val_loss: 0.0092 - val_mae: 0.0546 - 1s/epoch - 6ms/step
# epochs:29
# 204/204 - 1s - loss: 0.0023 - mae: 0.0325 - val_loss: 0.0108 - val_mae: 0.0609 - 1s/epoch - 6ms/step
# epochs:30
# 204/204 - 1s - loss: 0.0019 - mae: 0.0315 - val_loss: 0.0083 - val_mae: 0.0577 - 987ms/epoch - 5ms/step
# epochs:31
# 204/204 - 1s - loss: 0.0022 - mae: 0.0336 - val_loss: 0.0091 - val_mae: 0.0539 - 1s/epoch - 5ms/step
# epochs:32
# 204/204 - 1s - loss: 0.0020 - mae: 0.0309 - val_loss: 0.0078 - val_mae: 0.0563 - 1s/epoch - 5ms/step
# epochs:33
# 204/204 - 1s - loss: 0.0020 - mae: 0.0337 - val_loss: 0.0078 - val_mae: 0.0517 - 990ms/epoch - 5ms/step
# epochs:34
# 204/204 - 1s - loss: 0.0020 - mae: 0.0311 - val_loss: 0.0071 - val_mae: 0.0562 - 967ms/epoch - 5ms/step
# epochs:35
# 204/204 - 1s - loss: 0.0023 - mae: 0.0340 - val_loss: 0.0079 - val_mae: 0.0545 - 984ms/epoch - 5ms/step
# epochs:36
# 204/204 - 1s - loss: 0.0023 - mae: 0.0330 - val_loss: 0.0223 - val_mae: 0.0759 - 1s/epoch - 6ms/step
# epochs:37
# 204/204 - 1s - loss: 0.0022 - mae: 0.0330 - val_loss: 0.0087 - val_mae: 0.0502 - 1s/epoch - 6ms/step
# epochs:38
# 204/204 - 1s - loss: 0.0023 - mae: 0.0331 - val_loss: 0.0214 - val_mae: 0.0723 - 1s/epoch - 5ms/step
# epochs:39
# 204/204 - 1s - loss: 0.0022 - mae: 0.0322 - val_loss: 0.0139 - val_mae: 0.0627 - 982ms/epoch - 5ms/step
# epochs:40
# 204/204 - 1s - loss: 0.0024 - mae: 0.0329 - val_loss: 0.0207 - val_mae: 0.0725 - 975ms/epoch - 5ms/step
# epochs:41
# 204/204 - 1s - loss: 0.0021 - mae: 0.0315 - val_loss: 0.0115 - val_mae: 0.0640 - 997ms/epoch - 5ms/step
# epochs:42
# 204/204 - 1s - loss: 0.0018 - mae: 0.0311 - val_loss: 0.0111 - val_mae: 0.0595 - 1s/epoch - 6ms/step
# epochs:43
# 204/204 - 1s - loss: 0.0017 - mae: 0.0299 - val_loss: 0.0097 - val_mae: 0.0605 - 973ms/epoch - 5ms/step
# epochs:44
# 204/204 - 1s - loss: 0.0017 - mae: 0.0294 - val_loss: 0.0116 - val_mae: 0.0773 - 967ms/epoch - 5ms/step
# epochs:45
# 204/204 - 1s - loss: 0.0017 - mae: 0.0305 - val_loss: 0.0123 - val_mae: 0.0784 - 1s/epoch - 5ms/step
# epochs:46
# 204/204 - 1s - loss: 0.0025 - mae: 0.0378 - val_loss: 0.0136 - val_mae: 0.0652 - 988ms/epoch - 5ms/step
# epochs:47
# 204/204 - 1s - loss: 0.0027 - mae: 0.0343 - val_loss: 0.0129 - val_mae: 0.0651 - 973ms/epoch - 5ms/step
# epochs:48
# 204/204 - 1s - loss: 0.0021 - mae: 0.0312 - val_loss: 0.0171 - val_mae: 0.0717 - 1s/epoch - 5ms/step
# epochs:49
# 204/204 - 1s - loss: 0.0021 - mae: 0.0314 - val_loss: 0.0111 - val_mae: 0.0667 - 1s/epoch - 5ms/step
# epochs:50
# 204/204 - 1s - loss: 0.0018 - mae: 0.0298 - val_loss: 0.0123 - val_mae: 0.0699 - 988ms/epoch - 5ms/step
# epochs:51
# 204/204 - 1s - loss: 0.0020 - mae: 0.0317 - val_loss: 0.0124 - val_mae: 0.0617 - 1s/epoch - 5ms/step
# epochs:52
# 204/204 - 1s - loss: 0.0019 - mae: 0.0305 - val_loss: 0.0145 - val_mae: 0.0775 - 1s/epoch - 6ms/step
# epochs:53
# 204/204 - 1s - loss: 0.0017 - mae: 0.0298 - val_loss: 0.0133 - val_mae: 0.0732 - 1s/epoch - 7ms/step
# epochs:54
# 204/204 - 1s - loss: 0.0019 - mae: 0.0309 - val_loss: 0.0190 - val_mae: 0.0964 - 979ms/epoch - 5ms/step
# epochs:55
# 204/204 - 1s - loss: 0.0019 - mae: 0.0300 - val_loss: 0.0118 - val_mae: 0.0701 - 1s/epoch - 5ms/step
# epochs:56
# 204/204 - 1s - loss: 0.0016 - mae: 0.0284 - val_loss: 0.0108 - val_mae: 0.0667 - 981ms/epoch - 5ms/step
# epochs:57
# 204/204 - 1s - loss: 0.0015 - mae: 0.0280 - val_loss: 0.0141 - val_mae: 0.0843 - 1s/epoch - 5ms/step
# epochs:58
# 204/204 - 1s - loss: 0.0015 - mae: 0.0274 - val_loss: 0.0104 - val_mae: 0.0697 - 989ms/epoch - 5ms/step
# epochs:59
# 204/204 - 1s - loss: 0.0017 - mae: 0.0288 - val_loss: 0.0116 - val_mae: 0.0697 - 981ms/epoch - 5ms/step
# epochs:60
# 204/204 - 1s - loss: 0.0017 - mae: 0.0293 - val_loss: 0.0154 - val_mae: 0.0792 - 998ms/epoch - 5ms/step
# epochs:61
# 204/204 - 1s - loss: 0.0017 - mae: 0.0289 - val_loss: 0.0137 - val_mae: 0.0692 - 998ms/epoch - 5ms/step
# epochs:62
# 204/204 - 1s - loss: 0.0017 - mae: 0.0284 - val_loss: 0.0138 - val_mae: 0.0862 - 1s/epoch - 5ms/step
# epochs:63
# 204/204 - 1s - loss: 0.0023 - mae: 0.0330 - val_loss: 0.0091 - val_mae: 0.0612 - 1s/epoch - 6ms/step
# epochs:64
# 204/204 - 1s - loss: 0.0026 - mae: 0.0367 - val_loss: 0.0121 - val_mae: 0.0702 - 995ms/epoch - 5ms/step
# epochs:65
# 204/204 - 1s - loss: 0.0027 - mae: 0.0363 - val_loss: 0.0102 - val_mae: 0.0558 - 1s/epoch - 5ms/step
# epochs:66
# 204/204 - 1s - loss: 0.0024 - mae: 0.0325 - val_loss: 0.0124 - val_mae: 0.0700 - 975ms/epoch - 5ms/step
# epochs:67
# 204/204 - 1s - loss: 0.0023 - mae: 0.0331 - val_loss: 0.0100 - val_mae: 0.0566 - 994ms/epoch - 5ms/step
# epochs:68
# 204/204 - 1s - loss: 0.0017 - mae: 0.0295 - val_loss: 0.0089 - val_mae: 0.0637 - 977ms/epoch - 5ms/step
# epochs:69
# 204/204 - 1s - loss: 0.0015 - mae: 0.0276 - val_loss: 0.0135 - val_mae: 0.0806 - 1s/epoch - 5ms/step
# epochs:70
# 204/204 - 1s - loss: 0.0016 - mae: 0.0283 - val_loss: 0.0104 - val_mae: 0.0666 - 973ms/epoch - 5ms/step
# epochs:71
# 204/204 - 1s - loss: 0.0017 - mae: 0.0293 - val_loss: 0.0089 - val_mae: 0.0549 - 982ms/epoch - 5ms/step
# epochs:72
# 204/204 - 1s - loss: 0.0016 - mae: 0.0283 - val_loss: 0.0102 - val_mae: 0.0649 - 1s/epoch - 6ms/step
# epochs:73
# 204/204 - 1s - loss: 0.0014 - mae: 0.0270 - val_loss: 0.0099 - val_mae: 0.0614 - 1s/epoch - 6ms/step
# epochs:74
# 204/204 - 1s - loss: 0.0014 - mae: 0.0268 - val_loss: 0.0092 - val_mae: 0.0610 - 986ms/epoch - 5ms/step
# epochs:75
# 204/204 - 1s - loss: 0.0015 - mae: 0.0279 - val_loss: 0.0114 - val_mae: 0.0728 - 985ms/epoch - 5ms/step
# epochs:76
# 204/204 - 1s - loss: 0.0017 - mae: 0.0296 - val_loss: 0.0122 - val_mae: 0.0793 - 1s/epoch - 6ms/step
# epochs:77
# 204/204 - 1s - loss: 0.0018 - mae: 0.0314 - val_loss: 0.0147 - val_mae: 0.0644 - 977ms/epoch - 5ms/step
# epochs:78
# 204/204 - 1s - loss: 0.0022 - mae: 0.0315 - val_loss: 0.0127 - val_mae: 0.0704 - 1s/epoch - 6ms/step
# epochs:79
# 204/204 - 1s - loss: 0.0024 - mae: 0.0342 - val_loss: 0.0118 - val_mae: 0.0613 - 981ms/epoch - 5ms/step
# epochs:80
# 204/204 - 1s - loss: 0.0018 - mae: 0.0301 - val_loss: 0.0118 - val_mae: 0.0636 - 991ms/epoch - 5ms/step
# epochs:81
# 204/204 - 1s - loss: 0.0016 - mae: 0.0287 - val_loss: 0.0102 - val_mae: 0.0677 - 984ms/epoch - 5ms/step
# epochs:82
# 204/204 - 1s - loss: 0.0014 - mae: 0.0269 - val_loss: 0.0095 - val_mae: 0.0664 - 1s/epoch - 5ms/step
# epochs:83
# 204/204 - 1s - loss: 0.0014 - mae: 0.0271 - val_loss: 0.0115 - val_mae: 0.0753 - 1s/epoch - 6ms/step
# epochs:84
# 204/204 - 1s - loss: 0.0014 - mae: 0.0274 - val_loss: 0.0092 - val_mae: 0.0636 - 968ms/epoch - 5ms/step
# epochs:85
# 204/204 - 1s - loss: 0.0015 - mae: 0.0272 - val_loss: 0.0112 - val_mae: 0.0699 - 982ms/epoch - 5ms/step
# epochs:86
# 204/204 - 1s - loss: 0.0021 - mae: 0.0304 - val_loss: 0.0134 - val_mae: 0.0735 - 985ms/epoch - 5ms/step
# epochs:87
# 204/204 - 1s - loss: 0.0022 - mae: 0.0320 - val_loss: 0.0108 - val_mae: 0.0637 - 1s/epoch - 5ms/step
# epochs:88
# 204/204 - 1s - loss: 0.0021 - mae: 0.0333 - val_loss: 0.0154 - val_mae: 0.0702 - 978ms/epoch - 5ms/step
# epochs:89
# 204/204 - 1s - loss: 0.0016 - mae: 0.0288 - val_loss: 0.0116 - val_mae: 0.0719 - 1s/epoch - 5ms/step
# epochs:90
# 204/204 - 1s - loss: 0.0015 - mae: 0.0277 - val_loss: 0.0161 - val_mae: 0.0872 - 979ms/epoch - 5ms/step
# epochs:91
# 204/204 - 1s - loss: 0.0019 - mae: 0.0314 - val_loss: 0.0111 - val_mae: 0.0657 - 1s/epoch - 6ms/step
# epochs:92
# 204/204 - 1s - loss: 0.0015 - mae: 0.0276 - val_loss: 0.0107 - val_mae: 0.0725 - 972ms/epoch - 5ms/step
# epochs:93
# 204/204 - 1s - loss: 0.0014 - mae: 0.0265 - val_loss: 0.0117 - val_mae: 0.0763 - 979ms/epoch - 5ms/step
# epochs:94
# 204/204 - 1s - loss: 0.0016 - mae: 0.0288 - val_loss: 0.0149 - val_mae: 0.0633 - 997ms/epoch - 5ms/step
# epochs:95
# 204/204 - 1s - loss: 0.0016 - mae: 0.0287 - val_loss: 0.0126 - val_mae: 0.0688 - 981ms/epoch - 5ms/step
# epochs:96
# 204/204 - 1s - loss: 0.0016 - mae: 0.0278 - val_loss: 0.0138 - val_mae: 0.0780 - 984ms/epoch - 5ms/step
# epochs:97
# 204/204 - 1s - loss: 0.0016 - mae: 0.0283 - val_loss: 0.0156 - val_mae: 0.0621 - 966ms/epoch - 5ms/step
# epochs:98
# 204/204 - 1s - loss: 0.0015 - mae: 0.0276 - val_loss: 0.0157 - val_mae: 0.0715 - 979ms/epoch - 5ms/step
# epochs:99
# 204/204 - 1s - loss: 0.0022 - mae: 0.0317 - val_loss: 0.0114 - val_mae: 0.0722 - 972ms/epoch - 5ms/step

# %%
a = 7

# %%
model.evaluate(trainX, trainY, batch_size = a)
# Out:
# 204/204 [==============================] - 1s 3ms/step - loss: 0.0028 - mae: 0.0357
# [0.0027857411187142134, 0.0357191264629364]

# %%
print(custom_hist.train_loss)
# Out:
# [0.0024088581558316946, 0.002547487383708358, 0.0024731741286814213, 0.0031606380362063646, 0.002416197443380952, 0.0024732821621000767, 0.002411327324807644, 0.0024495187681168318, 0.0024219872429966927, 0.0021410800982266665, 0.007354819681495428, 0.003063358599320054, 0.0025908155366778374, 0.002488390076905489, 0.0023099989630281925, 0.0023682168684899807, 0.0022506550885736942, 0.0023498667869716883, 0.002092892536893487, 0.002141812117770314, 0.002169395098462701, 0.0019880044274032116, 0.002040738007053733, 0.0021727571729570627, 0.001992185600101948, 0.002031739102676511, 0.0019692780915647745, 0.0022107292897999287, 0.002713011810556054, 0.0022679935209453106, 0.0018982448382303119, 0.0021813404746353626, 0.001951657235622406, 0.002049861242994666, 0.001988940639421344, 0.0023114364594221115, 0.0022659762762486935, 0.0022305890452116728, 0.002338505582883954, 0.0022054421715438366, 0.00244313501752913, 0.002084058942273259, 0.001814960385672748, 0.0017425824189558625, 0.0016896174056455493, 0.0017474867636337876, 0.0025294709485024214, 0.002684773877263069, 0.0021326388232409954, 0.00213485024869442, 0.0017952189082279801, 0.0019579739309847355, 0.0018812090856954455, 0.0017102983547374606, 0.0019039777107536793, 0.0018778940429911017, 0.0016279771225526929, 0.001538202166557312, 0.0015025673201307654, 0.001675022067502141, 0.0016957379411906004, 0.0016762298764660954, 0.0017047337023541331, 0.002324535744264722, 0.0025697110686451197, 0.0026695390697568655, 0.0024221925996243954, 0.002264975802972913, 0.0017363866791129112, 0.0015258919447660446, 0.0015911763766780496, 0.0016999378567561507, 0.0016252426430583, 0.001436377759091556, 0.001406388240866363, 0.0014850692823529243, 0.0017128079198300838, 0.0018039928982034326, 0.0022162070963531733, 0.0024167231749743223, 0.00178432313259691, 0.0016193719347938895, 0.0014098878018558025, 0.001449166564270854, 0.0014202342135831714, 0.0014763001818209887, 0.0020775056909769773, 0.002182869939133525, 0.002140733180567622, 0.0016047455137595534, 0.001543137594126165, 0.001857403782196343, 0.0015437991824001074, 0.001357986475341022, 0.0015677552437409759, 0.0015953279798850417, 0.001567607861943543, 0.0015707332640886307, 0.0014944530557841063, 0.0021588837262243032]

# %%
plt.figure(figsize=(20,10))
plt.plot(custom_hist.train_loss, color = 'blue', label = 'train_loss')
plt.plot(custom_hist.val_loss, color = 'red', label = 'val_loss')
plt.title('Training Loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
from keras.models import load_model
model = load_model('/content/best-model-cabbage.h5')

# %% [markdown]
# Train Data *평가*

# %%
model.evaluate(trainX, trainY, batch_size=a)
# Out:
# 204/204 [==============================] - 1s 3ms/step - loss: 0.0019 - mae: 0.0310
# [0.0018876452231779695, 0.031016215682029724]

# %%
predicted_price_train = model.predict(trainX, batch_size=a, verbose=1)
# Out:
# 204/204 [==============================] - 1s 2ms/step

# %%
trainY_test = np.delete(trainY, np.s_[1:a], axis=1)
predicted_price_train_test = np.delete(predicted_price_train, np.s_[1:a], axis=1)

trainY_test = np.reshape(trainY_test, (1428, 1))
predicted_price_train_test = np.reshape(predicted_price_train_test, (1428, 1))
print(trainY_test.shape)
print(predicted_price_train_test.shape)
# Out:
# (1428, 1)
# (1428, 1)

# %%
plt.figure(figsize=(20,10))
plt.plot(trainY_test, color = 'blue', label = 'Actual Stock Price')
plt.plot(predicted_price_train_test, color = 'red', label = 'Predicted Stock Price')
plt.title('Price Prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
predicted_price_train_test = np.reshape(predicted_price_train_test, (1428, ))
predicted_price_train_test = scaler_target.inverse_transform(predicted_price_train_test.reshape(-1,1))

print(predicted_price_train_test, predicted_price_train_test.shape)

trainY_test = scaler_target.inverse_transform(trainY_test.reshape(-1,1))

print(trainY_test, trainY_test.shape)
# Out:
# [[3636.1414]
#  [3742.6855]
#  [3772.9058]
#  ...
#  [3534.3132]
#  [3527.0742]
#  [3538.6267]] (1428, 1)
# [[4333.]
#  [4167.]
#  [4167.]
#  ...
#  [3232.]
#  [3212.]
#  [3255.]] (1428, 1)

# %%
from sklearn.metrics import mean_squared_error 
MSE = mean_squared_error(trainY_test, predicted_price_train_test) 
np.sqrt(MSE)
# Out:
# 484.5749620382283

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(trainY_test, predicted_price_train_test)
# Out:
# 345.5061854087338

# %% [markdown]
# Val Date 평가

# %%
model.evaluate(validX, validY, batch_size=a)
# Out:
# 68/68 [==============================] - 0s 3ms/step - loss: 0.0051 - mae: 0.0427
# [0.005102522671222687, 0.04268584027886391]

# %%
predicted_price_valid = model.predict(validX, batch_size=a, verbose=1)
# Out:
# 68/68 [==============================] - 0s 2ms/step

# %%
validY_test = np.delete(validY, np.s_[1:a], axis=1)
predicted_price_valid_test = np.delete(predicted_price_valid, np.s_[1:a], axis=1)

validY_test = np.reshape(validY_test, (476, 1))
predicted_price_valid_test = np.reshape(predicted_price_valid_test, (476, 1))
print(validY_test.shape)
print(predicted_price_valid_test.shape)

plt.figure(figsize=(20,10))
plt.plot(validY_test, color = 'blue', label = 'Actual Stock Price')
plt.plot(predicted_price_valid_test, color = 'red', label = 'Predicted Stock Price')
plt.title('Price Prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# (476, 1)
# (476, 1)

# %%
predicted_price_valid_test = np.reshape(predicted_price_valid_test, (476, ))
predicted_price_valid_test = scaler_target.inverse_transform(predicted_price_valid_test.reshape(-1,1))

print(predicted_price_valid_test, predicted_price_valid_test.shape)

validY_test = scaler_target.inverse_transform(validY_test.reshape(-1,1))

print(validY_test, validY_test.shape)
# Out:
# [[ 8651.784 ]
#  [ 8516.287 ]
#  [ 8435.982 ]
#  [ 8193.32  ]
#  [ 7671.6934]
#  [ 6947.218 ]
#  [ 6147.2695]
#  [ 2847.0364]
#  [ 2696.811 ]
#  [ 2731.0469]
#  [ 2588.073 ]
#  [ 2477.489 ]
#  [ 2376.535 ]
#  [ 2329.9568]
#  [ 2450.5947]
#  [ 2426.3936]
#  [ 2440.825 ]
#  [ 2441.2166]
#  [ 2495.098 ]
#  [ 2530.2517]
#  [ 2526.1282]
#  [ 2905.2734]
#  [ 2925.4204]
#  [ 2868.4194]
#  [ 2858.8577]
#  [ 2818.821 ]
#  [ 2819.1887]
#  [ 2826.5444]
#  [ 2965.3   ]
#  [ 2904.0596]
#  [ 2878.9497]
#  [ 2895.4895]
#  [ 2883.24  ]
#  [ 2857.1243]
#  [ 2789.4934]
#  [ 2801.1929]
#  [ 2767.3433]
#  [ 2709.3918]
#  [ 2595.4785]
#  [ 2578.012 ]
#  [ 2601.5417]
#  [ 2610.467 ]
#  [ 2563.157 ]
#  [ 2584.5317]
#  [ 2639.8557]
#  [ 2647.2524]
#  [ 2656.3328]
#  [ 2604.9692]
#  [ 2629.1016]
#  [ 2677.5393]
#  [ 2680.484 ]
#  [ 2685.5452]
#  [ 2636.2048]
#  [ 2631.9146]
#  [ 2657.7039]
#  [ 2654.4822]
#  [ 2616.832 ]
#  [ 2548.7246]
#  [ 2522.276 ]
#  [ 2539.8535]
#  [ 2527.561 ]
#  [ 2491.5737]
#  [ 2444.765 ]
#  [ 2462.107 ]
#  [ 2493.0198]
#  [ 2596.4055]
#  [ 2594.6743]
#  [ 2574.8262]
#  [ 2552.8171]
#  [ 2518.0024]
#  [ 2482.6543]
#  [ 2490.6782]
#  [ 2479.2239]
#  [ 2459.6348]
#  [ 2407.945 ]
#  [ 2385.9294]
#  [ 2402.824 ]
#  [ 2409.8108]
#  [ 2399.1265]
#  [ 2359.4663]
#  [ 2370.2642]
#  [ 2391.8538]
#  [ 2419.5508]
#  [ 2407.0667]
#  [ 2423.2537]
#  [ 2452.1438]
#  [ 2452.9282]
#  [ 2444.6143]
#  [ 2426.8489]
#  [ 2401.873 ]
#  [ 2424.2363]
#  [ 2420.2986]
#  [ 2406.341 ]
#  [ 2379.781 ]
#  [ 2396.0955]
#  [ 2422.256 ]
#  [ 2422.728 ]
#  [ 2400.8948]
#  [ 2373.152 ]
#  [ 2351.095 ]
#  [ 2373.1494]
#  [ 2379.8616]
#  [ 2364.3547]
#  [ 2337.0342]
#  [ 2323.4043]
#  [ 2353.4827]
#  [ 2361.5178]
#  [ 2361.293 ]
#  [ 2342.6414]
#  [ 2351.917 ]
#  [ 2395.1204]
#  [ 2407.35  ]
#  [ 2397.9915]
#  [ 2360.674 ]
#  [ 2367.3464]
#  [ 2403.9116]
#  [ 2386.6787]
#  [ 2354.4001]
#  [ 2306.0183]
#  [ 2315.7317]
#  [ 2368.3767]
#  [ 2381.5361]
#  [ 2390.0525]
#  [ 2382.413 ]
#  [ 2412.3586]
#  [ 2501.0913]
#  [ 2521.7976]
#  [ 2576.3943]
#  [ 2642.9028]
#  [ 2659.3132]
#  [ 2686.7754]
#  [ 2659.264 ]
#  [ 2713.1633]
#  [ 2793.991 ]
#  [ 2819.3008]
#  [ 2734.0154]
#  [ 2631.0984]
#  [ 2539.6907]
#  [ 2534.8088]
#  [ 2490.8726]
#  [ 2405.8462]
#  [ 2304.6377]
#  [ 2339.2078]
#  [ 2418.9846]
#  [ 2462.256 ]
#  [ 2485.875 ]
#  [ 2482.621 ]
#  [ 2637.5393]
#  [ 2704.718 ]
#  [ 2709.456 ]
#  [ 2663.8855]
#  [ 2791.4482]
#  [ 2891.177 ]
#  [ 2917.33  ]
#  [ 2988.833 ]
#  [ 2967.4526]
#  [ 3023.543 ]
#  [ 3101.1975]
#  [ 3109.7588]
#  [ 3089.2354]
#  [ 3038.662 ]
#  [ 3067.7466]
#  [ 3129.5886]
#  [ 3190.156 ]
#  [ 3213.1328]
#  [ 3161.9766]
#  [ 3184.856 ]
#  [ 3223.2195]
#  [ 3187.7659]
#  [ 3150.4983]
#  [ 3098.2463]
#  [ 3112.665 ]
#  [ 3230.7258]
#  [ 3295.6167]
#  [ 3329.99  ]
#  [ 3274.9119]
#  [ 3355.8677]
#  [ 3407.9062]
#  [ 3390.3547]
#  [ 3454.8801]
#  [ 3391.2368]
#  [ 3399.695 ]
#  [ 3541.321 ]
#  [ 3556.5645]
#  [ 3534.212 ]
#  [ 3637.2634]
#  [ 3643.5762]
#  [ 3701.862 ]
#  [ 3683.1516]
#  [ 3677.2224]
#  [ 3605.1277]
#  [ 3699.1287]
#  [ 3804.3477]
#  [ 3999.1953]
#  [ 4081.7788]
#  [ 3992.6226]
#  [ 4162.225 ]
#  [ 4296.125 ]
#  [ 4366.361 ]
#  [ 4338.383 ]
#  [ 4377.1953]
#  [ 4379.2285]
#  [ 4339.44  ]
#  [ 4377.4175]
#  [ 4310.9976]
#  [ 4403.0645]
#  [ 4542.249 ]
#  [ 4598.673 ]
#  [ 4644.3784]
#  [ 4658.6094]
#  [ 5521.967 ]
#  [ 5866.321 ]
#  [ 6084.8633]
#  [ 6147.3804]
#  [ 6205.8154]
#  [ 6276.271 ]
#  [ 6364.9995]
#  [ 6229.4517]
#  [ 6324.444 ]
#  [ 6912.7944]
#  [ 7112.7026]
#  [ 9201.056 ]
#  [ 8254.173 ]
#  [ 7577.5776]
#  [ 7059.6235]
#  [ 6743.309 ]
#  [ 6510.819 ]
#  [ 6284.169 ]
#  [ 6240.8535]
#  [ 6254.2705]
#  [ 6165.902 ]
#  [ 6186.067 ]
#  [ 6171.4873]
#  [ 6175.6577]
#  [ 6159.4414]
#  [ 6094.9775]
#  [ 6081.6006]
#  [ 5979.1514]
#  [ 5958.564 ]
#  [ 5732.4214]
#  [ 5365.785 ]
#  [ 5219.3096]
#  [ 4989.877 ]
#  [ 4854.056 ]
#  [ 4465.375 ]
#  [ 4180.9683]
#  [ 3973.2346]
#  [ 3830.354 ]
#  [ 3756.3171]
#  [ 3588.57  ]
#  [ 3491.786 ]
#  [ 3520.4539]
#  [ 3461.64  ]
#  [ 3494.9778]
#  [ 3505.8025]
#  [ 3485.5972]
#  [ 3552.7168]
#  [ 3709.2927]
#  [ 3818.965 ]
#  [ 3978.7412]
#  [ 4013.8757]
#  [ 3924.9866]
#  [ 3904.4812]
#  [ 3924.73  ]
#  [ 4009.2805]
#  [ 4131.253 ]
#  [ 4216.3   ]
#  [ 4302.1187]
#  [ 4219.96  ]
#  [ 4160.22  ]
#  [ 4078.4343]
#  [ 3992.2761]
#  [ 4005.444 ]
#  [ 4063.621 ]
#  [ 3976.6846]
#  [ 4012.8826]
#  [ 4064.5256]
#  [ 4097.637 ]
#  [ 4153.0215]
#  [ 4055.4255]
#  [ 4012.0886]
#  [ 4017.009 ]
#  [ 4032.9832]
#  [ 4105.2744]
#  [ 4035.814 ]
#  [ 4031.2817]
#  [ 3999.5872]
#  [ 4044.0764]
#  [ 4214.242 ]
#  [ 4468.562 ]
#  [ 4509.913 ]
#  [ 4476.6094]
#  [ 4481.344 ]
#  [ 4412.5146]
#  [ 4606.9604]
#  [ 4684.763 ]
#  [ 4750.941 ]
#  [ 4738.628 ]
#  [ 4728.436 ]
#  [ 4860.119 ]
#  [ 4832.6294]
#  [ 4794.0576]
#  [ 4699.5596]
#  [ 4664.467 ]
#  [ 4635.2627]
#  [ 4536.8286]
#  [ 4489.3345]
#  [ 4525.9146]
#  [ 4433.466 ]
#  [ 4351.6265]
#  [ 4252.7114]
#  [ 4218.0845]
#  [ 4289.6514]
#  [ 4273.4688]
#  [ 4237.3945]
#  [ 4169.2104]
#  [ 4164.203 ]
#  [ 4267.458 ]
#  [ 4222.337 ]
#  [ 4146.9575]
#  [ 4055.6113]
#  [ 4053.6907]
#  [ 4147.415 ]
#  [ 4158.139 ]
#  [ 4126.028 ]
#  [ 4085.0923]
#  [ 4072.3684]
#  [ 4216.9326]
#  [ 4209.126 ]
#  [ 4168.713 ]
#  [ 4079.572 ]
#  [ 4048.019 ]
#  [ 4195.1284]
#  [ 4171.429 ]
#  [ 4144.081 ]
#  [ 4075.0598]
#  [ 4002.4333]
#  [ 4055.3733]
#  [ 4042.3127]
#  [ 4017.2786]
#  [ 3977.7922]
#  [ 3924.739 ]
#  [ 3983.244 ]
#  [ 4002.968 ]
#  [ 3996.0325]
#  [ 3951.7375]
#  [ 4123.362 ]
#  [ 4304.431 ]
#  [ 4358.595 ]
#  [ 4355.2935]
#  [ 4250.409 ]
#  [ 4210.403 ]
#  [ 4277.884 ]
#  [ 4312.0493]
#  [ 4305.896 ]
#  [ 4238.5645]
#  [ 4194.484 ]
#  [ 4284.5347]
#  [ 4279.9995]
#  [ 4268.052 ]
#  [ 4159.662 ]
#  [ 4261.7803]
#  [ 4255.71  ]
#  [ 4199.3203]
#  [ 4147.0464]
#  [ 4097.88  ]
#  [ 4269.4463]
#  [ 4357.985 ]
#  [ 4803.244 ]
#  [ 5434.075 ]
#  [ 5676.9824]
#  [ 6281.7153]
#  [ 6594.322 ]
#  [ 6903.415 ]
#  [ 6466.0264]
#  [ 5903.6533]
#  [ 5362.892 ]
#  [ 4928.436 ]
#  [ 4511.1167]
#  [ 4376.4526]
#  [ 4279.939 ]
#  [ 4238.4326]
#  [ 4218.9194]
#  [ 4387.406 ]
#  [ 4362.8936]
#  [ 4407.5747]
#  [ 4279.935 ]
#  [ 4398.8936]
#  [ 4504.4043]
#  [ 4385.954 ]
#  [ 4058.3938]
#  [ 3808.1833]
#  [ 3676.3528]
#  [ 3577.8787]
#  [ 3637.297 ]
#  [ 3765.132 ]
#  [ 3757.8818]
#  [ 3689.4502]
#  [ 3727.6665]
#  [ 3824.2056]
#  [ 3995.7607]
#  [ 3793.0386]
#  [ 3734.9954]
#  [ 3845.8796]
#  [ 3711.8733]
#  [ 3632.3098]
#  [ 3735.5466]
#  [ 3908.185 ]
#  [ 4152.9927]
#  [ 4303.5522]
#  [ 4446.3535]
#  [ 4513.304 ]
#  [ 4490.155 ]
#  [ 4657.9683]
#  [ 4714.2856]
#  [ 4659.4663]
#  [ 4613.2495]
#  [ 4547.396 ]
#  [ 4580.8916]
#  [ 4975.2476]
#  [ 5529.846 ]
#  [ 5803.9727]
#  [ 5941.9517]
#  [ 6166.804 ]
#  [ 6120.606 ]
#  [ 6077.0547]
#  [ 6498.676 ]
#  [ 6520.316 ]
#  [ 6684.097 ]
#  [ 6708.9663]
#  [ 6554.093 ]
#  [ 6599.706 ]
#  [ 6647.7935]
#  [ 7046.6353]
#  [ 7466.842 ]
#  [ 7660.3457]
#  [ 7836.9956]
#  [ 7873.9604]
#  [ 8347.686 ]
#  [ 8528.236 ]
#  [ 8483.602 ]
#  [ 8830.582 ]
#  [ 8964.48  ]
#  [ 9144.018 ]
#  [ 9284.201 ]
#  [ 9329.298 ]
#  [ 9354.051 ]
#  [ 9298.748 ]
#  [ 9502.619 ]
#  [ 9518.965 ]
#  [ 9397.6   ]
#  [ 9319.144 ]
#  [ 9257.4795]
#  [ 9296.128 ]
#  [ 9140.995 ]
#  [ 8898.8125]
#  [ 8910.75  ]
#  [ 9377.346 ]
#  [ 9665.773 ]
#  [10109.854 ]
#  [10053.757 ]
#  [10163.101 ]
#  [10222.612 ]
#  [10381.11  ]
#  [10660.541 ]
#  [10728.98  ]
#  [10694.572 ]
#  [10696.481 ]
#  [10734.941 ]
#  [10425.959 ]
#  [10384.297 ]
#  [ 9935.274 ]
#  [ 9760.263 ]
#  [ 9668.682 ]
#  [ 9956.887 ]
#  [ 9545.479 ]] (476, 1)
# [[ 3215.]
#  [ 3215.]
#  [ 3258.]
#  [ 3298.]
#  [ 3298.]
#  [ 3298.]
#  [ 3340.]
#  [ 3340.]
#  [ 3340.]
#  [ 3400.]
#  [ 3318.]
#  [ 3318.]
#  [ 3318.]
#  [ 3318.]
#  [ 3318.]
#  [ 3275.]
#  [ 3190.]
#  [ 3190.]
#  [ 3148.]
#  [ 3108.]
#  [ 3065.]
#  [ 3065.]
#  [ 3065.]
#  [ 2998.]
#  [ 2998.]
#  [ 2998.]
#  [ 2958.]
#  [ 2903.]
#  [ 2778.]
#  [ 2625.]
#  [ 2625.]
#  [ 2658.]
#  [ 2658.]
#  [ 2658.]
#  [ 2658.]
#  [ 2658.]
#  [ 2658.]
#  [ 2708.]
#  [ 2658.]
#  [ 2658.]
#  [ 2658.]
#  [ 2658.]
#  [ 2658.]
#  [ 2658.]
#  [ 2658.]
#  [ 2658.]
#  [ 2628.]
#  [ 2628.]
#  [ 2628.]
#  [ 2468.]
#  [ 2468.]
#  [ 2468.]
#  [ 2468.]
#  [ 2385.]
#  [ 2395.]
#  [ 2395.]
#  [ 2470.]
#  [ 2470.]
#  [ 2960.]
#  [ 2593.]
#  [ 2593.]
#  [ 2593.]
#  [ 2593.]
#  [ 2400.]
#  [ 2400.]
#  [ 2400.]
#  [ 2315.]
#  [ 2315.]
#  [ 2218.]
#  [ 2218.]
#  [ 2218.]
#  [ 2218.]
#  [ 2243.]
#  [ 2243.]
#  [ 2230.]
#  [ 2288.]
#  [ 2288.]
#  [ 2288.]
#  [ 2260.]
#  [ 2260.]
#  [ 2260.]
#  [ 2260.]
#  [ 2260.]
#  [ 2220.]
#  [ 2220.]
#  [ 2220.]
#  [ 2220.]
#  [ 2220.]
#  [ 2178.]
#  [ 2178.]
#  [ 2095.]
#  [ 2095.]
#  [ 2095.]
#  [ 2095.]
#  [ 2095.]
#  [ 2095.]
#  [ 2095.]
#  [ 2095.]
#  [ 2095.]
#  [ 2095.]
#  [ 2095.]
#  [ 2095.]
#  [ 2145.]
#  [ 2145.]
#  [ 2145.]
#  [ 2105.]
#  [ 2105.]
#  [ 2105.]
#  [ 2105.]
#  [ 1923.]
#  [ 1923.]
#  [ 2005.]
#  [ 1963.]
#  [ 1963.]
#  [ 1963.]
#  [ 1963.]
#  [ 1963.]
#  [ 1963.]
#  [ 2330.]
#  [ 2443.]
#  [ 2443.]
#  [ 2443.]
#  [ 2443.]
#  [ 2553.]
#  [ 2553.]
#  [ 2607.]
#  [ 2663.]
#  [ 2663.]
#  [ 2210.]
#  [ 2210.]
#  [ 2234.]
#  [ 2234.]
#  [ 1788.]
#  [ 1788.]
#  [ 1788.]
#  [ 2278.]
#  [ 2278.]
#  [ 2278.]
#  [ 2322.]
#  [ 2413.]
#  [ 2440.]
#  [ 2440.]
#  [ 2440.]
#  [ 2473.]
#  [ 2743.]
#  [ 2760.]
#  [ 2760.]
#  [ 2921.]
#  [ 2840.]
#  [ 2920.]
#  [ 2968.]
#  [ 2968.]
#  [ 2942.]
#  [ 2942.]
#  [ 2942.]
#  [ 2997.]
#  [ 3152.]
#  [ 3152.]
#  [ 3104.]
#  [ 3133.]
#  [ 3133.]
#  [ 3085.]
#  [ 3085.]
#  [ 3085.]
#  [ 3085.]
#  [ 3290.]
#  [ 3290.]
#  [ 3262.]
#  [ 3262.]
#  [ 3336.]
#  [ 3313.]
#  [ 3312.]
#  [ 3450.]
#  [ 3367.]
#  [ 3311.]
#  [ 3204.]
#  [ 3388.]
#  [ 3408.]
#  [ 3429.]
#  [ 3379.]
#  [ 3379.]
#  [ 3436.]
#  [ 3436.]
#  [ 3354.]
#  [ 3491.]
#  [ 3533.]
#  [ 3554.]
#  [ 3575.]
#  [ 3513.]
#  [ 3690.]
#  [ 3760.]
#  [ 3760.]
#  [ 3760.]
#  [ 3785.]
#  [ 3785.]
#  [ 3785.]
#  [ 3860.]
#  [ 3860.]
#  [ 4072.]
#  [ 4113.]
#  [ 4152.]
#  [ 4178.]
#  [ 4300.]
#  [ 5468.]
#  [ 5353.]
#  [ 5398.]
#  [ 5343.]
#  [ 5570.]
#  [ 5658.]
#  [ 5713.]
#  [ 5658.]
#  [ 6250.]
#  [ 7178.]
#  [ 7055.]
#  [ 9195.]
#  [ 8903.]
#  [ 7928.]
#  [ 7983.]
#  [ 8040.]
#  [ 8095.]
#  [ 8168.]
#  [ 8342.]
#  [ 8302.]
#  [ 7640.]
#  [ 7723.]
#  [ 7305.]
#  [ 7205.]
#  [ 7205.]
#  [ 7208.]
#  [ 7208.]
#  [ 7040.]
#  [ 6815.]
#  [ 6520.]
#  [ 6148.]
#  [ 6315.]
#  [ 6065.]
#  [ 6065.]
#  [ 5540.]
#  [ 5458.]
#  [ 5318.]
#  [ 5235.]
#  [ 5188.]
#  [ 4854.]
#  [ 4854.]
#  [ 4854.]
#  [ 4600.]
#  [ 4600.]
#  [ 4433.]
#  [ 4480.]
#  [ 4523.]
#  [ 4523.]
#  [ 4605.]
#  [ 4660.]
#  [ 4635.]
#  [ 4370.]
#  [ 4370.]
#  [ 4483.]
#  [ 4483.]
#  [ 4740.]
#  [ 4740.]
#  [ 4740.]
#  [ 4575.]
#  [ 4433.]
#  [ 4475.]
#  [ 4433.]
#  [ 4475.]
#  [ 4433.]
#  [ 4433.]
#  [ 4515.]
#  [ 4515.]
#  [ 4515.]
#  [ 4515.]
#  [ 4433.]
#  [ 4433.]
#  [ 4433.]
#  [ 4433.]
#  [ 4433.]
#  [ 4433.]
#  [ 4390.]
#  [ 4390.]
#  [ 4433.]
#  [ 4650.]
#  [ 4810.]
#  [ 4810.]
#  [ 4650.]
#  [ 4650.]
#  [ 4650.]
#  [ 4650.]
#  [ 4650.]
#  [ 4608.]
#  [ 4608.]
#  [ 4548.]
#  [ 4548.]
#  [ 4548.]
#  [ 4548.]
#  [ 4548.]
#  [ 4548.]
#  [ 4633.]
#  [ 4523.]
#  [ 4523.]
#  [ 4523.]
#  [ 4465.]
#  [ 4483.]
#  [ 4483.]
#  [ 4483.]
#  [ 4483.]
#  [ 4455.]
#  [ 4455.]
#  [ 4455.]
#  [ 4455.]
#  [ 4455.]
#  [ 4455.]
#  [ 4428.]
#  [ 4428.]
#  [ 4428.]
#  [ 4428.]
#  [ 4428.]
#  [ 4428.]
#  [ 4428.]
#  [ 4428.]
#  [ 4428.]
#  [ 4428.]
#  [ 4428.]
#  [ 4428.]
#  [ 4428.]
#  [ 4503.]
#  [ 4385.]
#  [ 4385.]
#  [ 4385.]
#  [ 4303.]
#  [ 4303.]
#  [ 4303.]
#  [ 4303.]
#  [ 4303.]
#  [ 4303.]
#  [ 4275.]
#  [ 4275.]
#  [ 4275.]
#  [ 4275.]
#  [ 4533.]
#  [ 4533.]
#  [ 4533.]
#  [ 4533.]
#  [ 4533.]
#  [ 4533.]
#  [ 4533.]
#  [ 4590.]
#  [ 4590.]
#  [ 4590.]
#  [ 4590.]
#  [ 4590.]
#  [ 4590.]
#  [ 4590.]
#  [ 4590.]
#  [ 4590.]
#  [ 4590.]
#  [ 4590.]
#  [ 4590.]
#  [ 4643.]
#  [ 4773.]
#  [ 4773.]
#  [ 5253.]
#  [ 5830.]
#  [ 5830.]
#  [ 6400.]
#  [ 6943.]
#  [ 7167.]
#  [ 5243.]
#  [ 5063.]
#  [ 5063.]
#  [ 4686.]
#  [ 4300.]
#  [ 4350.]
#  [ 4323.]
#  [ 4323.]
#  [ 4267.]
#  [ 4293.]
#  [ 4320.]
#  [ 4543.]
#  [ 4572.]
#  [ 4812.]
#  [ 4846.]
#  [ 4746.]
#  [ 4332.]
#  [ 4152.]
#  [ 4143.]
#  [ 3858.]
#  [ 4150.]
#  [ 4260.]
#  [ 4228.]
#  [ 4044.]
#  [ 4004.]
#  [ 4234.]
#  [ 4440.]
#  [ 4150.]
#  [ 4104.]
#  [ 4238.]
#  [ 3942.]
#  [ 4008.]
#  [ 4032.]
#  [ 4238.]
#  [ 4238.]
#  [ 4262.]
#  [ 4136.]
#  [ 4136.]
#  [ 4136.]
#  [ 4078.]
#  [ 4132.]
#  [ 4153.]
#  [ 4195.]
#  [ 4070.]
#  [ 4070.]
#  [ 4478.]
#  [ 5008.]
#  [ 5163.]
#  [ 5330.]
#  [ 5330.]
#  [ 5330.]
#  [ 5330.]
#  [ 6093.]
#  [ 6238.]
#  [ 6238.]
#  [ 5970.]
#  [ 5690.]
#  [ 5700.]
#  [ 5760.]
#  [ 6263.]
#  [ 6263.]
#  [ 6290.]
#  [ 6170.]
#  [ 6234.]
#  [ 6773.]
#  [ 6348.]
#  [ 6484.]
#  [ 7278.]
#  [ 7528.]
#  [ 7560.]
#  [ 8060.]
#  [ 8570.]
#  [ 8815.]
#  [ 8933.]
#  [ 9620.]
#  [ 9620.]
#  [ 9785.]
#  [ 9885.]
#  [ 9970.]
#  [ 9720.]
#  [ 9220.]
#  [ 8635.]
#  [ 9625.]
#  [10867.]
#  [11100.]
#  [11433.]
#  [11433.]
#  [11767.]
#  [11767.]
#  [11867.]
#  [12067.]
#  [12733.]
#  [12733.]
#  [12733.]
#  [12733.]
#  [10800.]
#  [11820.]
#  [10800.]
#  [10800.]
#  [10800.]
#  [11758.]
#  [11058.]
#  [11058.]
#  [10893.]
#  [ 9193.]
#  [ 7483.]
#  [ 7180.]
#  [ 6765.]
#  [ 6233.]] (476, 1)

# %%
plt.figure(figsize=(20,10))
plt.plot(validY_test, color = 'blue', label = 'Actual Stock Price')
plt.plot(predicted_price_valid_test, color = 'red', label = 'Predicted Stock Price')
plt.title('Price Prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error 
MSE = mean_squared_error(validY_test, predicted_price_valid_test) 
np.sqrt(MSE)
# Out:
# 936.9482165811032

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(validY_test, predicted_price_valid_test)
# Out:
# 537.6831536813944

# %% [markdown]
# Test Data 평가

# %%
model.evaluate(testX, testY, batch_size=a)
# Out:
# 68/68 [==============================] - 0s 3ms/step - loss: 0.0072 - mae: 0.0579
# [0.007241108920425177, 0.05791404843330383]

# %%
predicted_price_test = model.predict(testX, batch_size=a, verbose=1)
# Out:
# 68/68 [==============================] - 0s 2ms/step

# %%
testY_test = np.delete(testY, np.s_[1:a], axis=1)
predicted_price_test_test = np.delete(predicted_price_test, np.s_[1:a], axis=1)

testY_test = np.reshape(testY_test, (476, 1))
predicted_price_test_test = np.reshape(predicted_price_test_test, (476, 1))
print(testY_test.shape)
print(predicted_price_test_test.shape)

plt.figure(figsize=(20,10))
plt.plot(testY_test, color = 'blue', label = 'Actual Stock Price')
plt.plot(predicted_price_test_test, color = 'red', label = 'Predicted Stock Price')
plt.title('Price Prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# (476, 1)
# (476, 1)

# %%
predicted_price_test_test = np.reshape(predicted_price_test_test, (476, ))
predicted_price_test_test = scaler_target.inverse_transform(predicted_price_test_test.reshape(-1,1))

print(predicted_price_test_test, predicted_price_test_test.shape)

testY_test = scaler_target.inverse_transform(testY_test.reshape(-1,1))

print(testY_test, testY_test.shape)
# Out:
# [[8135.7427]
#  [7770.2925]
#  [7575.815 ]
#  [7510.2183]
#  [7335.444 ]
#  [7230.34  ]
#  [7179.5806]
#  [7532.6006]
#  [7048.0166]
#  [6624.1343]
#  [6171.394 ]
#  [5894.2627]
#  [5820.278 ]
#  [5360.949 ]
#  [3822.557 ]
#  [3367.4124]
#  [3408.3784]
#  [3270.9702]
#  [3077.3376]
#  [3007.2927]
#  [2720.5916]
#  [2319.9849]
#  [2040.3374]
#  [1894.4672]
#  [2670.8596]
#  [2734.3105]
#  [2856.7063]
#  [2687.2942]
#  [2667.9268]
#  [2598.032 ]
#  [2794.5125]
#  [2995.5718]
#  [3068.6638]
#  [3060.238 ]
#  [3020.5586]
#  [3312.9958]
#  [3366.5176]
#  [3312.2605]
#  [3135.0908]
#  [2963.6096]
#  [2996.6917]
#  [2976.6206]
#  [2881.1064]
#  [2799.3447]
#  [2894.035 ]
#  [2965.6255]
#  [2968.167 ]
#  [2854.3538]
#  [2769.0059]
#  [2764.9546]
#  [2890.6711]
#  [2904.004 ]
#  [2868.7969]
#  [2795.2573]
#  [2809.652 ]
#  [2743.5803]
#  [2802.95  ]
#  [2751.069 ]
#  [2807.961 ]
#  [2859.3682]
#  [2896.6255]
#  [2915.887 ]
#  [2946.5374]
#  [3022.6501]
#  [3117.2122]
#  [3122.6748]
#  [3127.391 ]
#  [3145.4443]
#  [3224.1372]
#  [3225.002 ]
#  [3170.0461]
#  [3154.1533]
#  [3163.1643]
#  [3283.5999]
#  [3324.1824]
#  [3283.4417]
#  [3250.4294]
#  [3298.984 ]
#  [3394.4788]
#  [3427.4375]
#  [3337.7827]
#  [3401.728 ]
#  [3383.727 ]
#  [3516.8848]
#  [3572.7627]
#  [3561.062 ]
#  [3562.5442]
#  [3612.3408]
#  [3587.6143]
#  [3568.8   ]
#  [3575.6917]
#  [3720.8662]
#  [4094.1697]
#  [4514.6665]
#  [4714.803 ]
#  [4876.8247]
#  [4921.829 ]
#  [4687.781 ]
#  [4522.478 ]
#  [4492.3774]
#  [4543.1514]
#  [4569.4097]
#  [4534.1934]
#  [4524.987 ]
#  [4593.3374]
#  [4660.0356]
#  [4800.184 ]
#  [4801.6763]
#  [4839.291 ]
#  [4896.689 ]
#  [4949.859 ]
#  [4866.144 ]
#  [4840.104 ]
#  [4823.0127]
#  [4661.8516]
#  [4702.851 ]
#  [4593.237 ]
#  [4567.8467]
#  [4519.2207]
#  [4818.3174]
#  [5110.4556]
#  [5297.8496]
#  [5394.058 ]
#  [5399.8135]
#  [5385.7783]
#  [5408.653 ]
#  [5486.486 ]
#  [5433.5557]
#  [5387.162 ]
#  [5392.5576]
#  [5405.8286]
#  [5398.6504]
#  [5524.989 ]
#  [5514.8613]
#  [5497.998 ]
#  [5484.6567]
#  [5493.16  ]
#  [5090.9634]
#  [4760.8955]
#  [4576.726 ]
#  [5212.179 ]
#  [5512.1553]
#  [5637.7935]
#  [5581.6914]
#  [5607.202 ]
#  [5193.445 ]
#  [4576.184 ]
#  [4154.1772]
#  [3541.8555]
#  [3263.8096]
#  [3198.3645]
#  [3200.7034]
#  [3074.2195]
#  [3089.8926]
#  [3078.073 ]
#  [3010.784 ]
#  [2976.8281]
#  [2954.0125]
#  [3103.0417]
#  [3217.9043]
#  [3245.5432]
#  [3244.989 ]
#  [3310.6047]
#  [3427.613 ]
#  [3458.8538]
#  [3411.1077]
#  [3396.5334]
#  [3437.589 ]
#  [3544.2908]
#  [3542.8008]
#  [3439.6897]
#  [3344.0337]
#  [3250.7537]
#  [3308.2136]
#  [3334.4185]
#  [3268.3745]
#  [3252.4932]
#  [3266.4285]
#  [3327.157 ]
#  [3354.4119]
#  [3325.0327]
#  [3337.3315]
#  [3402.521 ]
#  [3523.0679]
#  [3655.3792]
#  [3596.5918]
#  [3566.3936]
#  [3688.9248]
#  [3785.3792]
#  [3753.7192]
#  [3644.637 ]
#  [3557.2773]
#  [3569.3755]
#  [3744.1296]
#  [4083.4895]
#  [4389.362 ]
#  [4439.271 ]
#  [4489.319 ]
#  [4503.5205]
#  [4363.633 ]
#  [4179.434 ]
#  [4032.993 ]
#  [4237.391 ]
#  [4494.73  ]
#  [4602.912 ]
#  [4737.922 ]
#  [4800.5415]
#  [5269.492 ]
#  [5535.219 ]
#  [5921.955 ]
#  [6103.9756]
#  [6118.219 ]
#  [6167.991 ]
#  [6094.8335]
#  [5725.399 ]
#  [5333.2925]
#  [5190.398 ]
#  [5176.0225]
#  [5140.7407]
#  [4930.6772]
#  [4761.8027]
#  [4751.55  ]
#  [4842.2954]
#  [4908.41  ]
#  [5296.756 ]
#  [5469.1846]
#  [5797.587 ]
#  [6033.8594]
#  [5937.9336]
#  [6025.888 ]
#  [5922.7954]
#  [5829.588 ]
#  [5764.7295]
#  [5574.937 ]
#  [5614.1533]
#  [5543.3086]
#  [5573.646 ]
#  [5653.7056]
#  [5730.561 ]
#  [5863.261 ]
#  [5906.2437]
#  [5796.883 ]
#  [5578.6997]
#  [5268.3906]
#  [5066.132 ]
#  [4892.5723]
#  [4739.8574]
#  [4501.458 ]
#  [4442.8403]
#  [4123.75  ]
#  [3878.24  ]
#  [3694.9358]
#  [3664.5068]
#  [3653.054 ]
#  [3588.0894]
#  [3556.2476]
#  [3540.3604]
#  [3614.695 ]
#  [3617.8943]
#  [3581.0518]
#  [3536.8972]
#  [3607.9946]
#  [3713.099 ]
#  [3758.3044]
#  [3745.062 ]
#  [3713.1985]
#  [3756.0452]
#  [3850.249 ]
#  [4081.0115]
#  [4835.6304]
#  [4460.9175]
#  [5665.135 ]
#  [5508.7803]
#  [5457.024 ]
#  [5381.728 ]
#  [5331.0723]
#  [4997.156 ]
#  [4672.881 ]
#  [4308.242 ]
#  [4064.0366]
#  [3932.512 ]
#  [4145.566 ]
#  [4215.3506]
#  [4112.2085]
#  [3939.567 ]
#  [3819.2498]
#  [3906.2256]
#  [4108.933 ]
#  [4206.0693]
#  [4199.607 ]
#  [4129.836 ]
#  [4060.6653]
#  [3941.8367]
#  [3841.299 ]
#  [3801.2488]
#  [3826.8694]
#  [3813.5413]
#  [3830.1418]
#  [3791.4402]
#  [3738.8984]
#  [3756.0422]
#  [3808.9294]
#  [3832.4868]
#  [4021.15  ]
#  [3778.126 ]
#  [3510.1013]
#  [3414.4272]
#  [3750.939 ]
#  [3797.2979]
#  [3798.3987]
#  [3786.1099]
#  [3839.818 ]
#  [3897.7737]
#  [3881.7703]
#  [3874.129 ]
#  [3835.5427]
#  [3801.1335]
#  [3865.8062]
#  [3926.923 ]
#  [3788.113 ]
#  [3632.278 ]
#  [3575.3179]
#  [3450.2085]
#  [3413.551 ]
#  [3347.3982]
#  [3327.4326]
#  [3408.374 ]
#  [3270.1248]
#  [3335.9834]
#  [3287.586 ]
#  [3372.467 ]
#  [3318.5776]
#  [3325.1184]
#  [3380.5737]
#  [3389.8176]
#  [3376.1816]
#  [3327.0894]
#  [3307.0325]
#  [3359.5566]
#  [3490.6716]
#  [3556.9343]
#  [3547.1921]
#  [3501.6345]
#  [3483.8757]
#  [3468.023 ]
#  [3369.287 ]
#  [3389.3186]
#  [3437.7227]
#  [3499.7559]
#  [3538.412 ]
#  [3520.0713]
#  [3639.9404]
#  [3613.0466]
#  [3705.5317]
#  [3722.647 ]
#  [3720.464 ]
#  [3736.185 ]
#  [3784.4133]
#  [3719.5295]
#  [3649.1936]
#  [3615.0437]
#  [3674.9692]
#  [3787.5474]
#  [3882.2969]
#  [3851.3723]
#  [3857.944 ]
#  [4128.021 ]
#  [4267.3955]
#  [4355.6064]
#  [4326.8564]
#  [4179.4067]
#  [4178.093 ]
#  [4134.003 ]
#  [4130.3564]
#  [4045.912 ]
#  [3982.5046]
#  [4043.1643]
#  [4065.641 ]
#  [4184.7593]
#  [4277.3213]
#  [4512.912 ]
#  [4668.857 ]
#  [4890.2266]
#  [4933.5127]
#  [4914.6826]
#  [4859.9067]
#  [4881.1807]
#  [4921.852 ]
#  [4988.037 ]
#  [4953.9233]
#  [5003.324 ]
#  [4913.664 ]
#  [4852.124 ]
#  [4786.786 ]
#  [4748.8027]
#  [4831.768 ]
#  [5241.3228]
#  [4711.214 ]
#  [4222.901 ]
#  [3838.5635]
#  [3639.4226]
#  [3519.6365]
#  [3468.842 ]
#  [3339.2783]
#  [3306.2058]
#  [3331.1155]
#  [3336.2207]
#  [3324.1104]
#  [3228.5903]
#  [3249.4292]
#  [3201.3489]
#  [3174.096 ]
#  [3288.085 ]
#  [3407.3057]
#  [3495.2515]
#  [3490.4014]
#  [3485.1497]
#  [3491.128 ]
#  [3582.0662]
#  [3702.5286]
#  [3777.175 ]
#  [3741.086 ]
#  [3815.1208]
#  [4010.0518]
#  [4072.8716]
#  [3849.3403]
#  [3855.5576]
#  [4285.765 ]
#  [4500.493 ]
#  [4529.1133]
#  [4713.403 ]
#  [4852.4434]
#  [4781.9473]
#  [5187.806 ]
#  [5359.126 ]
#  [5319.03  ]
#  [5370.0005]
#  [5387.5957]
#  [5530.375 ]
#  [5936.991 ]
#  [6362.3647]
#  [6432.4556]
#  [6121.081 ]
#  [7601.0913]
#  [6796.841 ]
#  [6304.0996]
#  [5857.6455]
#  [5636.6987]
#  [5533.4727]
#  [5415.131 ]
#  [5260.863 ]
#  [5250.726 ]
#  [5394.1636]
#  [5663.9443]
#  [6013.2153]
#  [5963.6147]
#  [6068.1064]
#  [6238.942 ]
#  [6663.804 ]
#  [6928.3735]
#  [7204.895 ]
#  [7264.844 ]
#  [7410.9185]
#  [7428.284 ]
#  [7393.9673]
#  [7114.9033]
#  [6979.248 ]
#  [6784.1963]
#  [6669.978 ]
#  [6409.399 ]
#  [6270.91  ]
#  [6253.059 ]
#  [6177.0195]
#  [6347.8594]
#  [6323.414 ]
#  [6692.601 ]] (476, 1)
# [[ 5613.]
#  [ 5195.]
#  [ 4823.]
#  [ 4630.]
#  [ 4655.]
#  [ 4655.]
#  [ 4445.]
#  [ 4248.]
#  [ 3900.]
#  [ 3748.]
#  [ 3748.]
#  [ 3580.]
#  [ 3580.]
#  [ 1590.]
#  [ 1590.]
#  [ 1590.]
#  [ 1590.]
#  [ 3355.]
#  [ 3228.]
#  [ 3103.]
#  [ 2838.]
#  [ 2938.]
#  [ 2938.]
#  [ 2740.]
#  [ 2807.]
#  [ 2852.]
#  [ 2795.]
#  [ 2795.]
#  [ 3180.]
#  [ 2808.]
#  [ 2830.]
#  [ 2725.]
#  [ 2642.]
#  [ 2774.]
#  [ 2642.]
#  [ 2613.]
#  [ 2613.]
#  [ 2740.]
#  [ 2613.]
#  [ 2613.]
#  [ 2558.]
#  [ 2565.]
#  [ 2565.]
#  [ 2616.]
#  [ 2616.]
#  [ 2616.]
#  [ 2616.]
#  [ 2576.]
#  [ 2335.]
#  [ 2600.]
#  [ 2568.]
#  [ 2765.]
#  [ 2763.]
#  [ 2763.]
#  [ 2763.]
#  [ 2817.]
#  [ 2803.]
#  [ 2927.]
#  [ 2927.]
#  [ 2960.]
#  [ 2960.]
#  [ 2960.]
#  [ 2960.]
#  [ 2960.]
#  [ 2960.]
#  [ 2960.]
#  [ 2960.]
#  [ 2960.]
#  [ 2960.]
#  [ 2960.]
#  [ 3227.]
#  [ 3227.]
#  [ 3227.]
#  [ 3227.]
#  [ 3433.]
#  [ 3257.]
#  [ 3443.]
#  [ 3577.]
#  [ 3577.]
#  [ 3577.]
#  [ 3707.]
#  [ 3707.]
#  [ 3763.]
#  [ 3807.]
#  [ 3997.]
#  [ 4553.]
#  [ 4943.]
#  [ 4997.]
#  [ 4997.]
#  [ 4943.]
#  [ 4653.]
#  [ 4653.]
#  [ 4653.]
#  [ 4653.]
#  [ 4653.]
#  [ 4653.]
#  [ 4763.]
#  [ 4763.]
#  [ 4763.]
#  [ 5013.]
#  [ 5013.]
#  [ 5013.]
#  [ 5013.]
#  [ 5013.]
#  [ 5013.]
#  [ 5013.]
#  [ 5070.]
#  [ 4677.]
#  [ 4840.]
#  [ 4840.]
#  [ 4840.]
#  [ 4840.]
#  [ 5410.]
#  [ 5580.]
#  [ 5580.]
#  [ 5580.]
#  [ 5580.]
#  [ 5580.]
#  [ 5580.]
#  [ 5580.]
#  [ 5580.]
#  [ 5580.]
#  [ 5580.]
#  [ 5525.]
#  [ 5525.]
#  [ 5635.]
#  [ 5635.]
#  [ 5635.]
#  [ 5635.]
#  [ 5635.]
#  [ 4853.]
#  [ 4853.]
#  [ 4853.]
#  [ 5635.]
#  [ 5635.]
#  [ 5635.]
#  [ 5635.]
#  [ 5635.]
#  [ 3659.]
#  [ 3659.]
#  [ 3037.]
#  [ 2850.]
#  [ 2925.]
#  [ 3037.]
#  [ 3139.]
#  [ 2863.]
#  [ 2790.]
#  [ 2819.]
#  [ 2819.]
#  [ 2819.]
#  [ 2942.]
#  [ 2997.]
#  [ 3058.]
#  [ 3142.]
#  [ 3142.]
#  [ 3142.]
#  [ 3142.]
#  [ 3142.]
#  [ 3142.]
#  [ 3178.]
#  [ 3212.]
#  [ 3212.]
#  [ 3157.]
#  [ 3095.]
#  [ 2979.]
#  [ 2907.]
#  [ 2907.]
#  [ 2979.]
#  [ 2931.]
#  [ 2931.]
#  [ 2973.]
#  [ 2805.]
#  [ 2882.]
#  [ 2910.]
#  [ 2910.]
#  [ 2972.]
#  [ 2972.]
#  [ 3172.]
#  [ 3058.]
#  [ 3003.]
#  [ 3258.]
#  [ 3104.]
#  [ 3013.]
#  [ 3026.]
#  [ 2994.]
#  [ 3088.]
#  [ 3240.]
#  [ 3263.]
#  [ 3597.]
#  [ 3597.]
#  [ 3597.]
#  [ 3280.]
#  [ 3280.]
#  [ 3300.]
#  [ 3140.]
#  [ 3696.]
#  [ 3754.]
#  [ 3754.]
#  [ 4042.]
#  [ 4110.]
#  [ 4643.]
#  [ 4643.]
#  [ 5090.]
#  [ 5090.]
#  [ 5090.]
#  [ 5150.]
#  [ 5003.]
#  [ 4640.]
#  [ 4640.]
#  [ 4805.]
#  [ 4805.]
#  [ 4805.]
#  [ 4668.]
#  [ 4668.]
#  [ 4853.]
#  [ 4823.]
#  [ 4925.]
#  [ 5383.]
#  [ 5383.]
#  [ 5753.]
#  [ 5700.]
#  [ 5490.]
#  [ 5624.]
#  [ 5252.]
#  [ 5233.]
#  [ 5233.]
#  [ 5123.]
#  [ 5417.]
#  [ 5445.]
#  [ 5445.]
#  [ 5586.]
#  [ 5800.]
#  [ 5826.]
#  [ 5816.]
#  [ 5616.]
#  [ 5416.]
#  [ 5016.]
#  [ 5016.]
#  [ 5148.]
#  [ 5016.]
#  [ 4510.]
#  [ 4510.]
#  [ 4238.]
#  [ 3960.]
#  [ 3793.]
#  [ 3757.]
#  [ 3757.]
#  [ 3738.]
#  [ 3738.]
#  [ 3645.]
#  [ 3645.]
#  [ 3645.]
#  [ 3663.]
#  [ 3663.]
#  [ 3730.]
#  [ 3747.]
#  [ 3803.]
#  [ 3822.]
#  [ 3780.]
#  [ 3760.]
#  [ 3760.]
#  [ 4198.]
#  [ 4930.]
#  [ 4000.]
#  [ 5830.]
#  [ 4997.]
#  [ 4997.]
#  [ 5033.]
#  [ 5033.]
#  [ 4136.]
#  [ 4136.]
#  [ 4146.]
#  [ 4114.]
#  [ 4048.]
#  [ 4556.]
#  [ 4422.]
#  [ 4172.]
#  [ 4128.]
#  [ 4128.]
#  [ 4370.]
#  [ 4456.]
#  [ 4456.]
#  [ 4456.]
#  [ 4234.]
#  [ 3982.]
#  [ 3982.]
#  [ 3982.]
#  [ 3982.]
#  [ 3982.]
#  [ 3982.]
#  [ 3982.]
#  [ 3982.]
#  [ 3882.]
#  [ 3882.]
#  [ 3908.]
#  [ 3908.]
#  [ 4320.]
#  [ 3300.]
#  [ 3300.]
#  [ 3300.]
#  [ 4270.]
#  [ 4270.]
#  [ 4270.]
#  [ 4270.]
#  [ 4270.]
#  [ 4420.]
#  [ 4420.]
#  [ 4420.]
#  [ 4420.]
#  [ 4138.]
#  [ 4420.]
#  [ 4420.]
#  [ 4200.]
#  [ 3945.]
#  [ 3945.]
#  [ 3880.]
#  [ 3880.]
#  [ 3880.]
#  [ 3880.]
#  [ 4028.]
#  [ 3795.]
#  [ 4067.]
#  [ 3795.]
#  [ 3945.]
#  [ 3945.]
#  [ 3945.]
#  [ 3945.]
#  [ 3995.]
#  [ 3995.]
#  [ 3995.]
#  [ 4038.]
#  [ 4038.]
#  [ 4333.]
#  [ 4333.]
#  [ 4333.]
#  [ 4220.]
#  [ 4100.]
#  [ 4100.]
#  [ 4100.]
#  [ 4097.]
#  [ 4137.]
#  [ 4137.]
#  [ 4137.]
#  [ 4237.]
#  [ 4310.]
#  [ 4217.]
#  [ 4310.]
#  [ 4420.]
#  [ 4420.]
#  [ 4420.]
#  [ 4420.]
#  [ 4217.]
#  [ 4217.]
#  [ 4217.]
#  [ 4217.]
#  [ 4360.]
#  [ 4360.]
#  [ 4360.]
#  [ 4397.]
#  [ 4720.]
#  [ 4720.]
#  [ 4720.]
#  [ 4720.]
#  [ 4517.]
#  [ 4517.]
#  [ 4517.]
#  [ 4517.]
#  [ 4553.]
#  [ 4553.]
#  [ 4553.]
#  [ 4553.]
#  [ 4700.]
#  [ 4847.]
#  [ 5203.]
#  [ 5203.]
#  [ 5203.]
#  [ 5203.]
#  [ 5203.]
#  [ 5203.]
#  [ 5203.]
#  [ 5203.]
#  [ 5203.]
#  [ 5203.]
#  [ 5117.]
#  [ 4937.]
#  [ 4937.]
#  [ 5010.]
#  [ 5010.]
#  [ 5123.]
#  [ 5550.]
#  [ 4137.]
#  [ 4137.]
#  [ 3930.]
#  [ 3930.]
#  [ 3930.]
#  [ 3901.]
#  [ 3839.]
#  [ 3948.]
#  [ 3948.]
#  [ 3948.]
#  [ 3948.]
#  [ 3842.]
#  [ 3842.]
#  [ 3842.]
#  [ 3897.]
#  [ 4052.]
#  [ 4052.]
#  [ 4086.]
#  [ 4086.]
#  [ 4086.]
#  [ 4157.]
#  [ 4157.]
#  [ 4273.]
#  [ 4276.]
#  [ 4291.]
#  [ 4300.]
#  [ 4300.]
#  [ 4300.]
#  [ 4060.]
#  [ 4060.]
#  [ 4323.]
#  [ 4340.]
#  [ 4340.]
#  [ 4433.]
#  [ 4433.]
#  [ 4318.]
#  [ 4692.]
#  [ 4692.]
#  [ 4692.]
#  [ 4758.]
#  [ 5202.]
#  [ 5398.]
#  [ 5805.]
#  [ 6112.]
#  [ 6462.]
#  [ 6072.]
#  [ 8665.]
#  [ 7817.]
#  [ 6532.]
#  [ 6780.]
#  [ 6874.]
#  [ 6584.]
#  [ 6103.]
#  [ 6007.]
#  [ 6207.]
#  [ 6527.]
#  [ 6527.]
#  [ 6658.]
#  [ 6608.]
#  [ 6553.]
#  [ 6837.]
#  [ 6892.]
#  [ 6892.]
#  [ 6977.]
#  [ 6697.]
#  [ 6977.]
#  [ 6416.]
#  [ 6808.]
#  [ 6575.]
#  [ 6725.]
#  [ 6780.]
#  [ 6837.]
#  [ 7085.]
#  [ 7385.]
#  [ 7618.]
#  [ 7747.]
#  [ 8061.]
#  [ 8104.]
#  [ 9050.]
#  [11573.]
#  [12667.]
#  [10754.]
#  [10054.]
#  [ 9512.]
#  [ 9512.]
#  [ 9512.]] (476, 1)

# %%
from sklearn.metrics import mean_squared_error 
MSE = mean_squared_error(testY_test, predicted_price_test_test) 
np.sqrt(MSE)
# Out:
# 1024.6832315362599

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(testY_test, predicted_price_test_test)
# Out:
# 688.8566430356323

# %% [markdown]
# 예측방법

# %%
minX1 = np.array(dataX[0:7])
minX2 = np.array(dataX[0:8])
minX3 = np.array(dataX[0:2380])
minX4 = np.array(dataX[0:train_size])

# %%
predicted_price_min1 = model.predict(minX1, batch_size=a, verbose=1)
predicted_price_min2 = model.predict(minX2, batch_size=a, verbose=1) 
predicted_price_min3 = model.predict(minX3, batch_size=a, verbose=1)
predicted_price_min4 = model.predict(minX4, batch_size=a, verbose=1)
# Out:
# 1/1 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 1s 7ms/step
# 340/340 [==============================] - 1s 2ms/step
# 204/204 [==============================] - 1s 3ms/step

# %%
predicted_price_min1[0]
# Out:
# array([[0.24257636],
#        [0.2127758 ],
#        [0.19604716],
#        [0.19285223],
#        [0.17866859],
#        [0.17391121],
#        [0.19723114]], dtype=float32)

# %%
predicted_price_min2[0]
# Out:
# array([[0.19398737],
#        [0.19696312],
#        [0.19743334],
#        [0.20653376],
#        [0.19991168],
#        [0.20356661],
#        [0.23556557]], dtype=float32)

# %%
predicted_price_min3[0]
# Out:
# array([[0.27939177],
#        [0.27981317],
#        [0.27133626],
#        [0.27306294],
#        [0.26727262],
#        [0.27159923],
#        [0.2972232 ]], dtype=float32)

# %%
scaler_target.inverse_transform(predicted_price_min4[0].reshape(-1,1))
# Out:
# array([[1837.2285],
#        [1756.8563],
#        [1711.7391],
#        [1703.1224],
#        [1664.8691],
#        [1652.0386],
#        [1714.9324]], dtype=float32)
