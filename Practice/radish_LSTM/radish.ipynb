# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import random
import os

# %%
def my_seed_everywhere(seed: int = 42):
    random.seed(seed) # random
    np.random.seed(seed) # np
    os.environ["PYTHONHASHSEED"] = str(seed) # os
    tf.random.set_seed(seed) # tensorflow

my_seed = 42
my_seed_everywhere(my_seed)

# %%
df = pd.read_csv('/content/sample_data/radish_final.csv', index_col=0)
df = df.dropna(axis=0)
df = df.reset_index(drop=True)
df['Date'] = pd.to_datetime(df['Date'])
df['DayOfWeek'] = df['Date'].dt.dayofweek

# %%
df = df.drop(['Temp'],axis=1)
df = df.drop(['Oil'],axis=1)
df = df.drop(['Sup'],axis=1)
df = df.drop(['Avg_Price'], axis=1)

df['DayOfWeek'] = df['DayOfWeek'].astype('category')
df = pd.get_dummies(df, columns =['DayOfWeek'], prefix='W', drop_first=True)

df.tail()
# Out:
#            Date  Rain  Wind  sobimul  nongmul   Price  Produced  W_1  W_2  \
# 2390 2022-09-26   0.0   1.7      2.5      8.7  3714.0   1172345    0    0
# 2391 2022-09-27   0.0   1.6      2.5      8.7  3782.0   1172345    1    0
# 2392 2022-09-28   0.0   1.8      2.5      8.7  3782.0   1172345    0    1
# 2393 2022-09-29   0.0   1.4      2.5      8.7  3920.0   1172345    0    0
# 2394 2022-09-30   0.0   1.6      2.5      8.7  3970.0   1172345    0    0
#
#       W_3  W_4
# 2390    0    0
# 2391    0    0
# 2392    0    0
# 2393    1    0
# 2394    0    1

# %%
from sklearn.preprocessing import MinMaxScaler
input_indicator = df.loc[:,['Rain', 'Wind', 'sobimul', 'nongmul', 'Produced', 'W_1', 'W_2', 'W_3', 'W_4']]
target_indicator = df.loc[:,['Price']].values[:]
scaler_input = MinMaxScaler()
scaler_target = MinMaxScaler()
scaled_input_indicator = scaler_input.fit_transform(input_indicator)
scaled_target_indicator = scaler_target.fit_transform(target_indicator) # 가격 관련 지표에 스케일링

x = np.concatenate((scaled_target_indicator, scaled_input_indicator), axis=1)
y = x[:, [0]]

print(x)
print(y.shape)
# Out:
# [[0.24351879 0.         0.61403509 ... 1.         0.         0.        ]
#  [0.24876202 0.         0.36842105 ... 0.         1.         0.        ]
#  [0.23507137 0.         0.19298246 ... 0.         0.         1.        ]
#  ...
#  [0.79667929 0.         0.19298246 ... 1.         0.         0.        ]
#  [0.83687737 0.         0.12280702 ... 0.         1.         0.        ]
#  [0.85144189 0.         0.15789474 ... 0.         0.         1.        ]]
# (2395, 1)

# %%
# 21일치의 input으로 8일치의 output을 생산(API 문제상 당일날 input은 활용 불가능할 것으로 예상됨)
# 추후 train, validation, train set를 6년, 2년, 2년으로 나눠볼까 생각중, 지금은 many_to_many 코드 구현을 목표로 구현하지 않음
seq_length = 3
predict_day = 3
dataX = [] 
dataY = [] 
for i in range(0, int(len(y) - seq_length - predict_day)):
    _x = x[i : i + seq_length]
    _y = y[i + predict_day : i + seq_length + predict_day] 
    dataX.append(_x) 
    dataY.append(_y) 
print(len(dataX))
print(len(dataY))
# Out:
# 2389
# 2389

# %%
# Train Set 생성, 추후 Validation, Test도 여기에다가 추가 예상됨, 또한 21의 배수로 설정해야 batch에서 오류가 발생하지 않음
train_size = 1431
validation_size = 477
test_size = 477

trainX = np.array(dataX[0:train_size])
trainY = np.array(dataY[0:train_size])
validX = np.array(dataX[train_size:train_size+validation_size])
validY = np.array(dataY[train_size:train_size+validation_size])
testX = np.array(dataX[train_size+validation_size:train_size+validation_size+test_size])
testY = np.array(dataY[train_size+validation_size:train_size+validation_size+test_size])

print(trainX.shape)
print(trainY.shape)
print(validX.shape)
print(validY.shape)
print(testX.shape)
print(testY.shape)
# Out:
# (1431, 3, 10)
# (1431, 3, 1)
# (477, 3, 10)
# (477, 3, 1)
# (477, 3, 10)
# (477, 3, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, Activation
from tensorflow import keras

# %%
class CustomHistory(keras.callbacks.Callback):
    def init(self):
        self.train_loss = []
        self.val_loss = []
        
    def on_epoch_end(self, batch, logs={}):
        self.train_loss.append(logs.get('loss'))
        self.val_loss.append(logs.get('val_loss'))

# %%
input_columns = 10 # 데이터 셋의 '열' 개수 (dataX) / dataset's columns (dataX)

model = Sequential()
model.add(LSTM(16, batch_input_shape=(3, 3, input_columns), return_sequences=True, stateful=True, dropout=0.1))
model.add(LSTM(16, return_sequences=True, stateful=True, dropout=0.1))
model.add(Dense(1))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (3, 3, 16)                1728
#
#  lstm_1 (LSTM)               (3, 3, 16)                2112
#
#  dense (Dense)               (3, 3, 1)                 17
#
# =================================================================
# Total params: 3,857
# Trainable params: 3,857
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping
checkpoint_cb = keras.callbacks.ModelCheckpoint('best-model-radish.h5', save_best_only=True)
early_stopping_cb = keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=5, restore_best_weights=True)

# %%
keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %%
custom_hist = CustomHistory()
custom_hist.init()

# %%
for epoch_idx in range(100):
  print('epochs:' + str(epoch_idx))
  hist = model.fit(trainX, trainY, validation_data=(validX, validY), epochs=1, batch_size=3, verbose=2, shuffle=False, callbacks=[checkpoint_cb, custom_hist, early_stopping_cb])
  model.reset_states()
# Out:
# epochs:0
# 477/477 - 10s - loss: 0.0200 - mae: 0.1018 - val_loss: 0.1028 - val_mae: 0.2901 - 10s/epoch - 22ms/step
# epochs:1
# 477/477 - 2s - loss: 0.0202 - mae: 0.1121 - val_loss: 0.0859 - val_mae: 0.2700 - 2s/epoch - 4ms/step
# epochs:2
# 477/477 - 2s - loss: 0.0142 - mae: 0.0922 - val_loss: 0.0577 - val_mae: 0.2243 - 2s/epoch - 5ms/step
# epochs:3
# 477/477 - 2s - loss: 0.0102 - mae: 0.0750 - val_loss: 0.0420 - val_mae: 0.1931 - 2s/epoch - 5ms/step
# epochs:4
# 477/477 - 2s - loss: 0.0088 - mae: 0.0671 - val_loss: 0.0353 - val_mae: 0.1783 - 2s/epoch - 4ms/step
# epochs:5
# 477/477 - 2s - loss: 0.0081 - mae: 0.0635 - val_loss: 0.0348 - val_mae: 0.1777 - 2s/epoch - 4ms/step
# epochs:6
# 477/477 - 2s - loss: 0.0070 - mae: 0.0592 - val_loss: 0.0213 - val_mae: 0.1382 - 2s/epoch - 5ms/step
# epochs:7
# 477/477 - 2s - loss: 0.0068 - mae: 0.0569 - val_loss: 0.0253 - val_mae: 0.1509 - 2s/epoch - 5ms/step
# epochs:8
# 477/477 - 2s - loss: 0.0068 - mae: 0.0574 - val_loss: 0.0219 - val_mae: 0.1404 - 2s/epoch - 4ms/step
# epochs:9
# 477/477 - 2s - loss: 0.0064 - mae: 0.0547 - val_loss: 0.0206 - val_mae: 0.1358 - 2s/epoch - 5ms/step
# epochs:10
# 477/477 - 2s - loss: 0.0057 - mae: 0.0528 - val_loss: 0.0144 - val_mae: 0.1125 - 2s/epoch - 4ms/step
# epochs:11
# 477/477 - 2s - loss: 0.0056 - mae: 0.0517 - val_loss: 0.0174 - val_mae: 0.1242 - 2s/epoch - 4ms/step
# epochs:12
# 477/477 - 2s - loss: 0.0055 - mae: 0.0518 - val_loss: 0.0165 - val_mae: 0.1204 - 2s/epoch - 5ms/step
# epochs:13
# 477/477 - 2s - loss: 0.0056 - mae: 0.0517 - val_loss: 0.0190 - val_mae: 0.1303 - 2s/epoch - 5ms/step
# epochs:14
# 477/477 - 2s - loss: 0.0054 - mae: 0.0509 - val_loss: 0.0147 - val_mae: 0.1142 - 2s/epoch - 4ms/step
# epochs:15
# 477/477 - 2s - loss: 0.0050 - mae: 0.0490 - val_loss: 0.0109 - val_mae: 0.0965 - 2s/epoch - 4ms/step
# epochs:16
# 477/477 - 2s - loss: 0.0049 - mae: 0.0491 - val_loss: 0.0126 - val_mae: 0.1048 - 2s/epoch - 5ms/step
# epochs:17
# 477/477 - 2s - loss: 0.0048 - mae: 0.0489 - val_loss: 0.0121 - val_mae: 0.1031 - 2s/epoch - 5ms/step
# epochs:18
# 477/477 - 2s - loss: 0.0045 - mae: 0.0470 - val_loss: 0.0123 - val_mae: 0.1035 - 2s/epoch - 5ms/step
# epochs:19
# 477/477 - 2s - loss: 0.0047 - mae: 0.0469 - val_loss: 0.0106 - val_mae: 0.0951 - 2s/epoch - 5ms/step
# epochs:20
# 477/477 - 2s - loss: 0.0045 - mae: 0.0461 - val_loss: 0.0074 - val_mae: 0.0766 - 2s/epoch - 5ms/step
# epochs:21
# 477/477 - 2s - loss: 0.0044 - mae: 0.0462 - val_loss: 0.0086 - val_mae: 0.0827 - 2s/epoch - 5ms/step
# epochs:22
# 477/477 - 2s - loss: 0.0040 - mae: 0.0439 - val_loss: 0.0068 - val_mae: 0.0732 - 2s/epoch - 5ms/step
# epochs:23
# 477/477 - 2s - loss: 0.0036 - mae: 0.0417 - val_loss: 0.0063 - val_mae: 0.0719 - 2s/epoch - 4ms/step
# epochs:24
# 477/477 - 2s - loss: 0.0035 - mae: 0.0402 - val_loss: 0.0059 - val_mae: 0.0672 - 2s/epoch - 4ms/step
# epochs:25
# 477/477 - 2s - loss: 0.0035 - mae: 0.0422 - val_loss: 0.0061 - val_mae: 0.0690 - 2s/epoch - 5ms/step
# epochs:26
# 477/477 - 2s - loss: 0.0034 - mae: 0.0396 - val_loss: 0.0053 - val_mae: 0.0635 - 2s/epoch - 4ms/step
# epochs:27
# 477/477 - 2s - loss: 0.0031 - mae: 0.0384 - val_loss: 0.0042 - val_mae: 0.0535 - 2s/epoch - 4ms/step
# epochs:28
# 477/477 - 2s - loss: 0.0031 - mae: 0.0386 - val_loss: 0.0048 - val_mae: 0.0608 - 2s/epoch - 4ms/step
# epochs:29
# 477/477 - 2s - loss: 0.0030 - mae: 0.0372 - val_loss: 0.0030 - val_mae: 0.0426 - 2s/epoch - 4ms/step
# epochs:30
# 477/477 - 2s - loss: 0.0028 - mae: 0.0366 - val_loss: 0.0040 - val_mae: 0.0511 - 2s/epoch - 4ms/step
# epochs:31
# 477/477 - 2s - loss: 0.0030 - mae: 0.0367 - val_loss: 0.0064 - val_mae: 0.0733 - 2s/epoch - 5ms/step
# epochs:32
# 477/477 - 2s - loss: 0.0027 - mae: 0.0347 - val_loss: 0.0037 - val_mae: 0.0478 - 2s/epoch - 4ms/step
# epochs:33
# 477/477 - 2s - loss: 0.0028 - mae: 0.0367 - val_loss: 0.0039 - val_mae: 0.0503 - 2s/epoch - 5ms/step
# epochs:34
# 477/477 - 2s - loss: 0.0027 - mae: 0.0351 - val_loss: 0.0038 - val_mae: 0.0520 - 2s/epoch - 4ms/step
# epochs:35
# 477/477 - 2s - loss: 0.0027 - mae: 0.0352 - val_loss: 0.0037 - val_mae: 0.0518 - 2s/epoch - 5ms/step
# epochs:36
# 477/477 - 2s - loss: 0.0027 - mae: 0.0348 - val_loss: 0.0050 - val_mae: 0.0634 - 2s/epoch - 4ms/step
# epochs:37
# 477/477 - 2s - loss: 0.0026 - mae: 0.0344 - val_loss: 0.0030 - val_mae: 0.0421 - 2s/epoch - 5ms/step
# epochs:38
# 477/477 - 2s - loss: 0.0027 - mae: 0.0361 - val_loss: 0.0039 - val_mae: 0.0529 - 2s/epoch - 5ms/step
# epochs:39
# 477/477 - 2s - loss: 0.0027 - mae: 0.0351 - val_loss: 0.0038 - val_mae: 0.0538 - 2s/epoch - 4ms/step
# epochs:40
# 477/477 - 2s - loss: 0.0025 - mae: 0.0333 - val_loss: 0.0034 - val_mae: 0.0455 - 2s/epoch - 4ms/step
# epochs:41
# 477/477 - 2s - loss: 0.0027 - mae: 0.0354 - val_loss: 0.0032 - val_mae: 0.0454 - 2s/epoch - 5ms/step
# epochs:42
# 477/477 - 3s - loss: 0.0026 - mae: 0.0339 - val_loss: 0.0027 - val_mae: 0.0408 - 3s/epoch - 6ms/step
# epochs:43
# 477/477 - 2s - loss: 0.0025 - mae: 0.0333 - val_loss: 0.0034 - val_mae: 0.0487 - 2s/epoch - 5ms/step
# epochs:44
# 477/477 - 2s - loss: 0.0025 - mae: 0.0340 - val_loss: 0.0032 - val_mae: 0.0460 - 2s/epoch - 4ms/step
# epochs:45
# 477/477 - 2s - loss: 0.0026 - mae: 0.0348 - val_loss: 0.0027 - val_mae: 0.0400 - 2s/epoch - 4ms/step
# epochs:46
# 477/477 - 2s - loss: 0.0027 - mae: 0.0351 - val_loss: 0.0040 - val_mae: 0.0557 - 2s/epoch - 5ms/step
# epochs:47
# 477/477 - 2s - loss: 0.0024 - mae: 0.0330 - val_loss: 0.0030 - val_mae: 0.0417 - 2s/epoch - 5ms/step
# epochs:48
# 477/477 - 2s - loss: 0.0025 - mae: 0.0338 - val_loss: 0.0033 - val_mae: 0.0473 - 2s/epoch - 5ms/step
# epochs:49
# 477/477 - 2s - loss: 0.0025 - mae: 0.0338 - val_loss: 0.0029 - val_mae: 0.0420 - 2s/epoch - 4ms/step
# epochs:50
# 477/477 - 2s - loss: 0.0024 - mae: 0.0331 - val_loss: 0.0030 - val_mae: 0.0417 - 2s/epoch - 4ms/step
# epochs:51
# 477/477 - 2s - loss: 0.0025 - mae: 0.0336 - val_loss: 0.0027 - val_mae: 0.0403 - 2s/epoch - 4ms/step
# epochs:52
# 477/477 - 2s - loss: 0.0024 - mae: 0.0325 - val_loss: 0.0032 - val_mae: 0.0457 - 2s/epoch - 4ms/step
# epochs:53
# 477/477 - 2s - loss: 0.0025 - mae: 0.0332 - val_loss: 0.0031 - val_mae: 0.0456 - 2s/epoch - 4ms/step
# epochs:54
# 477/477 - 2s - loss: 0.0025 - mae: 0.0334 - val_loss: 0.0031 - val_mae: 0.0456 - 2s/epoch - 4ms/step
# epochs:55
# 477/477 - 2s - loss: 0.0024 - mae: 0.0327 - val_loss: 0.0034 - val_mae: 0.0484 - 2s/epoch - 4ms/step
# epochs:56
# 477/477 - 2s - loss: 0.0025 - mae: 0.0331 - val_loss: 0.0030 - val_mae: 0.0451 - 2s/epoch - 5ms/step
# epochs:57
# 477/477 - 2s - loss: 0.0024 - mae: 0.0331 - val_loss: 0.0027 - val_mae: 0.0408 - 2s/epoch - 4ms/step
# epochs:58
# 477/477 - 2s - loss: 0.0023 - mae: 0.0327 - val_loss: 0.0027 - val_mae: 0.0390 - 2s/epoch - 4ms/step
# epochs:59
# 477/477 - 2s - loss: 0.0024 - mae: 0.0325 - val_loss: 0.0027 - val_mae: 0.0412 - 2s/epoch - 5ms/step
# epochs:60
# 477/477 - 2s - loss: 0.0024 - mae: 0.0326 - val_loss: 0.0032 - val_mae: 0.0456 - 2s/epoch - 5ms/step
# epochs:61
# 477/477 - 2s - loss: 0.0023 - mae: 0.0323 - val_loss: 0.0032 - val_mae: 0.0433 - 2s/epoch - 4ms/step
# epochs:62
# 477/477 - 2s - loss: 0.0023 - mae: 0.0321 - val_loss: 0.0028 - val_mae: 0.0420 - 2s/epoch - 4ms/step
# epochs:63
# 477/477 - 2s - loss: 0.0023 - mae: 0.0325 - val_loss: 0.0033 - val_mae: 0.0467 - 2s/epoch - 5ms/step
# epochs:64
# 477/477 - 2s - loss: 0.0024 - mae: 0.0329 - val_loss: 0.0032 - val_mae: 0.0467 - 2s/epoch - 5ms/step
# epochs:65
# 477/477 - 2s - loss: 0.0023 - mae: 0.0320 - val_loss: 0.0034 - val_mae: 0.0472 - 2s/epoch - 5ms/step
# epochs:66
# 477/477 - 2s - loss: 0.0024 - mae: 0.0325 - val_loss: 0.0035 - val_mae: 0.0504 - 2s/epoch - 4ms/step
# epochs:67
# 477/477 - 2s - loss: 0.0022 - mae: 0.0317 - val_loss: 0.0029 - val_mae: 0.0429 - 2s/epoch - 4ms/step
# epochs:68
# 477/477 - 2s - loss: 0.0024 - mae: 0.0330 - val_loss: 0.0034 - val_mae: 0.0478 - 2s/epoch - 5ms/step
# epochs:69
# 477/477 - 2s - loss: 0.0023 - mae: 0.0318 - val_loss: 0.0028 - val_mae: 0.0410 - 2s/epoch - 4ms/step
# epochs:70
# 477/477 - 3s - loss: 0.0023 - mae: 0.0320 - val_loss: 0.0028 - val_mae: 0.0422 - 3s/epoch - 6ms/step
# epochs:71
# 477/477 - 2s - loss: 0.0024 - mae: 0.0325 - val_loss: 0.0031 - val_mae: 0.0442 - 2s/epoch - 5ms/step
# epochs:72
# 477/477 - 2s - loss: 0.0024 - mae: 0.0328 - val_loss: 0.0034 - val_mae: 0.0482 - 2s/epoch - 5ms/step
# epochs:73
# 477/477 - 2s - loss: 0.0023 - mae: 0.0317 - val_loss: 0.0030 - val_mae: 0.0424 - 2s/epoch - 5ms/step
# epochs:74
# 477/477 - 2s - loss: 0.0022 - mae: 0.0315 - val_loss: 0.0031 - val_mae: 0.0443 - 2s/epoch - 5ms/step
# epochs:75
# 477/477 - 2s - loss: 0.0022 - mae: 0.0306 - val_loss: 0.0029 - val_mae: 0.0413 - 2s/epoch - 5ms/step
# epochs:76
# 477/477 - 2s - loss: 0.0022 - mae: 0.0312 - val_loss: 0.0028 - val_mae: 0.0413 - 2s/epoch - 5ms/step
# epochs:77
# 477/477 - 2s - loss: 0.0022 - mae: 0.0314 - val_loss: 0.0029 - val_mae: 0.0424 - 2s/epoch - 5ms/step
# epochs:78
# 477/477 - 2s - loss: 0.0022 - mae: 0.0319 - val_loss: 0.0030 - val_mae: 0.0428 - 2s/epoch - 4ms/step
# epochs:79
# 477/477 - 2s - loss: 0.0022 - mae: 0.0319 - val_loss: 0.0041 - val_mae: 0.0542 - 2s/epoch - 4ms/step
# epochs:80
# 477/477 - 2s - loss: 0.0023 - mae: 0.0325 - val_loss: 0.0041 - val_mae: 0.0538 - 2s/epoch - 4ms/step
# epochs:81
# 477/477 - 2s - loss: 0.0023 - mae: 0.0323 - val_loss: 0.0033 - val_mae: 0.0473 - 2s/epoch - 5ms/step
# epochs:82
# 477/477 - 2s - loss: 0.0022 - mae: 0.0320 - val_loss: 0.0035 - val_mae: 0.0494 - 2s/epoch - 5ms/step
# epochs:83
# 477/477 - 2s - loss: 0.0022 - mae: 0.0312 - val_loss: 0.0032 - val_mae: 0.0454 - 2s/epoch - 4ms/step
# epochs:84
# 477/477 - 2s - loss: 0.0022 - mae: 0.0321 - val_loss: 0.0038 - val_mae: 0.0516 - 2s/epoch - 4ms/step
# epochs:85
# 477/477 - 2s - loss: 0.0022 - mae: 0.0318 - val_loss: 0.0040 - val_mae: 0.0537 - 2s/epoch - 5ms/step
# epochs:86
# 477/477 - 2s - loss: 0.0023 - mae: 0.0320 - val_loss: 0.0035 - val_mae: 0.0481 - 2s/epoch - 4ms/step
# epochs:87
# 477/477 - 3s - loss: 0.0021 - mae: 0.0312 - val_loss: 0.0028 - val_mae: 0.0407 - 3s/epoch - 5ms/step
# epochs:88
# 477/477 - 2s - loss: 0.0022 - mae: 0.0313 - val_loss: 0.0030 - val_mae: 0.0440 - 2s/epoch - 4ms/step
# epochs:89
# 477/477 - 2s - loss: 0.0022 - mae: 0.0313 - val_loss: 0.0029 - val_mae: 0.0423 - 2s/epoch - 4ms/step
# epochs:90
# 477/477 - 2s - loss: 0.0022 - mae: 0.0312 - val_loss: 0.0033 - val_mae: 0.0469 - 2s/epoch - 4ms/step
# epochs:91
# 477/477 - 2s - loss: 0.0021 - mae: 0.0311 - val_loss: 0.0029 - val_mae: 0.0427 - 2s/epoch - 4ms/step
# epochs:92
# 477/477 - 2s - loss: 0.0021 - mae: 0.0310 - val_loss: 0.0028 - val_mae: 0.0394 - 2s/epoch - 5ms/step
# epochs:93
# 477/477 - 2s - loss: 0.0022 - mae: 0.0312 - val_loss: 0.0030 - val_mae: 0.0415 - 2s/epoch - 4ms/step
# epochs:94
# 477/477 - 2s - loss: 0.0021 - mae: 0.0310 - val_loss: 0.0031 - val_mae: 0.0442 - 2s/epoch - 5ms/step
# epochs:95
# 477/477 - 2s - loss: 0.0021 - mae: 0.0306 - val_loss: 0.0033 - val_mae: 0.0463 - 2s/epoch - 4ms/step
# epochs:96
# 477/477 - 2s - loss: 0.0022 - mae: 0.0311 - val_loss: 0.0028 - val_mae: 0.0406 - 2s/epoch - 4ms/step
# epochs:97
# 477/477 - 2s - loss: 0.0022 - mae: 0.0305 - val_loss: 0.0037 - val_mae: 0.0500 - 2s/epoch - 5ms/step
# epochs:98
# 477/477 - 2s - loss: 0.0023 - mae: 0.0323 - val_loss: 0.0035 - val_mae: 0.0480 - 2s/epoch - 4ms/step
# epochs:99
# 477/477 - 2s - loss: 0.0021 - mae: 0.0312 - val_loss: 0.0031 - val_mae: 0.0426 - 2s/epoch - 4ms/step

# %%
a = 3

# %%
model.evaluate(trainX, trainY, batch_size = a)
# Out:
# 477/477 [==============================] - 1s 3ms/step - loss: 0.0027 - mae: 0.0414
# [0.0027099272701889277, 0.04138224199414253]

# %%
print(custom_hist.train_loss)
# Out:
# [0.01998017728328705, 0.020233742892742157, 0.014184574596583843, 0.01016801968216896, 0.008786695078015327, 0.008125859312713146, 0.007007337640970945, 0.00675453245639801, 0.00679842010140419, 0.006392937619239092, 0.0057363142259418964, 0.005637355614453554, 0.005547252483665943, 0.005615574773401022, 0.005396118387579918, 0.004969791509211063, 0.004870687611401081, 0.004843173548579216, 0.004540824331343174, 0.004690260160714388, 0.004489294718950987, 0.004389879759401083, 0.003994287457317114, 0.0035914264153689146, 0.0034854973200708628, 0.0034535257145762444, 0.003353980602696538, 0.0030814409255981445, 0.0031058616004884243, 0.0029724303167313337, 0.002847149036824703, 0.0029977562371641397, 0.0027022564318031073, 0.0028330953791737556, 0.0026815941091626883, 0.0026922316756099463, 0.0026681385934352875, 0.0025765947066247463, 0.0027489904314279556, 0.0026640063151717186, 0.0025282828137278557, 0.0026936104986816645, 0.002610189840197563, 0.002468627877533436, 0.0025253293570131063, 0.0025881680194288492, 0.0027160109020769596, 0.002449805848300457, 0.002498315880075097, 0.002524672308936715, 0.002404905157163739, 0.0025394123513251543, 0.0023749638348817825, 0.0025020192842930555, 0.0024588771630078554, 0.002361197955906391, 0.00251420377753675, 0.002411002991721034, 0.0023487848229706287, 0.0023774716537445784, 0.002374476520344615, 0.0022891706321388483, 0.0023010012228041887, 0.0023450537119060755, 0.002413302194327116, 0.002327979076653719, 0.0023656825069338083, 0.002236098749563098, 0.002390868728980422, 0.002335786120966077, 0.002265488263219595, 0.0023500840179622173, 0.002357759512960911, 0.002286534057930112, 0.002189654391258955, 0.002166538033634424, 0.0022073141299188137, 0.0022264819126576185, 0.002207129029557109, 0.002242004731670022, 0.0022609569132328033, 0.0023224216420203447, 0.0022202664986252785, 0.0021858199033886194, 0.0022046228405088186, 0.0022106815595179796, 0.0022854898124933243, 0.002123943530023098, 0.0022345276083797216, 0.0021790587343275547, 0.002190772444009781, 0.002144932048395276, 0.0020903642289340496, 0.002179258968681097, 0.0021208759862929583, 0.0021105448249727488, 0.0021700356155633926, 0.0021709417924284935, 0.002258552936837077, 0.0020912017207592726]

# %%
plt.figure(figsize=(20,10))
plt.plot(custom_hist.train_loss, color = 'blue', label = 'train_loss')
plt.plot(custom_hist.val_loss, color = 'red', label = 'val_loss')
plt.title('Training Loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
from keras.models import load_model
model = load_model('/content/best-model-radish.h5')

# %% [markdown]
# Train Data *평가*

# %%
model.evaluate(trainX, trainY, batch_size=a)
# Out:
# 477/477 [==============================] - 2s 3ms/step - loss: 0.0026 - mae: 0.0402
# [0.002553999423980713, 0.040215156972408295]

# %%
predicted_price_train = model.predict(trainX, batch_size=a, verbose=1)
# Out:
# 477/477 [==============================] - 2s 2ms/step

# %%
trainY_test = np.delete(trainY, np.s_[1:a], axis=1)
predicted_price_train_test = np.delete(predicted_price_train, np.s_[1:a], axis=1)

trainY_test = np.reshape(trainY_test, (1431, 1))
predicted_price_train_test = np.reshape(predicted_price_train_test, (1431, 1))
print(trainY_test.shape)
print(predicted_price_train_test.shape)
# Out:
# (1431, 1)
# (1431, 1)

# %%
plt.figure(figsize=(20,10))
plt.plot(trainY_test, color = 'blue', label = 'Actual Stock Price')
plt.plot(predicted_price_train_test, color = 'red', label = 'Predicted Stock Price')
plt.title('Price Prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
predicted_price_train_test = np.reshape(predicted_price_train_test, (1431, ))
predicted_price_train_test = scaler_target.inverse_transform(predicted_price_train_test.reshape(-1,1))

print(predicted_price_train_test, predicted_price_train_test.shape)

trainY_test = scaler_target.inverse_transform(trainY_test.reshape(-1,1))

print(trainY_test, trainY_test.shape)
# Out:
# [[1813.0887]
#  [1808.8407]
#  [1789.2644]
#  ...
#  [1892.5416]
#  [1848.4684]
#  [1804.0425]] (1431, 1)
# [[1787.]
#  [1787.]
#  [1769.]
#  ...
#  [1818.]
#  [1818.]
#  [1793.]] (1431, 1)

# %%
from sklearn.metrics import mean_squared_error 
MSE = mean_squared_error(trainY_test, predicted_price_train_test) 
np.sqrt(MSE)
# Out:
# 173.48646556792613

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(trainY_test, predicted_price_train_test)
# Out:
# 138.02800366330362

# %% [markdown]
# Val Date 평가

# %%
model.evaluate(validX, validY, batch_size=a)
# Out:
# 159/159 [==============================] - 0s 3ms/step - loss: 0.0027 - mae: 0.0408
# [0.002654194599017501, 0.040824003517627716]

# %%
predicted_price_valid = model.predict(validX, batch_size=a, verbose=1)
# Out:
# 159/159 [==============================] - 0s 2ms/step

# %%
validY_test = np.delete(validY, np.s_[1:a], axis=1)
predicted_price_valid_test = np.delete(predicted_price_valid, np.s_[1:a], axis=1)

validY_test = np.reshape(validY_test, (477, 1))
predicted_price_valid_test = np.reshape(predicted_price_valid_test, (477, 1))
print(validY_test.shape)
print(predicted_price_valid_test.shape)

plt.figure(figsize=(20,10))
plt.plot(validY_test, color = 'blue', label = 'Actual Stock Price')
plt.plot(predicted_price_valid_test, color = 'red', label = 'Predicted Stock Price')
plt.title('Price Prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# (477, 1)
# (477, 1)

# %%
predicted_price_valid_test = np.reshape(predicted_price_valid_test, (477, ))
predicted_price_valid_test = scaler_target.inverse_transform(predicted_price_valid_test.reshape(-1,1))

print(predicted_price_valid_test, predicted_price_valid_test.shape)

validY_test = scaler_target.inverse_transform(validY_test.reshape(-1,1))

print(validY_test, validY_test.shape)
# Out:
# [[3102.089 ]
#  [2909.498 ]
#  [3086.8545]
#  [2110.2021]
#  [2021.9312]
#  [2204.709 ]
#  [1402.8328]
#  [1369.7825]
#  [1426.6188]
#  [1372.4417]
#  [1398.5704]
#  [1329.7948]
#  [1535.4022]
#  [1604.4623]
#  [1564.7462]
#  [1699.8429]
#  [1699.1664]
#  [1643.4327]
#  [1680.9222]
#  [1701.2976]
#  [1704.5374]
#  [1669.874 ]
#  [1638.8934]
#  [1654.0776]
#  [1643.9572]
#  [1647.5009]
#  [1617.9664]
#  [1609.3884]
#  [1621.5935]
#  [1651.0083]
#  [1645.049 ]
#  [1638.0924]
#  [1687.2157]
#  [1726.7585]
#  [1733.342 ]
#  [1718.3721]
#  [1705.52  ]
#  [1695.9484]
#  [1712.6167]
#  [1708.1133]
#  [1720.3514]
#  [1734.9728]
#  [1725.5673]
#  [1711.6537]
#  [1640.9424]
#  [1611.2917]
#  [1607.0748]
#  [1596.3496]
#  [1548.0636]
#  [1529.6682]
#  [1495.2959]
#  [1515.3779]
#  [1527.5521]
#  [1538.8955]
#  [1533.3595]
#  [1553.5874]
#  [1509.8414]
#  [1468.9463]
#  [1443.9945]
#  [1422.3865]
#  [1418.1622]
#  [1482.2659]
#  [1492.0632]
#  [1587.3903]
#  [1610.8054]
#  [1622.0996]
#  [1552.2137]
#  [1511.1093]
#  [1485.9114]
#  [1461.1855]
#  [1444.6433]
#  [1425.0614]
#  [1435.357 ]
#  [1435.8871]
#  [1403.0804]
#  [1403.6798]
#  [1421.2557]
#  [1449.1475]
#  [1471.933 ]
#  [1487.8684]
#  [1486.9069]
#  [1491.6537]
#  [1500.9816]
#  [1504.1893]
#  [1518.2292]
#  [1509.9602]
#  [1502.6896]
#  [1501.9668]
#  [1489.3241]
#  [1490.3527]
#  [1460.7256]
#  [1449.5525]
#  [1446.9065]
#  [1435.7689]
#  [1434.1206]
#  [1453.7698]
#  [1480.3488]
#  [1507.6095]
#  [1519.1676]
#  [1527.4137]
#  [1520.5491]
#  [1533.2452]
#  [1545.9   ]
#  [1550.0304]
#  [1542.9865]
#  [1523.6489]
#  [1524.87  ]
#  [1522.8362]
#  [1505.9323]
#  [1495.196 ]
#  [1478.4377]
#  [1490.6396]
#  [1507.4364]
#  [1503.3698]
#  [1504.9446]
#  [1474.0172]
#  [1459.7432]
#  [1486.9861]
#  [1493.377 ]
#  [1609.8846]
#  [1693.1859]
#  [1766.7421]
#  [1820.7848]
#  [1784.261 ]
#  [1776.8218]
#  [1807.1099]
#  [1802.1626]
#  [1796.9688]
#  [1774.2865]
#  [1776.7727]
#  [1809.5708]
#  [1822.7842]
#  [1825.1967]
#  [1811.2749]
#  [1824.8615]
#  [1907.8605]
#  [1910.0184]
#  [1865.9583]
#  [1787.8398]
#  [1781.2617]
#  [1696.9675]
#  [1628.0481]
#  [1555.0715]
#  [1509.8154]
#  [1481.1187]
#  [1457.145 ]
#  [1450.006 ]
#  [1782.2844]
#  [1871.8339]
#  [1857.4764]
#  [1872.5269]
#  [1856.9575]
#  [1785.5363]
#  [1758.6738]
#  [1746.8601]
#  [1724.7755]
#  [1714.0018]
#  [1680.0105]
#  [1681.7799]
#  [1701.1984]
#  [1694.4794]
#  [1691.635 ]
#  [1681.5956]
#  [1695.9374]
#  [1719.0803]
#  [1713.2504]
#  [1717.3827]
#  [1711.357 ]
#  [1727.8556]
#  [1749.8844]
#  [1742.3784]
#  [1727.653 ]
#  [1712.0161]
#  [1722.8251]
#  [1743.8683]
#  [1750.8484]
#  [1737.1943]
#  [1669.3641]
#  [1723.9655]
#  [1682.37  ]
#  [1642.7366]
#  [1642.9839]
#  [1599.0332]
#  [1561.9884]
#  [1555.107 ]
#  [1542.196 ]
#  [1534.8248]
#  [1561.0299]
#  [1594.3976]
#  [1660.739 ]
#  [1653.8379]
#  [1630.2576]
#  [1602.8287]
#  [1601.2458]
#  [1597.1339]
#  [1597.1155]
#  [1594.9839]
#  [1613.2977]
#  [1626.622 ]
#  [1632.3137]
#  [1620.4801]
#  [1697.4045]
#  [1712.2477]
#  [1725.125 ]
#  [1719.9445]
#  [1730.2506]
#  [1809.0946]
#  [1887.9198]
#  [1977.1324]
#  [2011.0051]
#  [2028.3354]
#  [2200.4216]
#  [2220.3308]
#  [2215.2036]
#  [2111.6587]
#  [2145.9097]
#  [2182.6716]
#  [2181.8547]
#  [2178.327 ]
#  [2153.0693]
#  [2157.393 ]
#  [2222.438 ]
#  [2221.7234]
#  [2215.3906]
#  [2561.8745]
#  [2811.4575]
#  [2856.7424]
#  [2978.4736]
#  [2991.5059]
#  [2935.5364]
#  [2887.155 ]
#  [2912.6606]
#  [2964.5273]
#  [2920.5261]
#  [2927.2314]
#  [2919.6997]
#  [2937.4968]
#  [2989.7168]
#  [3014.0232]
#  [3010.3235]
#  [2998.2388]
#  [3025.4863]
#  [3016.0986]
#  [3001.3442]
#  [2879.929 ]
#  [2836.448 ]
#  [2873.373 ]
#  [2891.3354]
#  [2744.783 ]
#  [2579.8225]
#  [2573.5032]
#  [2638.508 ]
#  [2593.9985]
#  [2567.768 ]
#  [2586.8838]
#  [2578.8389]
#  [2594.9426]
#  [2502.6348]
#  [2657.4514]
#  [2548.574 ]
#  [2483.901 ]
#  [2497.4678]
#  [2458.215 ]
#  [2460.9014]
#  [2649.7434]
#  [2718.4116]
#  [2730.0796]
#  [2714.8633]
#  [2844.6946]
#  [2981.935 ]
#  [3070.0286]
#  [3192.7175]
#  [3164.23  ]
#  [3096.6414]
#  [3020.316 ]
#  [3024.5015]
#  [3011.3203]
#  [3011.5862]
#  [3011.34  ]
#  [2985.0222]
#  [2956.2612]
#  [2973.7986]
#  [2945.9458]
#  [2935.724 ]
#  [3508.4067]
#  [3542.9875]
#  [3667.469 ]
#  [3845.9045]
#  [3733.8716]
#  [3718.5752]
#  [3569.4397]
#  [3507.0295]
#  [3349.072 ]
#  [3163.1577]
#  [3033.9204]
#  [3028.278 ]
#  [2902.9534]
#  [2722.291 ]
#  [2727.79  ]
#  [2868.4917]
#  [2888.737 ]
#  [2877.3826]
#  [2832.7869]
#  [2755.4783]
#  [2686.3728]
#  [2631.57  ]
#  [2598.6501]
#  [2448.3008]
#  [2402.562 ]
#  [2404.6   ]
#  [2362.6804]
#  [2252.5247]
#  [2193.3643]
#  [2214.1619]
#  [2240.8064]
#  [2245.3054]
#  [2270.1072]
#  [2148.1257]
#  [2080.1345]
#  [2044.3656]
#  [1997.4352]
#  [1974.6165]
#  [1977.7992]
#  [2013.6772]
#  [2014.1165]
#  [2017.0292]
#  [2029.7183]
#  [1996.0339]
#  [1996.4019]
#  [1992.4761]
#  [1992.8878]
#  [1991.9565]
#  [2021.2292]
#  [1973.2852]
#  [1910.9503]
#  [1865.8241]
#  [1858.5901]
#  [1865.7155]
#  [1877.6926]
#  [1882.2588]
#  [1879.5289]
#  [1891.996 ]
#  [1838.7103]
#  [1825.6464]
#  [1791.2933]
#  [1763.1376]
#  [1759.607 ]
#  [1779.6648]
#  [1813.7582]
#  [1824.6923]
#  [1818.2139]
#  [1821.6517]
#  [1813.5166]
#  [1827.4448]
#  [1829.4324]
#  [1826.1897]
#  [1865.3944]
#  [1898.6636]
#  [1843.8402]
#  [1789.3995]
#  [1765.8042]
#  [1817.7168]
#  [1874.4137]
#  [1858.235 ]
#  [1832.5723]
#  [1849.364 ]
#  [1848.8066]
#  [1854.2594]
#  [1887.9413]
#  [1926.3451]
#  [1929.2751]
#  [1910.1638]
#  [1898.8136]
#  [1880.2921]
#  [1843.0846]
#  [1823.0571]
#  [1810.4401]
#  [1788.3378]
#  [1781.2596]
#  [1798.7203]
#  [1806.6678]
#  [1801.6097]
#  [1800.2039]
#  [1790.727 ]
#  [1836.9585]
#  [1857.1426]
#  [1853.0249]
#  [1850.9198]
#  [1851.0505]
#  [1870.1824]
#  [1870.6393]
#  [1859.155 ]
#  [1865.5028]
#  [1877.633 ]
#  [1919.9219]
#  [1944.4603]
#  [1959.16  ]
#  [1979.835 ]
#  [1958.2493]
#  [1981.8093]
#  [1963.6442]
#  [1939.5807]
#  [1968.0425]
#  [1946.5665]
#  [1939.8568]
#  [1945.2844]
#  [1965.1259]
#  [1932.9602]
#  [2012.6959]
#  [2074.5603]
#  [2103.0266]
#  [2071.195 ]
#  [2025.71  ]
#  [2001.385 ]
#  [2021.2643]
#  [2139.4856]
#  [2162.2947]
#  [2141.6587]
#  [2116.1833]
#  [2121.5845]
#  [2077.134 ]
#  [2078.2217]
#  [2059.321 ]
#  [2064.4167]
#  [2050.862 ]
#  [2038.1676]
#  [2049.8125]
#  [2101.5122]
#  [2048.3818]
#  [2027.0293]
#  [2188.2864]
#  [2234.6543]
#  [2204.7502]
#  [2257.4382]
#  [2283.1758]
#  [2292.6025]
#  [2274.3503]
#  [2289.3074]
#  [2395.745 ]
#  [2494.6226]
#  [2514.8662]
#  [2464.7754]
#  [2517.358 ]
#  [2547.7754]
#  [2886.7136]
#  [2786.9355]
#  [2804.1797]
#  [3420.6604]
#  [3512.8606]
#  [3408.9907]
#  [3379.288 ]
#  [3331.773 ]
#  [3267.6772]
#  [3589.908 ]
#  [3368.8843]
#  [3444.7405]
#  [3635.943 ]
#  [3663.5415]
#  [3600.022 ]
#  [3628.612 ]
#  [3589.1592]
#  [3663.0352]
#  [3617.0098]
#  [3605.5105]
#  [3506.7588]
#  [3491.4297]
#  [3623.3105]
#  [3529.0623]
#  [3522.5425]
#  [3509.2986]
#  [3581.3354]
#  [3763.5442]
#  [3726.612 ]
#  [3765.61  ]
#  [3729.1816]
#  [3527.2637]
#  [3245.183 ]] (477, 1)
# [[1768.]
#  [1726.]
#  [1726.]
#  [1705.]
#  [1623.]
#  [1593.]
#  [1618.]
#  [1618.]
#  [1618.]
#  [1605.]
#  [1630.]
#  [1609.]
#  [1609.]
#  [1609.]
#  [1584.]
#  [1584.]
#  [1584.]
#  [1584.]
#  [1584.]
#  [1559.]
#  [1571.]
#  [1571.]
#  [1571.]
#  [1535.]
#  [1535.]
#  [1535.]
#  [1588.]
#  [1564.]
#  [1584.]
#  [1625.]
#  [1625.]
#  [1625.]
#  [1625.]
#  [1597.]
#  [1597.]
#  [1584.]
#  [1584.]
#  [1584.]
#  [1584.]
#  [1584.]
#  [1584.]
#  [1494.]
#  [1494.]
#  [1494.]
#  [1494.]
#  [1394.]
#  [1452.]
#  [1354.]
#  [1412.]
#  [1432.]
#  [1432.]
#  [1432.]
#  [1432.]
#  [1276.]
#  [1276.]
#  [1276.]
#  [1276.]
#  [1276.]
#  [1334.]
#  [1352.]
#  [1472.]
#  [1472.]
#  [1472.]
#  [1310.]
#  [1310.]
#  [1310.]
#  [1310.]
#  [1310.]
#  [1312.]
#  [1332.]
#  [1292.]
#  [1234.]
#  [1292.]
#  [1332.]
#  [1332.]
#  [1352.]
#  [1352.]
#  [1352.]
#  [1332.]
#  [1332.]
#  [1352.]
#  [1372.]
#  [1372.]
#  [1334.]
#  [1334.]
#  [1334.]
#  [1334.]
#  [1294.]
#  [1292.]
#  [1292.]
#  [1292.]
#  [1292.]
#  [1352.]
#  [1352.]
#  [1352.]
#  [1372.]
#  [1372.]
#  [1372.]
#  [1372.]
#  [1372.]
#  [1372.]
#  [1372.]
#  [1372.]
#  [1372.]
#  [1354.]
#  [1354.]
#  [1354.]
#  [1354.]
#  [1372.]
#  [1372.]
#  [1372.]
#  [1372.]
#  [1312.]
#  [1312.]
#  [1372.]
#  [1372.]
#  [1533.]
#  [1580.]
#  [1612.]
#  [1678.]
#  [1630.]
#  [1630.]
#  [1668.]
#  [1668.]
#  [1668.]
#  [1668.]
#  [1668.]
#  [1668.]
#  [1710.]
#  [1710.]
#  [1710.]
#  [1710.]
#  [1768.]
#  [1768.]
#  [1714.]
#  [1647.]
#  [1671.]
#  [1487.]
#  [1487.]
#  [1353.]
#  [1353.]
#  [1353.]
#  [1353.]
#  [1360.]
#  [1701.]
#  [1701.]
#  [1646.]
#  [1701.]
#  [1701.]
#  [1630.]
#  [1630.]
#  [1616.]
#  [1616.]
#  [1616.]
#  [1587.]
#  [1587.]
#  [1587.]
#  [1587.]
#  [1587.]
#  [1587.]
#  [1587.]
#  [1587.]
#  [1587.]
#  [1587.]
#  [1613.]
#  [1613.]
#  [1613.]
#  [1613.]
#  [1613.]
#  [1621.]
#  [1621.]
#  [1621.]
#  [1646.]
#  [1621.]
#  [1533.]
#  [1634.]
#  [1509.]
#  [1509.]
#  [1509.]
#  [1456.]
#  [1456.]
#  [1456.]
#  [1456.]
#  [1456.]
#  [1513.]
#  [1513.]
#  [1513.]
#  [1513.]
#  [1513.]
#  [1484.]
#  [1480.]
#  [1480.]
#  [1480.]
#  [1494.]
#  [1494.]
#  [1494.]
#  [1494.]
#  [1494.]
#  [1583.]
#  [1583.]
#  [1583.]
#  [1583.]
#  [1583.]
#  [1703.]
#  [1779.]
#  [1826.]
#  [1826.]
#  [1897.]
#  [2064.]
#  [2040.]
#  [2040.]
#  [1957.]
#  [2040.]
#  [2054.]
#  [2069.]
#  [2069.]
#  [2059.]
#  [2059.]
#  [2116.]
#  [2116.]
#  [2087.]
#  [2411.]
#  [2589.]
#  [2660.]
#  [2857.]
#  [2877.]
#  [2854.]
#  [2854.]
#  [2877.]
#  [2940.]
#  [2897.]
#  [2926.]
#  [2926.]
#  [2917.]
#  [2974.]
#  [2997.]
#  [2997.]
#  [2997.]
#  [2997.]
#  [2997.]
#  [2997.]
#  [2873.]
#  [2873.]
#  [2873.]
#  [2885.]
#  [2714.]
#  [2575.]
#  [2626.]
#  [2626.]
#  [2570.]
#  [2546.]
#  [2546.]
#  [2546.]
#  [2546.]
#  [2445.]
#  [2600.]
#  [2445.]
#  [2445.]
#  [2445.]
#  [2411.]
#  [2411.]
#  [2554.]
#  [2609.]
#  [2609.]
#  [2609.]
#  [2723.]
#  [2866.]
#  [2946.]
#  [3096.]
#  [3096.]
#  [3064.]
#  [3026.]
#  [3026.]
#  [3023.]
#  [3032.]
#  [3032.]
#  [3010.]
#  [3010.]
#  [3010.]
#  [2970.]
#  [2970.]
#  [3496.]
#  [3552.]
#  [3802.]
#  [4203.]
#  [3938.]
#  [3952.]
#  [3672.]
#  [3685.]
#  [3433.]
#  [3185.]
#  [3143.]
#  [3143.]
#  [2975.]
#  [2785.]
#  [2810.]
#  [2893.]
#  [2870.]
#  [2824.]
#  [2792.]
#  [2703.]
#  [2678.]
#  [2644.]
#  [2578.]
#  [2404.]
#  [2404.]
#  [2404.]
#  [2338.]
#  [2164.]
#  [2185.]
#  [2185.]
#  [2185.]
#  [2185.]
#  [2185.]
#  [2024.]
#  [1990.]
#  [1990.]
#  [1924.]
#  [1924.]
#  [1924.]
#  [1924.]
#  [1904.]
#  [1924.]
#  [1924.]
#  [1884.]
#  [1884.]
#  [1884.]
#  [1884.]
#  [1884.]
#  [1924.]
#  [1804.]
#  [1772.]
#  [1772.]
#  [1772.]
#  [1772.]
#  [1752.]
#  [1772.]
#  [1772.]
#  [1772.]
#  [1694.]
#  [1694.]
#  [1660.]
#  [1660.]
#  [1660.]
#  [1698.]
#  [1698.]
#  [1698.]
#  [1698.]
#  [1698.]
#  [1698.]
#  [1698.]
#  [1698.]
#  [1710.]
#  [1760.]
#  [1760.]
#  [1663.]
#  [1663.]
#  [1663.]
#  [1760.]
#  [1760.]
#  [1704.]
#  [1704.]
#  [1738.]
#  [1738.]
#  [1724.]
#  [1760.]
#  [1760.]
#  [1760.]
#  [1760.]
#  [1760.]
#  [1760.]
#  [1664.]
#  [1664.]
#  [1684.]
#  [1684.]
#  [1684.]
#  [1684.]
#  [1684.]
#  [1684.]
#  [1684.]
#  [1684.]
#  [1724.]
#  [1724.]
#  [1724.]
#  [1724.]
#  [1738.]
#  [1738.]
#  [1738.]
#  [1738.]
#  [1738.]
#  [1772.]
#  [1793.]
#  [1810.]
#  [1837.]
#  [1851.]
#  [1831.]
#  [1853.]
#  [1828.]
#  [1828.]
#  [1828.]
#  [1828.]
#  [1828.]
#  [1828.]
#  [1828.]
#  [1828.]
#  [1926.]
#  [1926.]
#  [1946.]
#  [1918.]
#  [1885.]
#  [1902.]
#  [1904.]
#  [1996.]
#  [2016.]
#  [2016.]
#  [1996.]
#  [1996.]
#  [1936.]
#  [1996.]
#  [1936.]
#  [1936.]
#  [1936.]
#  [1956.]
#  [1976.]
#  [1976.]
#  [1916.]
#  [1916.]
#  [2076.]
#  [2056.]
#  [2070.]
#  [2124.]
#  [2158.]
#  [2158.]
#  [2158.]
#  [2224.]
#  [2286.]
#  [2346.]
#  [2366.]
#  [2326.]
#  [2412.]
#  [2412.]
#  [2732.]
#  [2592.]
#  [2692.]
#  [3262.]
#  [3426.]
#  [3353.]
#  [3395.]
#  [3335.]
#  [3335.]
#  [3760.]
#  [3445.]
#  [3653.]
#  [3820.]
#  [3863.]
#  [3778.]
#  [3870.]
#  [3795.]
#  [3870.]
#  [3828.]
#  [3828.]
#  [3695.]
#  [3703.]
#  [3828.]
#  [3686.]
#  [3686.]
#  [3686.]
#  [3786.]
#  [3995.]
#  [3995.]
#  [3995.]
#  [3995.]
#  [3570.]
#  [3193.]
#  [3153.]
#  [3443.]
#  [3178.]] (477, 1)

# %%
plt.figure(figsize=(20,10))
plt.plot(validY_test, color = 'blue', label = 'Actual Stock Price')
plt.plot(predicted_price_valid_test, color = 'red', label = 'Predicted Stock Price')
plt.title('Price Prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error 
MSE = mean_squared_error(validY_test, predicted_price_valid_test) 
np.sqrt(MSE)
# Out:
# 208.98489072962946

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(validY_test, predicted_price_valid_test)
# Out:
# 152.10026886178264

# %% [markdown]
# Test Data 평가

# %%
model.evaluate(testX, testY, batch_size=a)
# Out:
# 159/159 [==============================] - 0s 3ms/step - loss: 0.0042 - mae: 0.0520
# [0.004177647177129984, 0.05200831964612007]

# %%
predicted_price_test = model.predict(testX, batch_size=a, verbose=1)
# Out:
# 159/159 [==============================] - 0s 2ms/step

# %%
testY_test = np.delete(testY, np.s_[1:a], axis=1)
predicted_price_test_test = np.delete(predicted_price_test, np.s_[1:a], axis=1)

testY_test = np.reshape(testY_test, (477, 1))
predicted_price_test_test = np.reshape(predicted_price_test_test, (477, 1))
print(testY_test.shape)
print(predicted_price_test_test.shape)

plt.figure(figsize=(20,10))
plt.plot(testY_test, color = 'blue', label = 'Actual Stock Price')
plt.plot(predicted_price_test_test, color = 'red', label = 'Predicted Stock Price')
plt.title('Price Prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# (477, 1)
# (477, 1)

# %%
predicted_price_test_test = np.reshape(predicted_price_test_test, (477, ))
predicted_price_test_test = scaler_target.inverse_transform(predicted_price_test_test.reshape(-1,1))

print(predicted_price_test_test, predicted_price_test_test.shape)

testY_test = scaler_target.inverse_transform(testY_test.reshape(-1,1))

print(testY_test, testY_test.shape)
# Out:
# [[3188.9727]
#  [3304.8818]
#  [3247.7063]
#  [2932.6274]
#  [2640.4504]
#  [2526.7915]
#  [2634.0183]
#  [2757.7148]
#  [2708.2861]
#  [2676.4607]
#  [2685.1392]
#  [2565.2178]
#  [2485.0432]
#  [2462.4558]
#  [2432.8123]
#  [2458.7942]
#  [2354.678 ]
#  [2327.265 ]
#  [2323.7883]
#  [2324.6501]
#  [2197.2302]
#  [2086.714 ]
#  [2114.5334]
#  [2146.13  ]
#  [2157.3982]
#  [2168.3896]
#  [2118.606 ]
#  [2059.4048]
#  [2024.2367]
#  [2017.4724]
#  [2037.0215]
#  [2060.2031]
#  [2095.7205]
#  [2096.1526]
#  [2081.4622]
#  [2082.685 ]
#  [2049.3064]
#  [1996.8964]
#  [2005.461 ]
#  [2033.2202]
#  [1998.1357]
#  [1999.0621]
#  [1994.3937]
#  [1977.5999]
#  [1946.5522]
#  [1897.3674]
#  [1899.2404]
#  [1900.6046]
#  [1896.0066]
#  [1907.9597]
#  [1889.8496]
#  [1836.5221]
#  [1836.1134]
#  [1856.2053]
#  [2253.3838]
#  [2319.8613]
#  [2288.8992]
#  [2252.2642]
#  [2218.9958]
#  [2209.8389]
#  [2207.5215]
#  [2147.542 ]
#  [2109.909 ]
#  [2340.6753]
#  [2455.963 ]
#  [2472.2383]
#  [2444.339 ]
#  [2408.0222]
#  [2407.4424]
#  [2395.0393]
#  [2271.7803]
#  [2193.6953]
#  [2164.1396]
#  [2298.563 ]
#  [2339.606 ]
#  [2349.482 ]
#  [2334.2236]
#  [2315.5466]
#  [2152.4854]
#  [2056.071 ]
#  [2031.8873]
#  [2019.8137]
#  [2015.3918]
#  [2013.2214]
#  [1983.8885]
#  [1970.1688]
#  [1912.6716]
#  [1893.6853]
#  [1938.2386]
#  [1884.3112]
#  [1832.0286]
#  [1798.5352]
#  [1801.5255]
#  [1822.6614]
#  [1785.5508]
#  [1764.3807]
#  [1766.6937]
#  [1780.4624]
#  [1777.9008]
#  [1763.7917]
#  [1733.5819]
#  [1730.3706]
#  [1743.2849]
#  [1738.6418]
#  [1720.2731]
#  [1717.4077]
#  [1731.9253]
#  [1754.7405]
#  [1751.0272]
#  [1733.7882]
#  [1731.6898]
#  [1740.8994]
#  [1763.0522]
#  [1734.4802]
#  [1723.5   ]
#  [1703.3672]
#  [1702.1763]
#  [1704.9302]
#  [1676.9003]
#  [1670.8502]
#  [1678.885 ]
#  [1695.1056]
#  [1702.8796]
#  [1690.1078]
#  [1662.2247]
#  [1657.255 ]
#  [1669.7883]
#  [1725.1781]
#  [1756.932 ]
#  [1754.6025]
#  [1743.6864]
#  [1747.9724]
#  [1788.0742]
#  [1794.6934]
#  [1783.9218]
#  [1727.0535]
#  [1707.8745]
#  [1692.2949]
#  [1687.7948]
#  [1781.8534]
#  [1843.1615]
#  [1817.5969]
#  [1833.4132]
#  [1827.5156]
#  [1893.3068]
#  [1929.1335]
#  [2069.2922]
#  [2093.3691]
#  [2061.2288]
#  [2044.9825]
#  [2040.24  ]
#  [2024.4869]
#  [1991.3055]
#  [1997.4125]
#  [2009.4607]
#  [1976.5333]
#  [1910.2834]
#  [1856.8792]
#  [1772.0405]
#  [1720.8912]
#  [1704.7373]
#  [1695.9348]
#  [1686.6478]
#  [1709.3892]
#  [1733.2844]
#  [1751.15  ]
#  [1752.4587]
#  [1768.1914]
#  [1799.7216]
#  [1790.792 ]
#  [1824.2799]
#  [1825.4989]
#  [1815.1836]
#  [1834.7535]
#  [1853.4313]
#  [1871.1602]
#  [1870.7782]
#  [1846.5946]
#  [1811.688 ]
#  [1784.783 ]
#  [1775.6145]
#  [1786.4371]
#  [1791.0344]
#  [1942.0388]
#  [1993.496 ]
#  [2011.8768]
#  [1999.1718]
#  [1968.0697]
#  [1877.0732]
#  [1818.1555]
#  [1872.2347]
#  [1873.4587]
#  [1839.8867]
#  [1849.4484]
#  [1852.502 ]
#  [1868.0137]
#  [1779.1631]
#  [2303.947 ]
#  [2378.11  ]
#  [2361.5972]
#  [2282.5137]
#  [2276.6567]
#  [2254.872 ]
#  [2432.6755]
#  [2590.9006]
#  [2602.2834]
#  [2563.46  ]
#  [2600.8855]
#  [2717.7295]
#  [2553.198 ]
#  [2394.3665]
#  [2308.8774]
#  [2138.626 ]
#  [2047.7784]
#  [2047.6152]
#  [2065.11  ]
#  [2066.366 ]
#  [2772.3394]
#  [2531.3535]
#  [2326.341 ]
#  [2211.43  ]
#  [2168.0688]
#  [2304.3232]
#  [2349.8481]
#  [2245.0989]
#  [2123.3005]
#  [2022.1982]
#  [2051.7505]
#  [2092.5981]
#  [2135.4453]
#  [2180.5679]
#  [2180.3647]
#  [2139.301 ]
#  [2132.2307]
#  [2097.256 ]
#  [2076.3948]
#  [2157.7422]
#  [2175.6558]
#  [2165.9065]
#  [2028.7603]
#  [1962.4766]
#  [1916.894 ]
#  [1877.2909]
#  [1869.4447]
#  [1881.605 ]
#  [1876.6261]
#  [1849.2355]
#  [1861.3938]
#  [1883.9346]
#  [1883.93  ]
#  [1871.3685]
#  [1917.9044]
#  [1967.6748]
#  [1977.5824]
#  [2006.4359]
#  [2001.6658]
#  [1977.2026]
#  [2007.282 ]
#  [2028.7219]
#  [2004.1525]
#  [1975.3983]
#  [1947.1338]
#  [1919.6539]
#  [1918.9404]
#  [1958.1893]
#  [1942.7385]
#  [1909.9641]
#  [1925.3274]
#  [1944.3359]
#  [1959.9615]
#  [1958.0889]
#  [1942.6112]
#  [1974.9232]
#  [1994.4209]
#  [2011.3918]
#  [1994.8003]
#  [1964.5748]
#  [1987.9056]
#  [2012.3845]
#  [2006.8401]
#  [2007.202 ]
#  [1969.1221]
#  [1955.9409]
#  [1988.5326]
#  [2012.1395]
#  [2008.1525]
#  [2076.2744]
#  [2133.811 ]
#  [2150.3745]
#  [2133.1138]
#  [2101.0676]
#  [2037.5095]
#  [2023.5284]
#  [2046.3789]
#  [1994.371 ]
#  [1914.9385]
#  [1869.2384]
#  [1871.7039]
#  [1860.4447]
#  [1809.648 ]
#  [1810.5471]
#  [1836.5577]
#  [1861.5372]
#  [1883.7754]
#  [1876.1765]
#  [1857.0598]
#  [1799.8461]
#  [1749.9431]
#  [1762.5996]
#  [1756.4137]
#  [1734.781 ]
#  [1713.8735]
#  [1715.6293]
#  [1728.9781]
#  [1721.776 ]
#  [1711.3834]
#  [1675.4733]
#  [1677.8523]
#  [1714.758 ]
#  [1704.4712]
#  [1689.1858]
#  [1671.236 ]
#  [1703.9828]
#  [1688.4661]
#  [1737.3333]
#  [1763.2114]
#  [1752.557 ]
#  [1738.6697]
#  [1750.7346]
#  [1735.1263]
#  [1762.5035]
#  [1757.8307]
#  [1748.4248]
#  [1670.2152]
#  [1637.8169]
#  [1649.5942]
#  [1641.9539]
#  [1630.7689]
#  [1599.3301]
#  [1604.7063]
#  [1621.8319]
#  [1627.185 ]
#  [1607.1058]
#  [1627.6569]
#  [1641.1542]
#  [1633.1133]
#  [1631.8595]
#  [1642.7411]
#  [1651.0613]
#  [1649.4509]
#  [1640.8212]
#  [1601.5829]
#  [1612.5646]
#  [1619.2375]
#  [1609.2026]
#  [1591.7015]
#  [1685.8616]
#  [1750.0934]
#  [1776.6626]
#  [1765.9989]
#  [1726.0814]
#  [1703.6755]
#  [1712.6757]
#  [1674.9633]
#  [1693.2872]
#  [1698.6559]
#  [1647.7289]
#  [1631.352 ]
#  [1641.9904]
#  [1637.2184]
#  [1640.7511]
#  [1621.6346]
#  [1625.3495]
#  [1640.76  ]
#  [1638.2272]
#  [1632.6576]
#  [1626.7194]
#  [1647.4893]
#  [1710.428 ]
#  [1735.479 ]
#  [1733.7928]
#  [1744.1417]
#  [1779.6594]
#  [1822.174 ]
#  [1819.0983]
#  [1806.9971]
#  [1895.108 ]
#  [1957.8605]
#  [2002.6643]
#  [2004.3185]
#  [1972.4734]
#  [2082.3335]
#  [2176.5361]
#  [2130.218 ]
#  [2094.0793]
#  [1943.5208]
#  [1870.9023]
#  [1863.9912]
#  [1995.2307]
#  [1923.4346]
#  [2026.8767]
#  [2068.918 ]
#  [2170.7698]
#  [2169.9114]
#  [2118.276 ]
#  [2109.181 ]
#  [2130.4434]
#  [2108.3984]
#  [2073.5796]
#  [2078.9282]
#  [2120.3872]
#  [2109.6982]
#  [2092.5183]
#  [1916.793 ]
#  [1812.9933]
#  [1978.1302]
#  [2008.8357]
#  [2005.4108]
#  [1906.3145]
#  [1855.3511]
#  [1993.3771]
#  [2045.3197]
#  [2052.6929]
#  [2017.8927]
#  [2101.7295]
#  [2118.4978]
#  [2121.9402]
#  [2117.6018]
#  [2114.5703]
#  [2139.7058]
#  [2165.6587]
#  [2448.536 ]
#  [2460.3726]
#  [2467.0918]
#  [2403.764 ]
#  [2509.0803]
#  [2654.4849]
#  [3022.3315]
#  [2960.648 ]
#  [2921.895 ]
#  [2733.2136]
#  [2592.108 ]
#  [2665.8596]
#  [3180.0515]
#  [3023.427 ]
#  [2931.6343]
#  [2962.3408]
#  [2731.147 ]
#  [2714.8528]
#  [2639.4316]
#  [2552.5234]
#  [2683.4807]
#  [2791.791 ]
#  [2554.163 ]
#  [2737.0017]
#  [2964.6526]
#  [3120.419 ]
#  [3183.5063]
#  [3083.2993]
#  [3137.8997]
#  [3149.024 ]
#  [3167.8591]
#  [3155.8572]
#  [2927.6133]
#  [2875.2068]
#  [2859.0642]
#  [2789.9998]
#  [3016.2957]
#  [3008.9373]
#  [2935.6707]
#  [3324.803 ]
#  [3360.2598]
#  [3743.6616]
#  [3963.7776]
#  [3775.4631]
#  [3504.4976]
#  [3461.8892]] (477, 1)
# [[2985.]
#  [2784.]
#  [2670.]
#  [2730.]
#  [2773.]
#  [2695.]
#  [2657.]
#  [2630.]
#  [2497.]
#  [2449.]
#  [2449.]
#  [2423.]
#  [2423.]
#  [2280.]
#  [2280.]
#  [2280.]
#  [2280.]
#  [2066.]
#  [2042.]
#  [2092.]
#  [2092.]
#  [2092.]
#  [2063.]
#  [1968.]
#  [1968.]
#  [1968.]
#  [1968.]
#  [1968.]
#  [1968.]
#  [1968.]
#  [1968.]
#  [1968.]
#  [1968.]
#  [1934.]
#  [1871.]
#  [1934.]
#  [1934.]
#  [1884.]
#  [1884.]
#  [1884.]
#  [1884.]
#  [1834.]
#  [1805.]
#  [1805.]
#  [1805.]
#  [1805.]
#  [1805.]
#  [1779.]
#  [1698.]
#  [1762.]
#  [1762.]
#  [2098.]
#  [2068.]
#  [2068.]
#  [2068.]
#  [2045.]
#  [2045.]
#  [2045.]
#  [1970.]
#  [1970.]
#  [2157.]
#  [2213.]
#  [2213.]
#  [2213.]
#  [2213.]
#  [2213.]
#  [2213.]
#  [2055.]
#  [2055.]
#  [2055.]
#  [2147.]
#  [2147.]
#  [2147.]
#  [2147.]
#  [2147.]
#  [1893.]
#  [1893.]
#  [1893.]
#  [1893.]
#  [1893.]
#  [1855.]
#  [1808.]
#  [1808.]
#  [1723.]
#  [1723.]
#  [1770.]
#  [1645.]
#  [1645.]
#  [1630.]
#  [1630.]
#  [1630.]
#  [1590.]
#  [1590.]
#  [1590.]
#  [1590.]
#  [1590.]
#  [1590.]
#  [1543.]
#  [1543.]
#  [1543.]
#  [1543.]
#  [1543.]
#  [1543.]
#  [1543.]
#  [1543.]
#  [1543.]
#  [1543.]
#  [1548.]
#  [1548.]
#  [1548.]
#  [1500.]
#  [1548.]
#  [1500.]
#  [1500.]
#  [1500.]
#  [1453.]
#  [1500.]
#  [1500.]
#  [1500.]
#  [1458.]
#  [1458.]
#  [1458.]
#  [1480.]
#  [1480.]
#  [1530.]
#  [1555.]
#  [1555.]
#  [1530.]
#  [1530.]
#  [1580.]
#  [1580.]
#  [1580.]
#  [1483.]
#  [1483.]
#  [1483.]
#  [1483.]
#  [1647.]
#  [1647.]
#  [1573.]
#  [1647.]
#  [1647.]
#  [1713.]
#  [1713.]
#  [1830.]
#  [1830.]
#  [1830.]
#  [1830.]
#  [1830.]
#  [1830.]
#  [1830.]
#  [1830.]
#  [1830.]
#  [1770.]
#  [1698.]
#  [1698.]
#  [1552.]
#  [1552.]
#  [1552.]
#  [1552.]
#  [1552.]
#  [1552.]
#  [1552.]
#  [1552.]
#  [1552.]
#  [1598.]
#  [1617.]
#  [1557.]
#  [1617.]
#  [1608.]
#  [1608.]
#  [1648.]
#  [1648.]
#  [1648.]
#  [1648.]
#  [1648.]
#  [1612.]
#  [1580.]
#  [1580.]
#  [1614.]
#  [1614.]
#  [1761.]
#  [1761.]
#  [1761.]
#  [1761.]
#  [1761.]
#  [1644.]
#  [1616.]
#  [1687.]
#  [1687.]
#  [1688.]
#  [1688.]
#  [1672.]
#  [1672.]
#  [1490.]
#  [2070.]
#  [2038.]
#  [2038.]
#  [1988.]
#  [2063.]
#  [2063.]
#  [2213.]
#  [2330.]
#  [2330.]
#  [2330.]
#  [2415.]
#  [2495.]
#  [2273.]
#  [2203.]
#  [2203.]
#  [1973.]
#  [1973.]
#  [1973.]
#  [1973.]
#  [1973.]
#  [2415.]
#  [2028.]
#  [2028.]
#  [2028.]
#  [2080.]
#  [2180.]
#  [2180.]
#  [2005.]
#  [1910.]
#  [1910.]
#  [1960.]
#  [1960.]
#  [1960.]
#  [2005.]
#  [2005.]
#  [1948.]
#  [1948.]
#  [1905.]
#  [1905.]
#  [1980.]
#  [1980.]
#  [1980.]
#  [1788.]
#  [1788.]
#  [1745.]
#  [1745.]
#  [1745.]
#  [1745.]
#  [1695.]
#  [1695.]
#  [1713.]
#  [1713.]
#  [1673.]
#  [1673.]
#  [1773.]
#  [1773.]
#  [1755.]
#  [1780.]
#  [1780.]
#  [1780.]
#  [1823.]
#  [1823.]
#  [1776.]
#  [1776.]
#  [1776.]
#  [1746.]
#  [1746.]
#  [1746.]
#  [1746.]
#  [1746.]
#  [1760.]
#  [1760.]
#  [1760.]
#  [1760.]
#  [1760.]
#  [1786.]
#  [1786.]
#  [1786.]
#  [1786.]
#  [1786.]
#  [1814.]
#  [1814.]
#  [1786.]
#  [1786.]
#  [1786.]
#  [1790.]
#  [1819.]
#  [1819.]
#  [1819.]
#  [1873.]
#  [1907.]
#  [1907.]
#  [1907.]
#  [1907.]
#  [1840.]
#  [1840.]
#  [1872.]
#  [1795.]
#  [1723.]
#  [1718.]
#  [1718.]
#  [1678.]
#  [1614.]
#  [1678.]
#  [1678.]
#  [1678.]
#  [1732.]
#  [1732.]
#  [1732.]
#  [1692.]
#  [1652.]
#  [1684.]
#  [1684.]
#  [1684.]
#  [1673.]
#  [1673.]
#  [1657.]
#  [1657.]
#  [1657.]
#  [1635.]
#  [1635.]
#  [1635.]
#  [1635.]
#  [1635.]
#  [1635.]
#  [1652.]
#  [1592.]
#  [1690.]
#  [1690.]
#  [1690.]
#  [1690.]
#  [1723.]
#  [1675.]
#  [1686.]
#  [1686.]
#  [1686.]
#  [1577.]
#  [1577.]
#  [1577.]
#  [1577.]
#  [1577.]
#  [1552.]
#  [1552.]
#  [1552.]
#  [1552.]
#  [1552.]
#  [1552.]
#  [1552.]
#  [1552.]
#  [1592.]
#  [1592.]
#  [1550.]
#  [1592.]
#  [1592.]
#  [1538.]
#  [1538.]
#  [1538.]
#  [1538.]
#  [1513.]
#  [1668.]
#  [1668.]
#  [1668.]
#  [1668.]
#  [1635.]
#  [1652.]
#  [1652.]
#  [1570.]
#  [1652.]
#  [1652.]
#  [1570.]
#  [1570.]
#  [1570.]
#  [1570.]
#  [1570.]
#  [1553.]
#  [1553.]
#  [1553.]
#  [1553.]
#  [1553.]
#  [1563.]
#  [1563.]
#  [1635.]
#  [1647.]
#  [1647.]
#  [1685.]
#  [1685.]
#  [1727.]
#  [1727.]
#  [1727.]
#  [1860.]
#  [1860.]
#  [1907.]
#  [1907.]
#  [1907.]
#  [2015.]
#  [2060.]
#  [2027.]
#  [2027.]
#  [1850.]
#  [1850.]
#  [1850.]
#  [2000.]
#  [1850.]
#  [2000.]
#  [2000.]
#  [2080.]
#  [2080.]
#  [2080.]
#  [2080.]
#  [2080.]
#  [2080.]
#  [2080.]
#  [2080.]
#  [2080.]
#  [2080.]
#  [2080.]
#  [1810.]
#  [1810.]
#  [1994.]
#  [1994.]
#  [1994.]
#  [1856.]
#  [1856.]
#  [2014.]
#  [2014.]
#  [2014.]
#  [2114.]
#  [2148.]
#  [2148.]
#  [2148.]
#  [2148.]
#  [2148.]
#  [2148.]
#  [2148.]
#  [2385.]
#  [2445.]
#  [2445.]
#  [2423.]
#  [2507.]
#  [2638.]
#  [2937.]
#  [2915.]
#  [2937.]
#  [2750.]
#  [2692.]
#  [2766.]
#  [3150.]
#  [3030.]
#  [3000.]
#  [3080.]
#  [2780.]
#  [2880.]
#  [2798.]
#  [2798.]
#  [2942.]
#  [2942.]
#  [2717.]
#  [2944.]
#  [3083.]
#  [3230.]
#  [3293.]
#  [3293.]
#  [3293.]
#  [3333.]
#  [3333.]
#  [3333.]
#  [3063.]
#  [3063.]
#  [3063.]
#  [2948.]
#  [3135.]
#  [3115.]
#  [3174.]
#  [3440.]
#  [3540.]
#  [4002.]
#  [4480.]
#  [4214.]
#  [3762.]
#  [3762.]
#  [3848.]
#  [3848.]
#  [3848.]] (477, 1)

# %%
from sklearn.metrics import mean_squared_error 
MSE = mean_squared_error(testY_test, predicted_price_test_test) 
np.sqrt(MSE)
# Out:
# 222.87052180619494

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(testY_test, predicted_price_test_test)
# Out:
# 179.4269443727889

# %% [markdown]
# 예측방법

# %%
minX1 = np.array(dataX[0:3])
minX2 = np.array(dataX[0:4])
minX3 = np.array(dataX[0:2385])
minX4 = np.array(dataX[0:train_size])

# %%
predicted_price_min1 = model.predict(minX1, batch_size=a, verbose=1)
predicted_price_min2 = model.predict(minX2, batch_size=a, verbose=1) 
predicted_price_min3 = model.predict(minX3, batch_size=a, verbose=1)
predicted_price_min4 = model.predict(minX4, batch_size=a, verbose=1)
# Out:
# 1/1 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 1s 7ms/step
# 795/795 [==============================] - 2s 2ms/step
# 477/477 [==============================] - 1s 2ms/step

# %%
predicted_price_min1[0]
# Out:
# array([[0.655417  ],
#        [0.56645775],
#        [0.4538216 ]], dtype=float32)

# %%
predicted_price_min2[0]
# Out:
# array([[0.33691382],
#        [0.24142867],
#        [0.1687772 ]], dtype=float32)

# %%
predicted_price_min3[0]
# Out:
# array([[0.16786608],
#        [0.20725758],
#        [0.22311187]], dtype=float32)

# %%
scaler_target.inverse_transform(predicted_price_min4[0].reshape(-1,1))
# Out:
# array([[3297.0466],
#        [2991.6494],
#        [2604.9695]], dtype=float32)
